# %%
import tweepy
import os

# %%
consumer_key = "9cuRdPVXL2A433I6YFLPJuuE1"
consumer_secret = "Phlg3oDnWtqmlO6J0dCPdoHDFNWgTI0IYxFDigNLgoN9YpyV1W"
access_token = "1556896317821300736-d4ztDHqFknmBVDxGqovwCZ4SWbTv5O"
access_token_secret = "3J4x1QPKZUAj9jvcEldA30cUKXsPaJPtG4eguEuUYoBf7"

# %%
#계정 승인
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
twitter_api = tweepy.API(auth)

# %%
#검색 키워드 정의
keyword = "폭우"
api_result = []

# %%
api = tweepy.API(auth)

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
location = "%s,%s,%s" % ("35.95", "128.25", "1000km")  # 검색기준(대한민국 중심) 좌표, 반지름  

keyword = "폭우 OR 재난"                             # OR 로 검색어 묶어줌, 검색어 5개(반드시 OR 대문자로)

wfile = open(os.getcwd()+"/twitter.txt", mode='w', encoding='UTF-8')     # 텍스트 파일로 출력(쓰기모드)

# twitter 검색 cursor 선언

cursor = tweepy.Cursor(api.search_tweets, 
                       q=keyword,
                       #since='2020-01-01', # 2015-01-01 이후에 작성된 트윗들로 가져옴
                       count=1000,  # 페이지당 반환할 트위터 수 최대 100
                       geocode=location,
                       include_entities=True)

# %%
tweepy.cursor.Cursor
# Out:
# tweepy.cursor.Cursor

# %%
for i, tweet in enumerate(cursor.items()):
    print("{}: {}".format(i, tweet.text))
    wfile.write(tweet.text + '\n')
    
wfile.close()
# Out:
# 0: @hong_gil_dong12 최소한의 생각은 아까부터 본인이 안 하시는데요. 기본도 안 하고 재난 앞에 뭘 할 수 있겠어 징징만 몇번을 대답해드려야 하는지 모르겠네요. 누가 비 안 오게 했나요. 폭우 상황… https://t.co/PH2HJjv1YK
# 1: 험한 말 썼다가 지웠다. 우리 개아들들 보고싶다.폭우와 폭설을 뚫고 튼튼이 픽업하던때가 바로 얼마전인데..오늘은 컨디션이 별로라 계속 누워있다.내 삶이 갑갑하게 느껴지는 날이다.
# 2: 논란에 기름 끼얹나…尹대통령 ＂퇴근 때 이미 침수되더라＂(출처 : 시사저널 | 네이버 뉴스) https://t.co/yAYE6ysgEa
# 정부의 재난 대응을 둘러싼 비판이 커지는 가운데 윤석열 대통령이 국민… https://t.co/OaOHbvFm9j
# 3: 국립중앙도서관은 폭우 피해가 꽤 있나본데..
# ..수장고는 괜찮겠지 https://t.co/IYZByuTaaG
# 4: 맞아 어제 성남시는 재난문자없었지. https://t.co/kVwWffbWzV
# 5: 박성중, 폭우 피해 입은 서초구 "전쟁터 따로 없어"…9일 저녁에도 많은 비 예상으로 '비상'
#
# https://t.co/FCZ82DvnIj
# 6: 대한민국은 재난에 참 무감각하다는 생각을 했던게 일본 중형 태풍 올 때 백화점, 가게부터 지하철까지 18시에 셧다운…. 우리 이 날씨에 출근했다는거 부터가 좀 나에겐 이상함…
# 7: #윤석열 의 #이상한 #5시간, #국가 #재난 역대급 #폭우
#
# https://t.co/JuFcGW3DRa
# 8: 진짜 목숨 걸고 출근했다고..물 건너 왔더니 '나홀로 회사에' | 다음 뉴스 https://t.co/iiNbwHg1cs
# [2022 수도권 폭우]지하철 일부 운행중지, 도로 통제
# 귀가 아예 포기한 시민들도
# "이런 날씨에 출근해야 하느냐"
# 9: 이렇게 몇날며칠 폭우가 쏟아지는 날이면  수도꼭지 트는 것도 조심스럽다.
# ...

# %%
import pandas as pd

file = pd.read_csv('./twitter.txt')
new_csv_file = file.to_csv('./twitter.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       1 import pandas as pd
# ----> 3 file = pd.read_csv('./twitter.txt')
#       4 new_csv_file = file.to_csv('./twitter.csv')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

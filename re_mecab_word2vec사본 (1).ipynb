# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.7 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 10.4 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-08-12 11:24:11--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::3403:4be7, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOS4X4Q6S&Signature=jEm1PZGJfffyKQJ%2Bgiyf%2B30OBLA%3D&x-amz-security-token=FwoGZXIvYXdzEB0aDJ8PV7%2F7DBcg7%2FFm8yK%2BAWCP0zXclm3lAHf%2FdOIVAvTLfD3uvanN3fThzVfQTwBmT%2FcSBEUVueoRh%2Fk3mkonZraUnVKaY0je9VN4T1g2B%2Fy4oNwfklRnX01KIIhWVkNdiEMOEkIOotQBs07%2Bt9XR3ZiIglBuwgmtzjvyUdw1BmJVckkU2mijPzUCxmQcLW52YCug1pyd33Zb%2FB7beRo3KIl%2FhF%2FasqUc7Xf%2BEit%2B4SqAdfABbA0UyiMWicd%2Fw46fIZKPZbtfs2l5i55MovIo2%2FDYlwYyLerUBiivFtIo8qnUrqBBQXW25SU5S5wPSucHPD%2BmodC7vi7AStdfoNx9l%2B9hWg%3D%3D&Expires=1660305251 [following]
# --2022-08-12 11:24:11--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOS4X4Q6S&Signature=jEm1PZGJfffyKQJ%2Bgiyf%2B30OBLA%3D&x-amz-security-token=FwoGZXIvYXdzEB0aDJ8PV7%2F7DBcg7%2FFm8yK%2BAWCP0zXclm3lAHf%2FdOIVAvTLfD3uvanN3fThzVfQTwBmT%2FcSBEUVueoRh%2Fk3mkonZraUnVKaY0je9VN4T1g2B%2Fy4oNwfklRnX01KIIhWVkNdiEMOEkIOotQBs07%2Bt9XR3ZiIglBuwgmtzjvyUdw1BmJVckkU2mijPzUCxmQcLW52YCug1pyd33Zb%2FB7beRo3KIl%2FhF%2FasqUc7Xf%2BEit%2B4SqAdfABbA0UyiMWicd%2Fw46fIZKPZbtfs2l5i55MovIo2%2FDYlwYyLerUBiivFtIo8qnUrqBBQXW25SU5S5wPSucHPD%2BmodC7vi7AStdfoNx9l%2B9hWg%3D%3D&Expires=1660305251
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.172.161
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.172.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  7.56MB/s    in 0.2s
#
# 2022-08-12 11:24:12 (7.56 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2022-08-12 11:25:47--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c5:2ef4, 2406:da00:ff00::3403:4be7, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNLFQ64U6N&Signature=APwn4OLVJ6GwUUZ%2FOo3LvmjTboc%3D&x-amz-security-token=FwoGZXIvYXdzEB0aDBg1mwoMWUkieYLGHyK%2BAUYaIwefTCWNRDHd%2FYfLd0axJhpFj9VrWPLLQTd0uqYpv3fiAq5Cg3J9T8R6ZdRPyvNVOYW01ixwRMpq0NXxojdB8b0RsKk4nfEYVfQ5bRyawE59pOr648%2Bd2AgJPgW%2Fscs6ysyiqWxDKmszcGNbn7PARHjrEodEBgiHGDrUNatODQ90bPLtYhBAIKq7cKMqDsAunc%2FweXcdz1SYrW094G1HpszH3A%2FYLZyEvA5kTJCwN5HVvzw2posXeT%2BpgDwoj%2B7YlwYyLfv70qItxiaAiLXTN6UD%2BL6LOKl4shp37BkcaKGIvh21W%2FUBdfDgUr8OOPUtxg%3D%3D&Expires=1660304919 [following]
# --2022-08-12 11:25:47--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNLFQ64U6N&Signature=APwn4OLVJ6GwUUZ%2FOo3LvmjTboc%3D&x-amz-security-token=FwoGZXIvYXdzEB0aDBg1mwoMWUkieYLGHyK%2BAUYaIwefTCWNRDHd%2FYfLd0axJhpFj9VrWPLLQTd0uqYpv3fiAq5Cg3J9T8R6ZdRPyvNVOYW01ixwRMpq0NXxojdB8b0RsKk4nfEYVfQ5bRyawE59pOr648%2Bd2AgJPgW%2Fscs6ysyiqWxDKmszcGNbn7PARHjrEodEBgiHGDrUNatODQ90bPLtYhBAIKq7cKMqDsAunc%2FweXcdz1SYrW094G1HpszH3A%2FYLZyEvA5kTJCwN5HVvzw2posXeT%2BpgDwoj%2B7YlwYyLfv70qItxiaAiLXTN6UD%2BL6LOKl4shp37BkcaKGIvh21W%2FUBdfDgUr8OOPUtxg%3D%3D&Expires=1660304919
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 3.5.16.16
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|3.5.16.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  61.6MB/s    in 0.8s
#
# 2022-08-12 11:25:48 (61.6 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %%
import re

# %%
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash
# Out:
# --2022-08-16 12:25:07--  https://www.dropbox.com/s/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz [following]
# --2022-08-16 12:25:08--  https://www.dropbox.com/s/dl/9xls0tgtf3edgns/mecab-0.996-ko-0.9.2.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com/cd/0/get/BrFS2S5A5OHh-gpZuv9jRJAuqXBCBwLl9O3DGjolPWtsloD_jA3LXzygjPEtNPv-Pkrb5M4jBULXmwXYFefGMi1kKhSkt4Vj3qc9ge7vGojsJtWVQKo9Wnh-KRGv1IfH9diWibEesDA46gs6AyO8MCG7VDSO0RzwR0F16MTxlT7ojj9mL1XQuNV5n-8tkD-me3c/file?dl=1# [following]
# --2022-08-16 12:25:08--  https://uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com/cd/0/get/BrFS2S5A5OHh-gpZuv9jRJAuqXBCBwLl9O3DGjolPWtsloD_jA3LXzygjPEtNPv-Pkrb5M4jBULXmwXYFefGMi1kKhSkt4Vj3qc9ge7vGojsJtWVQKo9Wnh-KRGv1IfH9diWibEesDA46gs6AyO8MCG7VDSO0RzwR0F16MTxlT7ojj9mL1XQuNV5n-8tkD-me3c/file?dl=1
# Resolving uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com (uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com (uc3622182cdd78a6717c567d84e3.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/binary]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.06s
#
# 2022-08-16 12:25:09 (21.1 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz?dl=1’ saved [1414979/1414979]
#
# mecab-0.996-ko-0.9.2/
# mecab-0.996-ko-0.9.2/example/
# mecab-0.996-ko-0.9.2/example/example.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.cpp
# mecab-0.996-ko-0.9.2/example/example_lattice.c
# mecab-0.996-ko-0.9.2/example/example.c
# mecab-0.996-ko-0.9.2/example/thread_test.cpp
# mecab-0.996-ko-0.9.2/mecab-config.in
# mecab-0.996-ko-0.9.2/man/
# mecab-0.996-ko-0.9.2/man/Makefile.am
# mecab-0.996-ko-0.9.2/man/mecab.1
# mecab-0.996-ko-0.9.2/man/Makefile.in
# mecab-0.996-ko-0.9.2/mecab.iss.in
# mecab-0.996-ko-0.9.2/config.guess
# mecab-0.996-ko-0.9.2/README
# mecab-0.996-ko-0.9.2/COPYING
# mecab-0.996-ko-0.9.2/CHANGES.md
# mecab-0.996-ko-0.9.2/README.md
# mecab-0.996-ko-0.9.2/INSTALL
# mecab-0.996-ko-0.9.2/config.sub
# mecab-0.996-ko-0.9.2/configure.in
# mecab-0.996-ko-0.9.2/swig/
# mecab-0.996-ko-0.9.2/swig/Makefile
# mecab-0.996-ko-0.9.2/swig/version.h.in
# mecab-0.996-ko-0.9.2/swig/version.h
# mecab-0.996-ko-0.9.2/swig/MeCab.i
# mecab-0.996-ko-0.9.2/aclocal.m4
# mecab-0.996-ko-0.9.2/LGPL
# mecab-0.996-ko-0.9.2/Makefile.am
# mecab-0.996-ko-0.9.2/configure
# mecab-0.996-ko-0.9.2/tests/
# mecab-0.996-ko-0.9.2/tests/autolink/
# mecab-0.996-ko-0.9.2/tests/autolink/unk.def
# mecab-0.996-ko-0.9.2/tests/autolink/dicrc
# mecab-0.996-ko-0.9.2/tests/autolink/dic.csv
# mecab-0.996-ko-0.9.2/tests/autolink/test
# mecab-0.996-ko-0.9.2/tests/autolink/char.def
# mecab-0.996-ko-0.9.2/tests/autolink/matrix.def
# mecab-0.996-ko-0.9.2/tests/autolink/test.gld
# mecab-0.996-ko-0.9.2/tests/t9/
# mecab-0.996-ko-0.9.2/tests/t9/unk.def
# mecab-0.996-ko-0.9.2/tests/t9/ipadic.pl
# mecab-0.996-ko-0.9.2/tests/t9/dicrc
# mecab-0.996-ko-0.9.2/tests/t9/dic.csv
# mecab-0.996-ko-0.9.2/tests/t9/test
# mecab-0.996-ko-0.9.2/tests/t9/char.def
# mecab-0.996-ko-0.9.2/tests/t9/matrix.def
# mecab-0.996-ko-0.9.2/tests/t9/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/t9/test.gld
# mecab-0.996-ko-0.9.2/tests/cost-train/
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.train
# mecab-0.996-ko-0.9.2/tests/cost-train/ipa.test
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/rewrite.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/feature.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/unk.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dicrc
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/dic.csv
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/char.def
# mecab-0.996-ko-0.9.2/tests/cost-train/seed/matrix.def
# mecab-0.996-ko-0.9.2/tests/run-eval.sh
# mecab-0.996-ko-0.9.2/tests/run-cost-train.sh
# mecab-0.996-ko-0.9.2/tests/Makefile.am
# mecab-0.996-ko-0.9.2/tests/katakana/
# mecab-0.996-ko-0.9.2/tests/katakana/unk.def
# mecab-0.996-ko-0.9.2/tests/katakana/dicrc
# mecab-0.996-ko-0.9.2/tests/katakana/dic.csv
# mecab-0.996-ko-0.9.2/tests/katakana/test
# mecab-0.996-ko-0.9.2/tests/katakana/char.def
# mecab-0.996-ko-0.9.2/tests/katakana/matrix.def
# mecab-0.996-ko-0.9.2/tests/katakana/test.gld
# mecab-0.996-ko-0.9.2/tests/eval/
# mecab-0.996-ko-0.9.2/tests/eval/answer
# mecab-0.996-ko-0.9.2/tests/eval/system
# mecab-0.996-ko-0.9.2/tests/eval/test.gld
# mecab-0.996-ko-0.9.2/tests/shiin/
# mecab-0.996-ko-0.9.2/tests/shiin/unk.def
# mecab-0.996-ko-0.9.2/tests/shiin/dicrc
# mecab-0.996-ko-0.9.2/tests/shiin/dic.csv
# mecab-0.996-ko-0.9.2/tests/shiin/test
# mecab-0.996-ko-0.9.2/tests/shiin/char.def
# mecab-0.996-ko-0.9.2/tests/shiin/matrix.def
# mecab-0.996-ko-0.9.2/tests/shiin/mkdic.pl
# mecab-0.996-ko-0.9.2/tests/shiin/test.gld
# mecab-0.996-ko-0.9.2/tests/latin/
# mecab-0.996-ko-0.9.2/tests/latin/unk.def
# mecab-0.996-ko-0.9.2/tests/latin/dicrc
# mecab-0.996-ko-0.9.2/tests/latin/dic.csv
# mecab-0.996-ko-0.9.2/tests/latin/test
# mecab-0.996-ko-0.9.2/tests/latin/char.def
# mecab-0.996-ko-0.9.2/tests/latin/matrix.def
# mecab-0.996-ko-0.9.2/tests/latin/test.gld
# mecab-0.996-ko-0.9.2/tests/chartype/
# mecab-0.996-ko-0.9.2/tests/chartype/unk.def
# mecab-0.996-ko-0.9.2/tests/chartype/dicrc
# mecab-0.996-ko-0.9.2/tests/chartype/dic.csv
# mecab-0.996-ko-0.9.2/tests/chartype/test
# mecab-0.996-ko-0.9.2/tests/chartype/char.def
# mecab-0.996-ko-0.9.2/tests/chartype/matrix.def
# mecab-0.996-ko-0.9.2/tests/chartype/test.gld
# mecab-0.996-ko-0.9.2/tests/run-dics.sh
# mecab-0.996-ko-0.9.2/tests/ngram/
# mecab-0.996-ko-0.9.2/tests/ngram/unk.def
# mecab-0.996-ko-0.9.2/tests/ngram/dicrc
# mecab-0.996-ko-0.9.2/tests/ngram/dic.csv
# mecab-0.996-ko-0.9.2/tests/ngram/test
# mecab-0.996-ko-0.9.2/tests/ngram/char.def
# mecab-0.996-ko-0.9.2/tests/ngram/matrix.def
# mecab-0.996-ko-0.9.2/tests/ngram/test.gld
# mecab-0.996-ko-0.9.2/tests/Makefile.in
# mecab-0.996-ko-0.9.2/ltmain.sh
# mecab-0.996-ko-0.9.2/config.rpath
# mecab-0.996-ko-0.9.2/config.h.in
# mecab-0.996-ko-0.9.2/mecabrc.in
# mecab-0.996-ko-0.9.2/GPL
# mecab-0.996-ko-0.9.2/Makefile.train
# mecab-0.996-ko-0.9.2/ChangeLog
# mecab-0.996-ko-0.9.2/install-sh
# mecab-0.996-ko-0.9.2/AUTHORS
# mecab-0.996-ko-0.9.2/doc/
# mecab-0.996-ko-0.9.2/doc/bindings.html
# mecab-0.996-ko-0.9.2/doc/posid.html
# mecab-0.996-ko-0.9.2/doc/unk.html
# mecab-0.996-ko-0.9.2/doc/learn.html
# mecab-0.996-ko-0.9.2/doc/format.html
# mecab-0.996-ko-0.9.2/doc/libmecab.html
# mecab-0.996-ko-0.9.2/doc/mecab.css
# mecab-0.996-ko-0.9.2/doc/feature.html
# mecab-0.996-ko-0.9.2/doc/Makefile.am
# mecab-0.996-ko-0.9.2/doc/soft.html
# mecab-0.996-ko-0.9.2/doc/en/
# mecab-0.996-ko-0.9.2/doc/en/bindings.html
# mecab-0.996-ko-0.9.2/doc/dic-detail.html
# mecab-0.996-ko-0.9.2/doc/flow.png
# mecab-0.996-ko-0.9.2/doc/mecab.html
# mecab-0.996-ko-0.9.2/doc/index.html
# mecab-0.996-ko-0.9.2/doc/result.png
# mecab-0.996-ko-0.9.2/doc/doxygen/
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_a.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_eval.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_vars.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.css
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_r.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Tagger.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h_source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tabs.css
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_f.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.png
# mecab-0.996-ko-0.9.2/doc/doxygen/globals.html
# mecab-0.996-ko-0.9.2/doc/doxygen/nav_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_h.png
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/closed.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_l.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/functions_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Lattice-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_func.html
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers_type.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classMeCab_1_1Model-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__dictionary__info__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaces.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespacemembers.html
# mecab-0.996-ko-0.9.2/doc/doxygen/namespaceMeCab.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__path__t.html
# mecab-0.996-ko-0.9.2/doc/doxygen/files.html
# mecab-0.996-ko-0.9.2/doc/doxygen/structmecab__node__t-members.html
# mecab-0.996-ko-0.9.2/doc/doxygen/index.html
# mecab-0.996-ko-0.9.2/doc/doxygen/annotated.html
# mecab-0.996-ko-0.9.2/doc/doxygen/globals_defs.html
# mecab-0.996-ko-0.9.2/doc/doxygen/classes.html
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h-source.html
# mecab-0.996-ko-0.9.2/doc/doxygen/doxygen.png
# mecab-0.996-ko-0.9.2/doc/doxygen/tab_b.gif
# mecab-0.996-ko-0.9.2/doc/doxygen/bc_s.png
# mecab-0.996-ko-0.9.2/doc/doxygen/open.png
# mecab-0.996-ko-0.9.2/doc/doxygen/mecab_8h.html
# mecab-0.996-ko-0.9.2/doc/dic.html
# mecab-0.996-ko-0.9.2/doc/partial.html
# mecab-0.996-ko-0.9.2/doc/feature.png
# mecab-0.996-ko-0.9.2/doc/Makefile.in
# mecab-0.996-ko-0.9.2/missing
# mecab-0.996-ko-0.9.2/BSD
# mecab-0.996-ko-0.9.2/NEWS
# mecab-0.996-ko-0.9.2/mkinstalldirs
# mecab-0.996-ko-0.9.2/src/
# mecab-0.996-ko-0.9.2/src/dictionary.h
# mecab-0.996-ko-0.9.2/src/writer.h
# mecab-0.996-ko-0.9.2/src/utils.h
# mecab-0.996-ko-0.9.2/src/string_buffer.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.cpp
# mecab-0.996-ko-0.9.2/src/make.bat
# mecab-0.996-ko-0.9.2/src/mecab.h
# mecab-0.996-ko-0.9.2/src/freelist.h
# mecab-0.996-ko-0.9.2/src/string_buffer.h
# mecab-0.996-ko-0.9.2/src/learner_tagger.h
# mecab-0.996-ko-0.9.2/src/dictionary_compiler.cpp
# mecab-0.996-ko-0.9.2/src/eval.cpp
# mecab-0.996-ko-0.9.2/src/mecab-system-eval.cpp
# mecab-0.996-ko-0.9.2/src/darts.h
# mecab-0.996-ko-0.9.2/src/param.h
# mecab-0.996-ko-0.9.2/src/char_property.h
# mecab-0.996-ko-0.9.2/src/learner_node.h
# mecab-0.996-ko-0.9.2/src/mecab-dict-gen.cpp
# mecab-0.996-ko-0.9.2/src/mecab-dict-index.cpp
# mecab-0.996-ko-0.9.2/src/winmain.h
# mecab-0.996-ko-0.9.2/src/thread.h
# mecab-0.996-ko-0.9.2/src/context_id.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.am
# mecab-0.996-ko-0.9.2/src/connector.h
# mecab-0.996-ko-0.9.2/src/common.h
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.msvc.in
# mecab-0.996-ko-0.9.2/src/dictionary_rewriter.h
# mecab-0.996-ko-0.9.2/src/feature_index.h
# mecab-0.996-ko-0.9.2/src/iconv_utils.cpp
# mecab-0.996-ko-0.9.2/src/char_property.cpp
# mecab-0.996-ko-0.9.2/src/mecab-test-gen.cpp
# mecab-0.996-ko-0.9.2/src/tagger.cpp
# mecab-0.996-ko-0.9.2/src/mecab-cost-train.cpp
# mecab-0.996-ko-0.9.2/src/learner.cpp
# mecab-0.996-ko-0.9.2/src/dictionary.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.cpp
# mecab-0.996-ko-0.9.2/src/ucs.h
# mecab-0.996-ko-0.9.2/src/writer.cpp
# mecab-0.996-ko-0.9.2/src/learner_tagger.cpp
# mecab-0.996-ko-0.9.2/src/lbfgs.h
# mecab-0.996-ko-0.9.2/src/libmecab.cpp
# mecab-0.996-ko-0.9.2/src/tokenizer.h
# mecab-0.996-ko-0.9.2/src/mecab.cpp
# mecab-0.996-ko-0.9.2/src/utils.cpp
# mecab-0.996-ko-0.9.2/src/dictionary_generator.cpp
# mecab-0.996-ko-0.9.2/src/param.cpp
# mecab-0.996-ko-0.9.2/src/context_id.h
# mecab-0.996-ko-0.9.2/src/mmap.h
# mecab-0.996-ko-0.9.2/src/viterbi.h
# mecab-0.996-ko-0.9.2/src/viterbi.cpp
# mecab-0.996-ko-0.9.2/src/stream_wrapper.h
# mecab-0.996-ko-0.9.2/src/feature_index.cpp
# mecab-0.996-ko-0.9.2/src/nbest_generator.h
# mecab-0.996-ko-0.9.2/src/ucstable.h
# mecab-0.996-ko-0.9.2/src/nbest_generator.cpp
# mecab-0.996-ko-0.9.2/src/iconv_utils.h
# mecab-0.996-ko-0.9.2/src/connector.cpp
# mecab-0.996-ko-0.9.2/src/Makefile.in
# mecab-0.996-ko-0.9.2/src/scoped_ptr.h
# mecab-0.996-ko-0.9.2/Makefile.in
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... none
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... none
# checking how to run the C preprocessor... gcc -E
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking whether gcc needs -traditional... no
# checking whether make sets $(MAKE)... (cached) yes
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking how to print strings... printf
# checking for a sed that does not truncate output... /bin/sed
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking whether the shell understands some XSI constructs... yes
# checking whether the shell understands "+="... yes
# checking how to convert x86_64-unknown-linux-gnu file names to x86_64-unknown-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-unknown-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... dlltool
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# ./configure: line 7378: /usr/bin/file: No such file or directory
# checking for mt... no
# checking if : is a manifest tool... no
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... g++ -E
# checking for ld used by g++... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC -DPIC
# checking if g++ PIC flag -fPIC -DPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking if g++ supports -c -o file.o... (cached) yes
# checking whether the g++ linker (/usr/bin/ld) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for library containing strerror... none required
# checking whether byte ordering is bigendian... no
# checking for ld used by GCC... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for shared library run path origin... done
# checking for iconv... yes
# checking for working iconv... yes
# checking for iconv declaration...
#          extern size_t iconv (iconv_t cd, char * *inbuf, size_t *inbytesleft, char * *outbuf, size_t *outbytesleft);
# checking for ANSI C header files... (cached) yes
# checking for an ANSI C-conforming const... yes
# checking whether byte ordering is bigendian... (cached) no
# checking for string.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking for stdint.h... (cached) yes
# checking for sys/stat.h... (cached) yes
# checking sys/mman.h usability... yes
# checking sys/mman.h presence... yes
# checking for sys/mman.h... yes
# checking sys/times.h usability... yes
# checking sys/times.h presence... yes
# checking for sys/times.h... yes
# checking for sys/types.h... (cached) yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking ctype.h usability... yes
# checking ctype.h presence... yes
# checking for ctype.h... yes
# checking for sys/types.h... (cached) yes
# checking io.h usability... no
# checking io.h presence... no
# checking for io.h... no
# checking windows.h usability... no
# checking windows.h presence... no
# checking for windows.h... no
# checking pthread.h usability... yes
# checking pthread.h presence... yes
# checking for pthread.h... yes
# checking for off_t... yes
# checking for size_t... yes
# checking size of char... 1
# checking size of short... 2
# checking size of int... 4
# checking size of long... 8
# checking size of long long... 8
# checking size of size_t... 8
# checking for size_t... (cached) yes
# checking for unsigned long long int... yes
# checking for stdlib.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for sys/param.h... yes
# checking for getpagesize... yes
# checking for working mmap... yes
# checking for main in -lstdc++... yes
# checking for pthread_create in -lpthread... yes
# checking for pthread_join in -lpthread... yes
# checking for getenv... yes
# checking for opendir... yes
# checking whether make is GNU Make... yes
# checking if g++ supports stl <vector> (required)... yes
# checking if g++ supports stl <list> (required)... yes
# checking if g++ supports stl <map> (required)... yes
# checking if g++ supports stl <set> (required)... yes
# checking if g++ supports stl <queue> (required)... yes
# checking if g++ supports stl <functional> (required)... yes
# checking if g++ supports stl <algorithm> (required)... yes
# checking if g++ supports stl <string> (required)... yes
# checking if g++ supports stl <iostream> (required)... yes
# checking if g++ supports stl <sstream> (required)... yes
# checking if g++ supports stl <fstream> (required)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports const_cast<> (required)... yes
# checking if g++ supports static_cast<> (required)... yes
# checking if g++ supports reinterpret_cast<> (required)... yes
# checking if g++ supports namespaces (required) ... yes
# checking if g++ supports __thread (optional)... yes
# checking if g++ supports template <class T> (required)... yes
# checking if g++ supports GCC native atomic operations (optional)... yes
# checking if g++ supports OSX native atomic operations (optional)... no
# checking if g++ environment provides all required features... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/Makefile.msvc
# config.status: creating man/Makefile
# config.status: creating doc/Makefile
# config.status: creating tests/Makefile
# config.status: creating swig/version.h
# config.status: creating mecab.iss
# config.status: creating mecab-config
# config.status: creating mecabrc
# config.status: creating config.h
# config.status: executing depfiles commands
# config.status: executing libtool commands
# config.status: executing default commands
# make  all-recursive
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# Making all in src
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o viterbi.lo viterbi.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c viterbi.cpp  -fPIC -DPIC -o .libs/viterbi.o
# In file included from viterbi.cpp:14:0:
# param.h:30:13: warning: 'Target {anonymous}::lexical_cast(Source) [with Target = std::__cxx11::basic_string<char>; Source = std::__cxx11::basic_string<char>]' defined but not used [-Wunused-function]
#  std::string lexical_cast<std::string, std::string>(std::string arg) {
#              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c viterbi.cpp -o viterbi.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o tagger.lo tagger.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tagger.cpp  -fPIC -DPIC -o .libs/tagger.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tagger.cpp -o tagger.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o utils.lo utils.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c utils.cpp  -fPIC -DPIC -o .libs/utils.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c utils.cpp -o utils.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o eval.lo eval.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c eval.cpp  -fPIC -DPIC -o .libs/eval.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c eval.cpp -o eval.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o iconv_utils.lo iconv_utils.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c iconv_utils.cpp  -fPIC -DPIC -o .libs/iconv_utils.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c iconv_utils.cpp -o iconv_utils.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_rewriter.lo dictionary_rewriter.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_rewriter.cpp  -fPIC -DPIC -o .libs/dictionary_rewriter.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_rewriter.cpp -o dictionary_rewriter.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_generator.lo dictionary_generator.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_generator.cpp  -fPIC -DPIC -o .libs/dictionary_generator.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_generator.cpp -o dictionary_generator.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary_compiler.lo dictionary_compiler.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_compiler.cpp  -fPIC -DPIC -o .libs/dictionary_compiler.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary_compiler.cpp -o dictionary_compiler.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o context_id.lo context_id.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c context_id.cpp  -fPIC -DPIC -o .libs/context_id.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c context_id.cpp -o context_id.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o connector.lo connector.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c connector.cpp  -fPIC -DPIC -o .libs/connector.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c connector.cpp -o connector.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o nbest_generator.lo nbest_generator.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c nbest_generator.cpp  -fPIC -DPIC -o .libs/nbest_generator.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c nbest_generator.cpp -o nbest_generator.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o writer.lo writer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c writer.cpp  -fPIC -DPIC -o .libs/writer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c writer.cpp -o writer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o string_buffer.lo string_buffer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c string_buffer.cpp  -fPIC -DPIC -o .libs/string_buffer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c string_buffer.cpp -o string_buffer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o param.lo param.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c param.cpp  -fPIC -DPIC -o .libs/param.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c param.cpp -o param.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o tokenizer.lo tokenizer.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tokenizer.cpp  -fPIC -DPIC -o .libs/tokenizer.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c tokenizer.cpp -o tokenizer.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o char_property.lo char_property.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c char_property.cpp  -fPIC -DPIC -o .libs/char_property.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c char_property.cpp -o char_property.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o dictionary.lo dictionary.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary.cpp  -fPIC -DPIC -o .libs/dictionary.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c dictionary.cpp -o dictionary.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o feature_index.lo feature_index.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c feature_index.cpp  -fPIC -DPIC -o .libs/feature_index.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c feature_index.cpp -o feature_index.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o lbfgs.lo lbfgs.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c lbfgs.cpp  -fPIC -DPIC -o .libs/lbfgs.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c lbfgs.cpp -o lbfgs.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o learner_tagger.lo learner_tagger.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner_tagger.cpp  -fPIC -DPIC -o .libs/learner_tagger.o
# learner_tagger.cpp:25:7: warning: 'char* MeCab::{anonymous}::mystrdup(const string&)' defined but not used [-Wunused-function]
#  char *mystrdup(const std::string &str) {
#        ^~~~~~~~
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner_tagger.cpp -o learner_tagger.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o learner.lo learner.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner.cpp  -fPIC -DPIC -o .libs/learner.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c learner.cpp -o learner.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=compile g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o libmecab.lo libmecab.cpp
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c libmecab.cpp  -fPIC -DPIC -o .libs/libmecab.o
# libtool: compile:  g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102 -DMECAB_DEFAULT_RC=\"/usr/local/etc/mecabrc\" -O3 -Wall -c libmecab.cpp -o libmecab.o >/dev/null 2>&1
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall  -no-undefined -version-info 2:0:0  -o libmecab.la -rpath /usr/local/lib viterbi.lo tagger.lo utils.lo eval.lo iconv_utils.lo dictionary_rewriter.lo dictionary_generator.lo dictionary_compiler.lo context_id.lo connector.lo nbest_generator.lo writer.lo string_buffer.lo param.lo tokenizer.lo char_property.lo dictionary.lo feature_index.lo lbfgs.lo learner_tagger.lo learner.lo libmecab.lo  -lpthread -lpthread  -lstdc++
# libtool: link: g++  -fPIC -DPIC -shared -nostdlib /usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu/crti.o /usr/lib/gcc/x86_64-linux-gnu/7/crtbeginS.o  .libs/viterbi.o .libs/tagger.o .libs/utils.o .libs/eval.o .libs/iconv_utils.o .libs/dictionary_rewriter.o .libs/dictionary_generator.o .libs/dictionary_compiler.o .libs/context_id.o .libs/connector.o .libs/nbest_generator.o .libs/writer.o .libs/string_buffer.o .libs/param.o .libs/tokenizer.o .libs/char_property.o .libs/dictionary.o .libs/feature_index.o .libs/lbfgs.o .libs/learner_tagger.o .libs/learner.o .libs/libmecab.o   -lpthread -L/usr/lib/gcc/x86_64-linux-gnu/7 -L/usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu -L/usr/lib/gcc/x86_64-linux-gnu/7/../../../../lib -L/lib/x86_64-linux-gnu -L/lib/../lib -L/usr/lib/x86_64-linux-gnu -L/usr/lib/../lib -L/usr/local/cuda/lib64/stubs -L/usr/lib/gcc/x86_64-linux-gnu/7/../../.. -lstdc++ -lm -lc -lgcc_s /usr/lib/gcc/x86_64-linux-gnu/7/crtendS.o /usr/lib/gcc/x86_64-linux-gnu/7/../../../x86_64-linux-gnu/crtn.o  -O3   -Wl,-soname -Wl,libmecab.so.2 -o .libs/libmecab.so.2.0.0
# libtool: link: (cd ".libs" && rm -f "libmecab.so.2" && ln -s "libmecab.so.2.0.0" "libmecab.so.2")
# libtool: link: (cd ".libs" && rm -f "libmecab.so" && ln -s "libmecab.so.2.0.0" "libmecab.so")
# libtool: link: ar cru .libs/libmecab.a  viterbi.o tagger.o utils.o eval.o iconv_utils.o dictionary_rewriter.o dictionary_generator.o dictionary_compiler.o context_id.o connector.o nbest_generator.o writer.o string_buffer.o param.o tokenizer.o char_property.o dictionary.o feature_index.o lbfgs.o learner_tagger.o learner.o libmecab.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libmecab.a
# libtool: link: ( cd ".libs" && rm -f "libmecab.la" && ln -s "../libmecab.la" "libmecab.la" )
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab.o mecab.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab mecab.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab mecab.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-dict-index.o mecab-dict-index.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-dict-index mecab-dict-index.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-dict-index mecab-dict-index.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-dict-gen.o mecab-dict-gen.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-dict-gen mecab-dict-gen.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-dict-gen mecab-dict-gen.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-cost-train.o mecab-cost-train.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-cost-train mecab-cost-train.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-cost-train mecab-cost-train.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-system-eval.o mecab-system-eval.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-system-eval mecab-system-eval.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-system-eval mecab-system-eval.o  ./.libs/libmecab.so -lpthread -lstdc++
# g++ -DHAVE_CONFIG_H -I. -I.. -DDIC_VERSION=102   -DMECAB_DEFAULT_RC="\"/usr/local/etc/mecabrc\""    -O3 -Wall  -c -o mecab-test-gen.o mecab-test-gen.cpp
# /bin/bash ../libtool --tag=CXX   --mode=link g++  -O3 -Wall    -o mecab-test-gen mecab-test-gen.o libmecab.la -lpthread -lpthread  -lstdc++
# libtool: link: g++ -O3 -Wall -o .libs/mecab-test-gen mecab-test-gen.o  ./.libs/libmecab.so -lpthread -lstdc++
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making all in man
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making all in doc
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making all in tests
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making check in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making check in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making check in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Nothing to be done for 'check'.
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making check in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make  check-TESTS
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 177
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 178x178
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 83
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 84x84
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 450
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 162
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3x3
# emitting matrix      : 100% |###########################################|
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 4
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 11
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# ./pos-id.def is not found. minimum setting is used
# reading ./unk.def ... 2
# emitting double-array: 100% |###########################################|
# ./model.def is not found. skipped.
# ./pos-id.def is not found. minimum setting is used
# reading ./dic.csv ... 1
# reading ./matrix.def ... 1x1
#
# done!
# PASS: run-dics.sh
# PASS: run-eval.sh
# seed/pos-id.def is not found. minimum setting is used
# reading seed/unk.def ... 40
# emitting double-array: 100% |###########################################|
# seed/model.def is not found. skipped.
# seed/pos-id.def is not found. minimum setting is used
# reading seed/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading seed/matrix.def ... 1x1
#
# done!
# reading corpus ...
# Number of sentences: 34
# Number of features:  64108
# eta:                 0.00005
# freq:                1
# eval-size:           6
# unk-eval-size:       4
# threads:             1
# charset:             EUC-JP
# C(sigma^2):          1.00000
#
# iter=0 err=1.00000 F=0.35771 target=2406.28355 diff=1.00000
# iter=1 err=0.97059 F=0.65652 target=1484.25231 diff=0.38318
# iter=2 err=0.91176 F=0.79331 target=863.32765 diff=0.41834
# iter=3 err=0.85294 F=0.89213 target=596.72480 diff=0.30881
# iter=4 err=0.61765 F=0.95467 target=336.30744 diff=0.43641
# iter=5 err=0.50000 F=0.96702 target=246.53039 diff=0.26695
# iter=6 err=0.35294 F=0.95472 target=188.93963 diff=0.23361
# iter=7 err=0.20588 F=0.99106 target=168.62665 diff=0.10751
# iter=8 err=0.05882 F=0.99777 target=158.64865 diff=0.05917
# iter=9 err=0.08824 F=0.99665 target=154.14530 diff=0.02839
# iter=10 err=0.08824 F=0.99665 target=151.94257 diff=0.01429
# iter=11 err=0.02941 F=0.99888 target=147.20825 diff=0.03116
# iter=12 err=0.00000 F=1.00000 target=147.34956 diff=0.00096
# iter=13 err=0.02941 F=0.99888 target=146.32592 diff=0.00695
# iter=14 err=0.00000 F=1.00000 target=145.77299 diff=0.00378
# iter=15 err=0.02941 F=0.99888 target=145.24641 diff=0.00361
# iter=16 err=0.00000 F=1.00000 target=144.96490 diff=0.00194
# iter=17 err=0.02941 F=0.99888 target=144.90246 diff=0.00043
# iter=18 err=0.00000 F=1.00000 target=144.75959 diff=0.00099
# iter=19 err=0.00000 F=1.00000 target=144.71727 diff=0.00029
# iter=20 err=0.00000 F=1.00000 target=144.66337 diff=0.00037
# iter=21 err=0.00000 F=1.00000 target=144.61349 diff=0.00034
# iter=22 err=0.00000 F=1.00000 target=144.62987 diff=0.00011
# iter=23 err=0.00000 F=1.00000 target=144.60060 diff=0.00020
# iter=24 err=0.00000 F=1.00000 target=144.59125 diff=0.00006
# iter=25 err=0.00000 F=1.00000 target=144.58619 diff=0.00004
# iter=26 err=0.00000 F=1.00000 target=144.58219 diff=0.00003
# iter=27 err=0.00000 F=1.00000 target=144.58059 diff=0.00001
#
# Done! writing model file ...
# model-ipadic.c1.0.f1.model is not a binary model. reopen it as text mode...
# reading seed/unk.def ... 40
# reading seed/dic.csv ... 4335
# emitting model-ipadic.c1.0.f1.dic/left-id.def/ model-ipadic.c1.0.f1.dic/right-id.def
# emitting model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting matrix      : 100% |###########################################|
# copying seed/char.def to model-ipadic.c1.0.f1.dic/char.def
# copying seed/rewrite.def to model-ipadic.c1.0.f1.dic/rewrite.def
# copying seed/dicrc to model-ipadic.c1.0.f1.dic/dicrc
# copying seed/feature.def to model-ipadic.c1.0.f1.dic/feature.def
# copying model-ipadic.c1.0.f1.model to model-ipadic.c1.0.f1.dic/model.def
#
# done!
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# model-ipadic.c1.0.f1.dic/pos-id.def is not found. minimum setting is used
# reading model-ipadic.c1.0.f1.dic/dic.csv ... 4335
# emitting double-array: 100% |###########################################|
# reading model-ipadic.c1.0.f1.dic/matrix.def ... 346x346
# emitting matrix      : 100% |###########################################|
#
# done!
#               precision          recall         F
# LEVEL 0:    12.8959(57/442) 11.8998(57/479) 12.3779
# LEVEL 1:    12.2172(54/442) 11.2735(54/479) 11.7264
# LEVEL 2:    11.7647(52/442) 10.8559(52/479) 11.2921
# LEVEL 4:    11.7647(52/442) 10.8559(52/479) 11.2921
# PASS: run-cost-train.sh
# ==================
# All 3 tests passed
# ==================
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# Making install in src
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/src'
# test -z "/usr/local/lib" || /bin/mkdir -p "/usr/local/lib"
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libmecab.la '/usr/local/lib'
# libtool: install: /usr/bin/install -c .libs/libmecab.so.2.0.0 /usr/local/lib/libmecab.so.2.0.0
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so.2 || { rm -f libmecab.so.2 && ln -s libmecab.so.2.0.0 libmecab.so.2; }; })
# libtool: install: (cd /usr/local/lib && { ln -s -f libmecab.so.2.0.0 libmecab.so || { rm -f libmecab.so && ln -s libmecab.so.2.0.0 libmecab.so; }; })
# libtool: install: /usr/bin/install -c .libs/libmecab.lai /usr/local/lib/libmecab.la
# libtool: install: /usr/bin/install -c .libs/libmecab.a /usr/local/lib/libmecab.a
# libtool: install: chmod 644 /usr/local/lib/libmecab.a
# libtool: install: ranlib /usr/local/lib/libmecab.a
# libtool: finish: PATH="/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/sbin" ldconfig -n /usr/local/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /usr/local/lib
#
# ...
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# test -z "/usr/local/bin" || /bin/mkdir -p "/usr/local/bin"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab '/usr/local/bin'
# libtool: install: /usr/bin/install -c .libs/mecab /usr/local/bin/mecab
# test -z "/usr/local/libexec/mecab" || /bin/mkdir -p "/usr/local/libexec/mecab"
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c mecab-dict-index mecab-dict-gen mecab-cost-train mecab-system-eval mecab-test-gen '/usr/local/libexec/mecab'
# libtool: install: /usr/bin/install -c .libs/mecab-dict-index /usr/local/libexec/mecab/mecab-dict-index
# libtool: install: /usr/bin/install -c .libs/mecab-dict-gen /usr/local/libexec/mecab/mecab-dict-gen
# libtool: install: /usr/bin/install -c .libs/mecab-cost-train /usr/local/libexec/mecab/mecab-cost-train
# libtool: install: /usr/bin/install -c .libs/mecab-system-eval /usr/local/libexec/mecab/mecab-system-eval
# libtool: install: /usr/bin/install -c .libs/mecab-test-gen /usr/local/libexec/mecab/mecab-test-gen
# test -z "/usr/local/include" || /bin/mkdir -p "/usr/local/include"
#  /usr/bin/install -c -m 644 mecab.h '/usr/local/include'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/src'
# Making install in man
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[2]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/local/share/man/man1" || /bin/mkdir -p "/usr/local/share/man/man1"
#  /usr/bin/install -c -m 644 mecab.1 '/usr/local/share/man/man1'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/man'
# Making install in doc
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/doc'
# Making install in tests
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[2]: Nothing to be done for 'install-exec-am'.
# make[2]: Nothing to be done for 'install-data-am'.
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2/tests'
# make[1]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# make[2]: Entering directory '/tmp/mecab-0.996-ko-0.9.2'
# test -z "/usr/local/bin" || /bin/mkdir -p "/usr/local/bin"
#  /usr/bin/install -c mecab-config '/usr/local/bin'
# test -z "/usr/local/etc" || /bin/mkdir -p "/usr/local/etc"
#  /usr/bin/install -c -m 644 mecabrc '/usr/local/etc'
# make[2]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# make[1]: Leaving directory '/tmp/mecab-0.996-ko-0.9.2'
# --2022-08-16 12:26:35--  https://www.dropbox.com/s/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz [following]
# --2022-08-16 12:26:35--  https://www.dropbox.com/s/dl/i8girnk5p80076c/mecab-ko-dic-2.1.1-20180720.tar.gz
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com/cd/0/get/BrHmyWT7q_XgypSHN_NZLjvq9HAerTwqj6druH49Iy2jn_ZOgTqnFtFrjzmt2SlFbur6y_FVPaAYdQlaWs27fTSVGnShGgIgCbpXyEAspAWkBTmD1CpaR_2gQ_t-2hicxP-s056Z8y4q5ArHEKx7e9c4AwXix2wSJVjMtLPEIZD7G9mNiwLz2VGkE3viuzkhmjU/file?dl=1# [following]
# --2022-08-16 12:26:35--  https://ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com/cd/0/get/BrHmyWT7q_XgypSHN_NZLjvq9HAerTwqj6druH49Iy2jn_ZOgTqnFtFrjzmt2SlFbur6y_FVPaAYdQlaWs27fTSVGnShGgIgCbpXyEAspAWkBTmD1CpaR_2gQ_t-2hicxP-s056Z8y4q5ArHEKx7e9c4AwXix2wSJVjMtLPEIZD7G9mNiwLz2VGkE3viuzkhmjU/file?dl=1
# Resolving ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com (ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com (ucda3fa4a529ec0e2820bb25af0e.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/binary]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  89.3MB/s    in 0.5s
#
# 2022-08-16 12:26:36 (89.3 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz?dl=1’ saved [49775061/49775061]
#
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   automake autotools-dev libsigsegv2 m4
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc libtool gettext m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev libsigsegv2 m4
# 0 upgraded, 5 newly installed, 0 to remove and 19 not upgraded.
# Need to get 1,082 kB of archives.
# After this operation, 3,994 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Fetched 1,082 kB in 1s (929 kB/s)
# Selecting previously unselected package libsigsegv2:amd64.
# (Reading database ... 155680 files and directories currently installed.)
# Preparing to unpack .../libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../archives/m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up autoconf (2.69-11) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# mecab-ko-dic-2.1.1-20180720/
# mecab-ko-dic-2.1.1-20180720/configure
# mecab-ko-dic-2.1.1-20180720/COPYING
# mecab-ko-dic-2.1.1-20180720/autogen.sh
# mecab-ko-dic-2.1.1-20180720/Place-station.csv
# mecab-ko-dic-2.1.1-20180720/NNG.csv
# mecab-ko-dic-2.1.1-20180720/README
# mecab-ko-dic-2.1.1-20180720/EF.csv
# mecab-ko-dic-2.1.1-20180720/MAG.csv
# mecab-ko-dic-2.1.1-20180720/Preanalysis.csv
# mecab-ko-dic-2.1.1-20180720/NNB.csv
# mecab-ko-dic-2.1.1-20180720/Person-actor.csv
# mecab-ko-dic-2.1.1-20180720/VV.csv
# mecab-ko-dic-2.1.1-20180720/Makefile.in
# mecab-ko-dic-2.1.1-20180720/matrix.def
# mecab-ko-dic-2.1.1-20180720/EC.csv
# mecab-ko-dic-2.1.1-20180720/NNBC.csv
# mecab-ko-dic-2.1.1-20180720/clean
# mecab-ko-dic-2.1.1-20180720/ChangeLog
# mecab-ko-dic-2.1.1-20180720/J.csv
# mecab-ko-dic-2.1.1-20180720/.keep
# mecab-ko-dic-2.1.1-20180720/feature.def
# mecab-ko-dic-2.1.1-20180720/Foreign.csv
# mecab-ko-dic-2.1.1-20180720/XPN.csv
# mecab-ko-dic-2.1.1-20180720/EP.csv
# mecab-ko-dic-2.1.1-20180720/NR.csv
# mecab-ko-dic-2.1.1-20180720/left-id.def
# mecab-ko-dic-2.1.1-20180720/Place.csv
# mecab-ko-dic-2.1.1-20180720/Symbol.csv
# mecab-ko-dic-2.1.1-20180720/dicrc
# mecab-ko-dic-2.1.1-20180720/NP.csv
# mecab-ko-dic-2.1.1-20180720/ETM.csv
# mecab-ko-dic-2.1.1-20180720/IC.csv
# mecab-ko-dic-2.1.1-20180720/Place-address.csv
# mecab-ko-dic-2.1.1-20180720/Group.csv
# mecab-ko-dic-2.1.1-20180720/model.def
# mecab-ko-dic-2.1.1-20180720/XSN.csv
# mecab-ko-dic-2.1.1-20180720/INSTALL
# mecab-ko-dic-2.1.1-20180720/rewrite.def
# mecab-ko-dic-2.1.1-20180720/Inflect.csv
# mecab-ko-dic-2.1.1-20180720/configure.ac
# mecab-ko-dic-2.1.1-20180720/NNP.csv
# mecab-ko-dic-2.1.1-20180720/CoinedWord.csv
# mecab-ko-dic-2.1.1-20180720/XSV.csv
# mecab-ko-dic-2.1.1-20180720/pos-id.def
# mecab-ko-dic-2.1.1-20180720/Makefile.am
# mecab-ko-dic-2.1.1-20180720/unk.def
# mecab-ko-dic-2.1.1-20180720/missing
# mecab-ko-dic-2.1.1-20180720/VCP.csv
# mecab-ko-dic-2.1.1-20180720/install-sh
# mecab-ko-dic-2.1.1-20180720/Hanja.csv
# mecab-ko-dic-2.1.1-20180720/MAJ.csv
# mecab-ko-dic-2.1.1-20180720/XSA.csv
# mecab-ko-dic-2.1.1-20180720/Wikipedia.csv
# mecab-ko-dic-2.1.1-20180720/tools/
# mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# mecab-ko-dic-2.1.1-20180720/tools/mecab-bestn.sh
# mecab-ko-dic-2.1.1-20180720/tools/convert_for_using_store.sh
# mecab-ko-dic-2.1.1-20180720/user-dic/
# mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/place.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/person.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/README.md
# mecab-ko-dic-2.1.1-20180720/NorthKorea.csv
# mecab-ko-dic-2.1.1-20180720/VX.csv
# mecab-ko-dic-2.1.1-20180720/right-id.def
# mecab-ko-dic-2.1.1-20180720/VA.csv
# mecab-ko-dic-2.1.1-20180720/char.def
# mecab-ko-dic-2.1.1-20180720/NEWS
# mecab-ko-dic-2.1.1-20180720/MM.csv
# mecab-ko-dic-2.1.1-20180720/ETN.csv
# mecab-ko-dic-2.1.1-20180720/AUTHORS
# mecab-ko-dic-2.1.1-20180720/Person.csv
# mecab-ko-dic-2.1.1-20180720/XR.csv
# mecab-ko-dic-2.1.1-20180720/VCN.csv
# Looking in current directory for macros.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:2: http://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /tmp/mecab-ko-dic-2.1.1-20180720/missing: Unknown `--is-lightweight' option
# Try `/tmp/mecab-ko-dic-2.1.1-20180720/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for mecab-config... /usr/local/bin/mecab-config
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./J.csv ... 416
# reading ./NNP.csv ... 2371
# reading ./EF.csv ... 1820
# reading ./Preanalysis.csv ... 5
# reading ./EP.csv ... 51
# reading ./NNG.csv ... 208524
# reading ./NorthKorea.csv ... 3
# reading ./Person-actor.csv ... 99230
# reading ./ETN.csv ... 14
# reading ./XSV.csv ... 23
# reading ./EC.csv ... 2547
# reading ./XR.csv ... 3637
# reading ./NR.csv ... 482
# reading ./Inflect.csv ... 44820
# reading ./NNBC.csv ... 677
# reading ./NP.csv ... 342
# reading ./VCN.csv ... 7
# reading ./Person.csv ... 196459
# reading ./Group.csv ... 3176
# reading ./MM.csv ... 453
# reading ./Foreign.csv ... 11690
# reading ./MAJ.csv ... 240
# reading ./Symbol.csv ... 16
# reading ./XSN.csv ... 124
# reading ./VX.csv ... 125
# reading ./Place.csv ... 30303
# reading ./ETM.csv ... 133
# reading ./Hanja.csv ... 125750
# reading ./MAG.csv ... 14242
# reading ./VA.csv ... 2360
# reading ./VCP.csv ... 9
# reading ./VV.csv ... 7331
# reading ./Wikipedia.csv ... 36762
# reading ./IC.csv ... 1305
# reading ./CoinedWord.csv ... 148
# reading ./NNB.csv ... 140
# reading ./Place-station.csv ... 1145
# reading ./XSA.csv ... 19
# reading ./Place-address.csv ... 19301
# reading ./XPN.csv ... 83
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"
# make[1]: Entering directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/tmp/mecab-ko-dic-2.1.1-20180720'
# Cloning into 'mecab-python-0.996'...
# Unpacking objects: 100% (17/17), done.
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# copying MeCab.py -> build/lib.linux-x86_64-3.7
# running build_ext
# building '_MeCab' extension
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/include -I/usr/include/python3.7m -c MeCab_wrap.cxx -o build/temp.linux-x86_64-3.7/MeCab_wrap.o
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/MeCab_wrap.o -L/usr/local/lib -lmecab -lstdc++ -o build/lib.linux-x86_64-3.7/_MeCab.cpython-37m-x86_64-linux-gnu.so
# running install
# running build
# running build_py
# running build_ext
# running install_lib
# copying build/lib.linux-x86_64-3.7/_MeCab.cpython-37m-x86_64-linux-gnu.so -> /usr/local/lib/python3.7/dist-packages
# copying build/lib.linux-x86_64-3.7/MeCab.py -> /usr/local/lib/python3.7/dist-packages
# byte-compiling /usr/local/lib/python3.7/dist-packages/MeCab.py to MeCab.cpython-37.pyc
# running install_egg_info
# Writing /usr/local/lib/python3.7/dist-packages/mecab_python-0.996_ko_0.9.2.egg-info
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 68 kB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 54.9 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %%
import pandas as pd
import numpy as np
mecab_text = pd.read_csv('/content/데이터수집본(중복없음) (1).csv')

# %%
mecab_text
# Out:
#      Unnamed: 0  Unnamed: 0.1                   ID  \
# 0             0             0  1556991811700240384
# 1             1             1  1556991703256821761
# 2             2             2  1556991657337552896
# 3             3             3  1556991610772402176
# 4             4             4  1556991592782737410
# ..          ...           ...                  ...
# 824       95409          1434  1557307563116740610
# 825       95411          1436  1557307562512375810
# 826       95412          1437  1557307561245904896
# 827       95413          1438  1557307558905294850
# 828       95414          1439  1557307556913025024
#
#                                                   Text  \
# 0    서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 1    RT @anna12285: @babylion0505 @free351 지겹게 이어지던...
# 2    RT @envsha: 이번주 뉴스만 해도\n- 파키스탄 지난 5주간 폭우로 282명...
# 3    RT @c2bwsjuhmEW3tbX: 이상 이천화재로 사람죽어갈때 경기도지사랑 떡볶...
# 4    RT @ulttung: 재난에 닥치니 진짜 문재인대통령, 이낙연 총리님시절이 그리워...
# ..                                                 ...
# 824  RT @serii812: #RT #FOLLOW\n초코에몽 부자돼서 이벤트 열어봐요 ...
# 825  ...진실을 밝혀 주셔서, 본인의 죄를 뒤집어쓰고 죽는 이가 없게 해 주셔서 진심으...
# 826  RT @GoldenChild: [💡] #골드니스 여러분!\n지금 바로 네이버 '#V...
# 827          RT @spring_is_428: 성규랑 동시대를 살고있어서 너무 다행이다
# 828  220810 사찬 자14\n천사님 덕분에 꽃숮 드디어 첫 직관ㅠㅠ https://t...
#
#                           Date       Key  duplicates
# 0          2022-08-09 13:12:30  산불 or 화재         360
# 1          2022-08-09 13:12:04  산불 or 화재         360
# 2          2022-08-09 13:11:53  산불 or 화재         360
# 3          2022-08-09 13:11:42  산불 or 화재        1614
# 4          2022-08-09 13:11:37  산불 or 화재         638
# ..                         ...       ...         ...
# 824  2022-08-10 10:07:11+00:00        기타           4
# 825  2022-08-10 10:07:10+00:00        기타           4
# 826  2022-08-10 10:07:10+00:00        기타           4
# 827  2022-08-10 10:07:10+00:00        기타           4
# 828  2022-08-10 10:07:09+00:00        기타           4
#
# [829 rows x 7 columns]

# %%
mecab_text= mecab_text[['Text']]

# %%
mecab_text
# Out:
#                                                   Text
# 0    서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 1    RT @anna12285: @babylion0505 @free351 지겹게 이어지던...
# 2    RT @envsha: 이번주 뉴스만 해도\n- 파키스탄 지난 5주간 폭우로 282명...
# 3    RT @c2bwsjuhmEW3tbX: 이상 이천화재로 사람죽어갈때 경기도지사랑 떡볶...
# 4    RT @ulttung: 재난에 닥치니 진짜 문재인대통령, 이낙연 총리님시절이 그리워...
# ..                                                 ...
# 824  RT @serii812: #RT #FOLLOW\n초코에몽 부자돼서 이벤트 열어봐요 ...
# 825  ...진실을 밝혀 주셔서, 본인의 죄를 뒤집어쓰고 죽는 이가 없게 해 주셔서 진심으...
# 826  RT @GoldenChild: [💡] #골드니스 여러분!\n지금 바로 네이버 '#V...
# 827          RT @spring_is_428: 성규랑 동시대를 살고있어서 너무 다행이다
# 828  220810 사찬 자14\n천사님 덕분에 꽃숮 드디어 첫 직관ㅠㅠ https://t...
#
# [829 rows x 1 columns]

# %%
# '한글'을 제외한 다른 문자 모두 제거
import re  
remove_except_ko = re.compile(r"[^가-힣ㄱ-ㅎㅏ-ㅣ\\s]") 
def preprocess(text):
    text = re.sub(remove_except_ko,' ',text).strip()
    return text 
mecab_text['Text'] = mecab_text['Text'].map(lambda x : preprocess(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
mecab_text
# Out:
#                                                   Text
# 0    서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 1                               지겹게 이어지던 산불  기억속에 가득하다
# 2    s    이번주 뉴스만 해도   파키스탄 지난  주간 폭우로    명 사망   미국...
# 3    s            이상 이천화재로 사람죽어갈때 경기도지사랑 떡볶이먹방찍고계셨던...
# 4    재난에 닥치니 진짜 문재인대통령  이낙연 총리님시절이 그리워죽겠음 그때 산불났을 때...
# ..                                                 ...
# 824  s                     초코에몽 부자돼서 이벤트 열어봐요   트친들...
# 825  진실을 밝혀 주셔서  본인의 죄를 뒤집어쓰고 죽는 이가 없게 해 주셔서 진심으로 감...
# 826  골드니스 여러분  지금 바로 네이버       파티룸 에 놀러오세요  아래의 링크로...
# 827              s       s      성규랑 동시대를 살고있어서 너무 다행이다
# 828       사찬 자   천사님 덕분에 꽃숮 드디어 첫 직관ㅠㅠ     s         s
#
# [829 rows x 1 columns]

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)

# %%
from konlpy.tag import Okt
okt=Okt()
# mecab 사용해 토큰화, 한글자 제거, stop_word 제거
stop_word = ['께서','에서','이다','에게','으로','이랑','까지','부터','하다']
stopPos = ['Determiner','Adverb','Conjuctions','Josa','PreEomi','Eomi','Suffix',
          'Punctuation','Foreign','Alpha','Number','Unknown','KoreanParticle']
def token_okt(text):
    text = okt.pos(text)
    text = [i for i in text if len(i[0])>1]
    text = [i for i in text if i[0] not in stop_word]
    text = [i[0] for i in text if i[1] not in stopPos]
    return text

# %%
def make_tokens(df):
    df['tokens'] = ''
    tokens_list=[]
    for i, row in df.iterrows():
        if i%500==0:
            print(i,'/',len(df))
        token = token_okt(df['Text'][i])
        df['tokens'][i] = ' '.join(token)
    return df

mecab_text = make_tokens(mecab_text)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0 / 829
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 500 / 829

# %%
mecab_text
# Out:
#                                                   Text  \
# 0    서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 1                               지겹게 이어지던 산불  기억속에 가득하다
# 2    s    이번주 뉴스만 해도   파키스탄 지난  주간 폭우로    명 사망   미국...
# 3    s            이상 이천화재로 사람죽어갈때 경기도지사랑 떡볶이먹방찍고계셨던...
# 4    재난에 닥치니 진짜 문재인대통령  이낙연 총리님시절이 그리워죽겠음 그때 산불났을 때...
# ..                                                 ...
# 824  s                     초코에몽 부자돼서 이벤트 열어봐요   트친들...
# 825  진실을 밝혀 주셔서  본인의 죄를 뒤집어쓰고 죽는 이가 없게 해 주셔서 진심으로 감...
# 826  골드니스 여러분  지금 바로 네이버       파티룸 에 놀러오세요  아래의 링크로...
# 827              s       s      성규랑 동시대를 살고있어서 너무 다행이다
# 828       사찬 자   천사님 덕분에 꽃숮 드디어 첫 직관ㅠㅠ     s         s
#
#                                                 tokens
# 0    서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 1                                     지겹게 이어지던 산불 가득하다
# 2    이번 뉴스 해도 파키스탄 지난 주간 폭우 사망 미국 켄터키주 폭우 사망 이란 폭우 ...
# 3                   이상 화재 사람 죽어 도지사 떡볶이 먹방 찍고계셨던 말씀 셨습
# 4    재난 닥치니 진짜 문재인 대통령 이낙연 총리 시절 그리워 죽겠음 그때 산불 났을 어...
# ..                                                 ...
# 824                초코 부자 돼서 이벤트 열어 봐요 트친 참여 가능하니깐 받아가요
# 825           진실 밝혀 주셔서 본인 뒤집어 쓰고 죽는 없게 주셔서 진심 감사 드립니다
# 826  골드 니스 여러분 지금 바로 네이버 파티 놀러 오세요 아래 링크 들어와 주세요 어플...
# 827                                     성규 동시 살고있어서 다행
# 828                                     사찬 천사 덕분 꽃숮 직관
#
# [829 rows x 2 columns]

# %%
# 빈칸 찾아내기
mecab_text.replace('', np.nan, inplace=True)
mecab_text.isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Text      0
# tokens    0
# dtype: int64

# %%
#Null 값 없애기
mecab_text=mecab_text.dropna()
mecab_text.isnull().sum()
# Out:
# Text      0
# tokens    0
# dtype: int64

# %%
mecab_text
# Out:
#                                                   Text  \
# 0    서울 되련님들도 뭣같고 오세이돈도 뭣같고 지옥런한 새끼도 뭣같고 산불 안보러간다고 ...
# 1                               지겹게 이어지던 산불  기억속에 가득하다
# 2    s    이번주 뉴스만 해도   파키스탄 지난  주간 폭우로    명 사망   미국...
# 3    s            이상 이천화재로 사람죽어갈때 경기도지사랑 떡볶이먹방찍고계셨던...
# 4    재난에 닥치니 진짜 문재인대통령  이낙연 총리님시절이 그리워죽겠음 그때 산불났을 때...
# ..                                                 ...
# 824  s                     초코에몽 부자돼서 이벤트 열어봐요   트친들...
# 825  진실을 밝혀 주셔서  본인의 죄를 뒤집어쓰고 죽는 이가 없게 해 주셔서 진심으로 감...
# 826  골드니스 여러분  지금 바로 네이버       파티룸 에 놀러오세요  아래의 링크로...
# 827              s       s      성규랑 동시대를 살고있어서 너무 다행이다
# 828       사찬 자   천사님 덕분에 꽃숮 드디어 첫 직관ㅠㅠ     s         s
#
#                                                 tokens
# 0    서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 1                                     지겹게 이어지던 산불 가득하다
# 2    이번 뉴스 해도 파키스탄 지난 주간 폭우 사망 미국 켄터키주 폭우 사망 이란 폭우 ...
# 3                   이상 화재 사람 죽어 도지사 떡볶이 먹방 찍고계셨던 말씀 셨습
# 4    재난 닥치니 진짜 문재인 대통령 이낙연 총리 시절 그리워 죽겠음 그때 산불 났을 어...
# ..                                                 ...
# 824                초코 부자 돼서 이벤트 열어 봐요 트친 참여 가능하니깐 받아가요
# 825           진실 밝혀 주셔서 본인 뒤집어 쓰고 죽는 없게 주셔서 진심 감사 드립니다
# 826  골드 니스 여러분 지금 바로 네이버 파티 놀러 오세요 아래 링크 들어와 주세요 어플...
# 827                                     성규 동시 살고있어서 다행
# 828                                     사찬 천사 덕분 꽃숮 직관
#
# [829 rows x 2 columns]

# %%
mecab1=mecab_text[['tokens']]

# %%
mecab1
# Out:
#                                                 tokens
# 0    서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...
# 1                                     지겹게 이어지던 산불 가득하다
# 2    이번 뉴스 해도 파키스탄 지난 주간 폭우 사망 미국 켄터키주 폭우 사망 이란 폭우 ...
# 3                   이상 화재 사람 죽어 도지사 떡볶이 먹방 찍고계셨던 말씀 셨습
# 4    재난 닥치니 진짜 문재인 대통령 이낙연 총리 시절 그리워 죽겠음 그때 산불 났을 어...
# ..                                                 ...
# 824                초코 부자 돼서 이벤트 열어 봐요 트친 참여 가능하니깐 받아가요
# 825           진실 밝혀 주셔서 본인 뒤집어 쓰고 죽는 없게 주셔서 진심 감사 드립니다
# 826  골드 니스 여러분 지금 바로 네이버 파티 놀러 오세요 아래 링크 들어와 주세요 어플...
# 827                                     성규 동시 살고있어서 다행
# 828                                     사찬 천사 덕분 꽃숮 직관
#
# [829 rows x 1 columns]

# %%
pos_dict = pd.DataFrame(pd.read_csv(r'/content/pos_pol_word_단어추가.txt', sep='\n', quoting=3,header=15))
pos_dict.rename(columns={'극성 : 긍정':'word'},inplace=True)
pos_dict.head()
# Out:
#     word
# 0    멀쩡한
# 1   가득하다
# 2    그리워
# 3  바람직하지
# 4     깔깔

# %%
neg_dict = pd.DataFrame(pd.read_csv(r'/content/neg_pol_word_단어추가.txt', sep='\n', quoting=3,header=14))
neg_dict.rename(columns={'극성 : 부정':'word'},inplace=True)
neg_dict.head()
# Out:
#   word
# 0  지옥런
# 1   새끼
# 2   산불
# 3  버리고
# 4   침수

# %%
bad_dict = pd.DataFrame(pd.read_csv(r'/content/욕설 사전.txt',sep='\n',quoting=3,header=None))
bad_dict.rename(columns={0:'word'},inplace=True)
bad_dict.head()
# Out:
#   word
# 0  뭣같음
# 1   지랄
# 2   개뿔
# 3   슈펄
# 4  디질것

# %%
tone_ls = []
for doc in mecab1['tokens']:
    #print(doc.split())
    #words=[]
    #words.append(doc.split(' '))
    splitdoc = doc.split()
    pos=0
    neg=0
    bad=1
    for word in splitdoc:
        if word in list(pos_dict['word']):
            pos += 1
        if word in list(neg_dict['word']):
            neg += 1
        if word in list(bad_dict['word']):
            bad = 0
    if bad == 0 :
        tone_ls.append(-3)            
    elif (pos+neg)!=0:
        tone = (pos-neg)/(pos+neg)
        if tone >0:
          
          tone_ls.append(1)
        elif (tone <0) & (tone >=-0.5) :
          
          tone_ls.append(-1)
        elif tone< -0.5:
          tone_ls.append(-2)  
        elif tone ==0:
          tone_ls.append(0)
    else:
        tone_ls.append(0)
mecab1['tone']= tone_ls

# %%
mecab1
# Out:
#                                                 tokens  tone
# 0    서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...    -3
# 1                                     지겹게 이어지던 산불 가득하다    -1
# 2    이번 뉴스 해도 파키스탄 지난 주간 폭우 사망 미국 켄터키주 폭우 사망 이란 폭우 ...    -2
# 3                   이상 화재 사람 죽어 도지사 떡볶이 먹방 찍고계셨던 말씀 셨습    -2
# 4    재난 닥치니 진짜 문재인 대통령 이낙연 총리 시절 그리워 죽겠음 그때 산불 났을 어...    -2
# ..                                                 ...   ...
# 824                초코 부자 돼서 이벤트 열어 봐요 트친 참여 가능하니깐 받아가요     1
# 825           진실 밝혀 주셔서 본인 뒤집어 쓰고 죽는 없게 주셔서 진심 감사 드립니다     1
# 826  골드 니스 여러분 지금 바로 네이버 파티 놀러 오세요 아래 링크 들어와 주세요 어플...     0
# 827                                     성규 동시 살고있어서 다행     0
# 828                                     사찬 천사 덕분 꽃숮 직관     1
#
# [829 rows x 2 columns]

# %%
# mecab_text.to_csv('데이터수집본re.csv', encoding="utf8")

# %%
from tqdm import tqdm
from konlpy.tag import Mecab

# %%
# 형태소 분석기 Mecab을 사용하여 토큰화를 진행해보겠습니다.
mecab = Mecab()

# %%
# # output_file에는 총 몇 줄이 있는지 확인합니다.
# f = open('/content/데이터수집본re.csv', encoding="utf8")
# lines = f.read().splitlines()
# print(len(lines))

# %%
# 95,461개의 줄이 존재합니다. 상위 10개만 출력해봅시다.

# %%
# lines[:10]

# %%
result = []

for line in tqdm(mecab1['tokens']):
  # 빈 문자열이 아닌 경우에만 수행
  if line:
    result.append(mecab.morphs(line))
# Out:
# 100%|██████████| 829/829 [00:00<00:00, 6404.89it/s]

# %%
# 빈 문자열은 제외하고 형태소 분석을 진행했습니다. 
# 이제 몇 개의 줄. 즉, 몇 개의 문장이 존재하는지 확인해봅시다.

# %%
len(result)
# Out:
# 829

# %%
# 95,461개로 문장의 수가 줄지 않았습니다.

# %%
result
# Out:
# [['서울',
#   '되',
#   '련',
#   '뭣',
#   '같',
#   '이',
#   '돈',
#   '뭣',
#   '같',
#   '지옥',
#   '런',
#   '새끼',
#   '뭣',
#   '같',
#   '산불',
#   '보',
#   '러',
#   '간다',
#   '했',
#   '으면서',
#   '멀쩡',
#   '한',
#   '컨트롤',
#   '타워',
#   '버리',
#   '고',
#   '침수',
#   '궁',
#   '댕',
#   '뭉개',
#   '있',
#   '던',
#   '새끼',
#   '뭣',
#   '같',
#   '음'],
#  ['지겹', '게', '이어지', '던', '산불', '가득', '하', '다'],
#  ['이번',
#   '뉴스',
#   '해도',
#   '파키스탄',
#   '지난',
#   '주간',
#   '폭우',
#   '사망',
#   '미국',
#   '켄터키주',
#   '폭우',
#   '사망',
#   '이',
#   '란',
#   '폭우',
#   '사망',
#   '미국',
#   '서부',
#   '산불',
#   '계속',
#   '번지',
#   '작년',
#   '도',
#   '를',
#   '찍',
#   '고',
#   '전소',
#   '캐나다',
#   '튼',
#   '시',
#   '올해'],
#  ['이상',
#   '화재',
#   '사람',
#   '죽',
#   '어',
#   '도지사',
#   '떡볶이',
#   '먹방',
#   '찍',
#   '고',
#   '계셨',
#   '던',
#   '말씀',
#   '셨',
#   '습'],
#  ['재난',
#   '닥치',
#   '니',
#   '진짜',
#   '문재',
#   '인',
#   '대통령',
#   '이낙연',
#   '총리',
#   '시절',
#   '그리워',
#   '죽',
#   '겠',
#   '음',
#   '그때',
#   '산불',
#   '났',
#   '을',
#   '어떻',
#   '게',
#   '했',
#   '냐',
#   '다른',
#   '거',
#   '도',
#   '비슷',
#   '함',
#   '총리',
#   '상황',
#   '정리',
#   '브리핑',
#   '노란',
#   '잠바',
#   '입',
#   '고',
#   '앉',
#   '으셔서',
#   '산림청',
#   '소방청',
#   '강원',
#   '도',
#   '있',
#   '는',
#   '관계',
#   '기관',
#   '짚',
#   '으며',
#   '현재'],
#  ['너희',
#   '메시아',
#   '이재명',
#   '대통령',
#   '이',
#   '었',
#   '으면',
#   '달랐',
#   '을까',
#   '재난',
#   '상황',
#   '꼴값',
#   '떨',
#   '었',
#   '던',
#   '이재명',
#   '판교',
#   '풍구',
#   '사고',
#   '이재명',
#   '어떻게',
#   '행동',
#   '했',
#   '나',
#   '알아봐',
#   '쿠팡',
#   '화재',
#   '때문',
#   '소방관',
#   '죽',
#   '어',
#   '했',
#   '는지',
#   '도',
#   '알아보',
#   '고',
#   '코로나'],
#  ['윤석열',
#   '울진',
#   '산불',
#   '재민',
#   '찾',
#   '아',
#   '있',
#   '더라도',
#   '헬기',
#   '타',
#   '고',
#   '와야',
#   '죠',
#   '다음',
#   '뉴스'],
#  ['속초',
#   '산불',
#   '속',
#   '초시',
#   '전날',
#   '제주',
#   '도',
#   '여행',
#   '떠났',
#   '다가',
#   '당일',
#   '비행기',
#   '없',
#   '어',
#   '다음',
#   '비행기',
#   '부랴부랴',
#   '올라온',
#   '바람직',
#   '하',
#   '지',
#   '않',
#   '은',
#   '처신',
#   '비난',
#   '했',
#   '던',
#   '언론',
#   '기억',
#   '그런데',
#   '서울',
#   '복판',
#   '물난리',
#   '기적',
#   '대',
#   '면'],
#  ['윤석열',
#   '폭우',
#   '출근',
#   '비난',
#   '하',
#   '면서',
#   '이재명',
#   '쿠팡',
#   '화재',
#   '먹방',
#   '모른',
#   '이낙연',
#   '산불',
#   '재해',
#   '막',
#   '은',
#   '아프리카',
#   '돼지',
#   '열',
#   '병',
#   '막',
#   '은',
#   '무시'],
#  ['미드',
#   '뉴스룸',
#   '년',
#   '전',
#   '나온',
#   '장면',
#   '지금',
#   '탄소',
#   '예산',
#   '기',
#   '가',
#   '톤',
#   '정도',
#   '남',
#   '았',
#   '고',
#   '대기',
#   '이산화',
#   '탄소',
#   '농도',
#   '여기',
#   '하',
#   '는',
#   '대량',
#   '이민',
#   '산불',
#   '폭풍',
#   '식량난',
#   '식수',
#   '부족',
#   '역병',
#   '같',
#   '은',
#   '포스트',
#   '아포',
#   '칼',
#   '립스',
#   '세계',
#   '맛보',
#   '고',
#   '있',
#   '네'],
#  ['물난리',
#   '새끼',
#   '슬슬',
#   '이재명',
#   '이',
#   '었',
#   '으면',
#   '어쩌',
#   '하',
#   '면서',
#   '드릉',
#   '대',
#   '같',
#   '은데',
#   '이재명',
#   '호로',
#   '새끼',
#   '쿠팡',
#   '화재',
#   '떡볶이',
#   '먹',
#   '던',
#   '없',
#   '고',
#   '추석',
#   '코로나',
#   '아웃브레이크',
#   '시작',
#   '되',
#   '고',
#   '다음',
#   '여름',
#   '폭우',
#   '있',
#   '었',
#   '는'],
#  ['쿠팡',
#   '대형',
#   '화재',
#   '깔깔',
#   '웃',
#   '으면서',
#   '떡볶이',
#   '먹방',
#   '하',
#   '는',
#   '거',
#   '생생',
#   '하',
#   '게',
#   '봤',
#   '는데',
#   '올려'],
#  ['엄니',
#   '년차',
#   '공무원',
#   '재난',
#   '상황',
#   '비상',
#   '근무',
#   '없',
#   '었',
#   '음',
#   '여기',
#   '는',
#   '와서',
#   '현재',
#   '침수',
#   '피해',
#   '없',
#   '지만',
#   '조금',
#   '오거',
#   '산불',
#   '난다거나',
#   '하',
#   '면',
#   '비상',
#   '근무',
#   '새벽',
#   '퇴근',
#   '새',
#   '고',
#   '담날'],
#  ['이재명',
#   '대통령',
#   '추첨',
#   '기간',
#   '동안',
#   '삼척',
#   '울진',
#   '산불',
#   '났',
#   '을',
#   '방문',
#   '시간',
#   '주작',
#   '하',
#   '던',
#   '위인'],
#  ['이낙연',
#   '총리',
#   '시절',
#   '강원도',
#   '산불',
#   '저지',
#   '를',
#   '위해',
#   '전국',
#   '모여드',
#   '는',
#   '소방관',
#   '소방차',
#   '소방차',
#   '행렬',
#   '보',
#   '고',
#   '감명',
#   '받',
#   '았',
#   '습니다'],
#  ['이재명',
#   '재난',
#   '대처',
#   '하',
#   '는',
#   '방식',
#   '코로나',
#   '이후',
#   '재난',
#   '원금',
#   '노래',
#   '하',
#   '며',
#   '각종',
#   '기금',
#   '예산',
#   '빼내',
#   '어',
#   '수조',
#   '남김',
#   '정작',
#   '경기도',
#   '수해',
#   '개군',
#   '억',
#   '원',
#   '지원',
#   '정부',
#   '재난',
#   '원금'],
#  ['이재명',
#   '낙선',
#   '원인',
#   '황',
#   '교익',
#   '먹방',
#   '촬영',
#   '황',
#   '교익',
#   '차관',
#   '지위',
#   '경기',
#   '관광',
#   '공사',
#   '사장',
#   '임명',
#   '날라',
#   '갔',
#   '다고',
#   '생각',
#   '한다',
#   '경기도',
#   '소방',
#   '최고',
#   '책임자',
#   '자기',
#   '지역',
#   '대형',
#   '화재',
#   '팽',
#   '개',
#   '마산',
#   '내려가'],
#  ['윤석열',
#   '지난',
#   '대선',
#   '산불',
#   '현장',
#   '가',
#   '서',
#   '헬기',
#   '타',
#   '고',
#   '와야',
#   '죠',
#   '하',
#   '며',
#   '입',
#   '털',
#   '사진',
#   '찍',
#   '고',
#   '갔',
#   '던',
#   '거',
#   '생각나',
#   '면',
#   '난다'],
#  ['민주당',
#   '정치',
#   '인',
#   '산불',
#   '방지',
#   '예산',
#   '깎',
#   '았',
#   '는가',
#   '민주당',
#   '정치',
#   '인',
#   '산불',
#   '났',
#   '는데',
#   '퇴근',
#   '했',
#   '는가'],
#  ['현재',
#   '우리',
#   '나라',
#   '에탄올',
#   '화',
#   '로',
#   '안전',
#   '기준',
#   '없',
#   '습니다',
#   '소비',
#   '자원',
#   '시중',
#   '판매',
#   '화',
#   '로',
#   '호주',
#   '기준',
#   '따라',
#   '조사',
#   '결과',
#   '모두',
#   '부적합',
#   '한',
#   '에탄올',
#   '불꽃',
#   '보이',
#   '지',
#   '않',
#   '는',
#   '특성',
#   '있',
#   '습니다',
#   '사용',
#   '자',
#   '불꽃'],
#  ['이',
#   '천',
#   '화재',
#   '떡볶이',
#   '먹방',
#   '이재명',
#   '재난',
#   '대비',
#   '능력',
#   '인성',
#   '아예',
#   '없',
#   '는',
#   '판명',
#   '되',
#   '었',
#   '다',
#   '소리',
#   '하',
#   '지',
#   '이낙연'],
#  ['산불', '나', '면', '간다', '했', '지', '가', '지', '가', '겠', '단', '소리', '했', '다'],
#  ['그래',
#   '우리',
#   '산불',
#   '나',
#   '고',
#   '지진',
#   '날',
#   '때',
#   '문재',
#   '인',
#   '때문',
#   '장난',
#   '하',
#   '자는',
#   '아니',
#   '고',
#   '하',
#   '면',
#   '윤석열',
#   '때문',
#   '지랄',
#   '하',
#   '니까',
#   '빡',
#   '치',
#   '는',
#   '거',
#   '지'],
#  ['이재명',
#   '도지사',
#   '소방',
#   '업무',
#   '하',
#   '는',
#   '없',
#   '다',
#   '해',
#   '놓',
#   '고',
#   '정작',
#   '경기도',
#   '화재',
#   '났',
#   '을',
#   '황',
#   '교익',
#   '마산',
#   '볶',
#   '에',
#   '처묵',
#   '처묵'],
#  ['울진', '산불', '서울', '침수'],
#  ['이재명',
#   '됐',
#   '으면',
#   '그랬',
#   '다고',
#   '쿠팡',
#   '화재',
#   '이러',
#   '고',
#   '있',
#   '었',
#   '던',
#   '까먹',
#   '었',
#   '음'],
#  ['잦',
#   '은',
#   '폭우',
#   '태풍',
#   '겪',
#   '는',
#   '부산',
#   '사람',
#   '장마',
#   '끝',
#   '나',
#   '고',
#   '나',
#   '내리',
#   '고',
#   '나',
#   '서',
#   '부터',
#   '바퀴',
#   '출몰',
#   '심해져',
#   '요',
#   '하수',
#   '조금',
#   '튀',
#   '면',
#   '바로',
#   '씻',
#   '어',
#   '야',
#   '해요',
#   '여름',
#   '하수',
#   '바퀴벌레',
#   '천국',
#   '겨울',
#   '사',
#   '는데요'],
#  ['서울',
#   '물난리',
#   '당했',
#   '습니다',
#   '저희',
#   '건물',
#   '하수',
#   '역류',
#   '침수',
#   '되',
#   '는',
#   '바람',
#   '저희',
#   '천장',
#   '무너져서',
#   '포장재',
#   '재료',
#   '잠겼',
#   '네요',
#   '당분간',
#   '발송',
#   '어찌',
#   '될지',
#   '는',
#   '내일',
#   '아침',
#   '정리',
#   '하',
#   '며',
#   '다시',
#   '한',
#   '번',
#   '확인',
#   '자세',
#   '한'],
#  ['저희',
#   '어머니',
#   '강원',
#   '도',
#   '사',
#   '시',
#   '는데',
#   '출근길',
#   '소리',
#   '나',
#   '서',
#   '돌아보',
#   '니',
#   '나무',
#   '무너져',
#   '있',
#   '었',
#   '대요',
#   '강원도',
#   '침수',
#   '산사태',
#   '피해',
#   '관심',
#   '가져',
#   '주',
#   '세요'],
#  ['특보',
#   '웃긴',
#   '게',
#   '강남',
#   '삼성',
#   '샌',
#   '다고',
#   '보도',
#   '하',
#   '더니',
#   '이후',
#   '대',
#   '기업',
#   '오피스',
#   '삼성',
#   '이름',
#   '뺀다',
#   '전화',
#   '온',
#   '듯'],
#  ['아니',
#   '뉴스',
#   '특보',
#   '제보',
#   '받',
#   '은',
#   '각종',
#   '침수',
#   '영상',
#   '보여',
#   '주',
#   '는',
#   '게',
#   '맞',
#   '아',
#   '이건',
#   '재미',
#   '아님',
#   '침수',
#   '지역',
#   '지도',
#   '표시',
#   '해',
#   '주',
#   '고',
#   '예보',
#   '알려',
#   '주',
#   '고',
#   '침수',
#   '황시',
#   '어',
#   '케',
#   '해야',
#   '하',
#   '는지',
#   '대피',
#   '요령',
#   '챙겨',
#   '야',
#   '하',
#   '는',
#   '거',
#   '나',
#   '그런',
#   '거',
#   '반복',
#   '해서',
#   '알려줘',
#   '야',
#   '하',
#   '는',
#   '거',
#   '아닌가'],
#  ['퇴근',
#   '하',
#   '면서',
#   '침수',
#   '시작',
#   '봤',
#   '으면',
#   '돌렸',
#   '어야지',
#   '새끼',
#   '소리',
#   '소주',
#   '한잔',
#   '생각',
#   '정신',
#   '놨',
#   '었'],
#  ['어제',
#   '서울',
#   '물난리',
#   '집중호우',
#   '여파',
#   '강남역',
#   '침수',
#   '발생',
#   '하',
#   '면서',
#   '강남역',
#   '일대',
#   '바퀴벌레',
#   '선생',
#   '출몰',
#   '하',
#   '는',
#   '끔찍',
#   '한',
#   '상황',
#   '발생',
#   '했',
#   '습니다'],
#  ['마이',
#   '케이',
#   '팝',
#   '캘린더',
#   '퍼플',
#   '키스',
#   '개인',
#   '좋',
#   '고',
#   '멤버',
#   '모든',
#   '아름답',
#   '지만',
#   '하',
#   '면',
#   '습한',
#   '장마',
#   '청량',
#   '한',
#   '해변',
#   '가',
#   '를',
#   '좋아하',
#   '기',
#   '때문',
#   '청량',
#   '가득',
#   '여성',
#   '시선',
#   '빼앗겨'],
#  ['침수'],
#  ['침수',
#   '됐',
#   '던',
#   '지하철역',
#   '거의',
#   '복구',
#   '됐',
#   '다니',
#   '밤새',
#   '얼마나',
#   '많',
#   '은',
#   '애써',
#   '주',
#   '신',
#   '덕분',
#   '일까'],
#  ['진짜',
#   '이런',
#   '재밌',
#   '다고',
#   '패러디',
#   '하',
#   '는',
#   '이미지',
#   '모아서',
#   '바이럴',
#   '하',
#   '는',
#   '보',
#   '는',
#   '고통',
#   '스럽',
#   '다',
#   '동료',
#   '시민',
#   '반지하',
#   '죽',
#   '고',
#   '터전',
#   '무너지',
#   '고',
#   '차량',
#   '침수',
#   '되',
#   '는데',
#   '재난',
#   '어떤',
#   '소',
#   '로',
#   '거리',
#   '찾',
#   '고',
#   '즐긴다'],
#  ['아니',
#   '뉴스',
#   '특보',
#   '보다',
#   '보',
#   '니',
#   '웃긴다',
#   '지방',
#   '태풍',
#   '와서',
#   '무너져도',
#   '자막',
#   '덜렁',
#   '나오',
#   '고',
#   '이',
#   '었',
#   '어서',
#   '지역',
#   '사람',
#   '남부',
#   '지방',
#   '태풍',
#   '피해',
#   '있',
#   '는지',
#   '도',
#   '몰랐',
#   '던',
#   '적',
#   '도',
#   '있',
#   '는데',
#   '동네',
#   '비오',
#   '니까',
#   '방송',
#   '끊',
#   '고',
#   '특보'],
#  ['트위터',
#   '진짜',
#   '재난',
#   '재해',
#   '알맞',
#   '는',
#   '맨홀',
#   '뚜껑',
#   '조심',
#   '해',
#   '거리',
#   '가까이',
#   '있',
#   '지',
#   '침수',
#   '잡',
#   '거나',
#   '짚',
#   '으면서',
#   '걸',
#   '어야지',
#   '그러',
#   '면',
#   '뚜껑',
#   '날아간',
#   '맨',
#   '홀',
#   '빠지',
#   '거나',
#   '물살',
#   '쓸려',
#   '가',
#   '물난리',
#   '피부병',
#   '전염병',
#   '조심',
#   '해'],
#  ['실시간',
#   '강남역',
#   '슈퍼맨',
#   '등장',
#   '아저씨',
#   '폭우',
#   '침수',
#   '강남역',
#   '복판',
#   '배수관',
#   '쌓여',
#   '있',
#   '는',
#   '쓰레기',
#   '맨손',
#   '건져',
#   '덕분',
#   '종아리',
#   '차올랐',
#   '던',
#   '금방',
#   '내려감'],
#  ['침수',
#   '반지하',
#   '사람',
#   '죽',
#   '은',
#   '고현',
#   '찾아가',
#   '구겨',
#   '앉',
#   '아',
#   '가',
#   '며',
#   '구경',
#   '하',
#   '다가',
#   '어제',
#   '퇴근',
#   '하',
#   '면서',
#   '우리',
#   '아파트',
#   '언덕',
#   '있',
#   '는데',
#   '도',
#   '잠겼',
#   '하',
#   '며',
#   '누구',
#   '물',
#   '어',
#   '보',
#   '지',
#   '않',
#   '은',
#   '자신',
#   '전날',
#   '퇴근'],
#  ['침수',
#   '되',
#   '는',
#   '봤',
#   '지만',
#   '아니',
#   '고',
#   '일',
#   '도',
#   '아니',
#   '니까',
#   '퇴근',
#   '했',
#   '다',
#   '같',
#   '은',
#   '대통령',
#   '하',
#   '면',
#   '되',
#   '는',
#   '아닌가',
#   '그것',
#   '피해',
#   '지역',
#   '현장'],
#  ['이제야',
#   '한숨',
#   '돌릴',
#   '나',
#   '서',
#   '풀',
#   '어',
#   '보',
#   '는',
#   '지하철',
#   '침수',
#   '버스',
#   '침수',
#   '차',
#   '도',
#   '막힘',
#   '도로',
#   '막힘',
#   '막판',
#   '수영',
#   '해서',
#   '퇴근',
#   '시간',
#   '푼다',
#   '이제',
#   '정전',
#   '곁들인'],
#  ['아픈',
#   '아기',
#   '키우',
#   '는',
#   '친구',
#   '반지하',
#   '침수',
#   '하수',
#   '역류',
#   '걱정',
#   '정전',
#   '되',
#   '면',
#   '아기',
#   '산소',
#   '호흡',
#   '기',
#   '를',
#   '두려워하',
#   '고',
#   '있',
#   '다',
#   '외래',
#   '진료',
#   '위해',
#   '호출',
#   '장애',
#   '인',
#   '택시',
#   '배차',
#   '시간',
#   '걸렸',
#   '고',
#   '목금',
#   '진료',
#   '재활'],
#  ['알티',
#   '타네',
#   '강남',
#   '고급',
#   '아파트',
#   '침수',
#   '피해',
#   '입',
#   '었',
#   '는데',
#   '불',
#   '공평',
#   '이런',
#   '얘기',
#   '나오',
#   '는',
#   '화남',
#   '조금',
#   '생각',
#   '해봐도',
#   '알',
#   '잖아요',
#   '반지하',
#   '지하',
#   '사',
#   '는',
#   '사람',
#   '거리',
#   '시장',
#   '장사',
#   '하',
#   '는',
#   '사람',
#   '강남',
#   '고급',
#   '아파트',
#   '사',
#   '는',
#   '사람',
#   '같',
#   '은'],
#  ['맞',
#   '는',
#   '입니다',
#   '덧붙이',
#   '자면',
#   '경험',
#   '운전',
#   '도로',
#   '물밑',
#   '안보',
#   '여요',
#   '그냥',
#   '침수',
#   '도로',
#   '피하',
#   '제일',
#   '좋',
#   '습니다',
#   '거기',
#   '자작',
#   '하',
#   '게',
#   '물',
#   '이',
#   '고인',
#   '건지',
#   '낭떠러지',
#   '물',
#   '이',
#   '건지',
#   '없',
#   '어요',
#   '있',
#   '어요'],
#  ['여러분',
#   '그거',
#   '아',
#   '시',
#   '나요',
#   '서울',
#   '물난리',
#   '강남',
#   '정전',
#   '강남역',
#   '침수',
#   '실트',
#   '오늘',
#   '내린',
#   '비',
#   '는',
#   '내일',
#   '모레',
#   '내릴',
#   '예고편',
#   '랍',
#   '니',
#   '참',
#   '고',
#   '러브',
#   '다이브',
#   '하',
#   '러',
#   '가',
#   '겠',
#   '음',
#   '사진',
#   '시계',
#   '방향',
#   '오늘',
#   '내일',
#   '모레'],
#  ['왔',
#   '는데',
#   '다음',
#   '대중교통',
#   '말짱',
#   '해졌',
#   '다',
#   '천재지변',
#   '인력',
#   '막',
#   '은',
#   '간밤',
#   '얼마나',
#   '힘드',
#   '셨을까',
#   '게다가',
#   '지하철',
#   '청소',
#   '거의',
#   '여자',
#   '하',
#   '시',
#   '잖아',
#   '좋',
#   '게',
#   '도',
#   '침수',
#   '구간',
#   '출퇴근',
#   '하',
#   '지만',
#   '마음',
#   '무겁'],
#  ['반지하',
#   '침수',
#   '사고',
#   '현장',
#   '찾',
#   '은',
#   '대통령',
#   '오세훈',
#   '서울',
#   '시장',
#   '출처',
#   '뉴스',
#   '네이버',
#   '뉴스',
#   '카메라',
#   '의식',
#   '하',
#   '지'],
#  ['지하철',
#   '호선',
#   '운영',
#   '오늘',
#   '모두',
#   '정상',
#   '화',
#   '반면',
#   '민간',
#   '운영',
#   '하',
#   '는',
#   '호선',
#   '일부',
#   '구간',
#   '운영',
#   '되',
#   '고',
#   '상당수',
#   '침수',
#   '복구',
#   '있',
#   '는',
#   '여러분',
#   '지금',
#   '민영화',
#   '결론',
#   '보',
#   '고',
#   '계십니다',
#   '운영',
#   '최대'],
#  ['침수',
#   '되',
#   '면',
#   '누구',
#   '수리',
#   '복구',
#   '호텔',
#   '잡',
#   '아',
#   '지낼',
#   '있',
#   '고',
#   '쓰',
#   '게',
#   '소지품',
#   '새로',
#   '여유',
#   '있',
#   '는데',
#   '누구',
#   '당장',
#   '곳',
#   '도',
#   '정부',
#   '마련',
#   '주',
#   '지',
#   '않',
#   '으면',
#   '없',
#   '고',
#   '생',
#   '필',
#   '품',
#   '도',
#   '한두',
#   '새',
#   '로',
#   '사',
#   '는',
#   '부담'],
#  ['뉴욕',
#   '폭설',
#   '경보',
#   '예상',
#   '된다고',
#   '뉴스',
#   '나온',
#   '병원',
#   '출퇴근',
#   '어려운',
#   '직원',
#   '위해',
#   '호텔',
#   '빌려',
#   '숙식',
#   '제공',
#   '했',
#   '고',
#   '출근',
#   '직원',
#   '날씨',
#   '와줘서',
#   '고맙',
#   '다며',
#   '병원',
#   '매점',
#   '이용',
#   '권',
#   '매점',
#   '자체',
#   '싸',
#   '서'],
#  ['퇴근',
#   '하',
#   '면서',
#   '보',
#   '니',
#   '벌써',
#   '다른',
#   '아래쪽',
#   '아파트',
#   '침수',
#   '시작',
#   '되',
#   '더라',
#   '아니',
#   '퇴근',
#   '하',
#   '지',
#   '대본',
#   '컨트롤',
#   '하',
#   '셔야',
#   '지',
#   '기',
#   '어',
#   '들어가',
#   '세요',
#   '반지하',
#   '죽',
#   '어도',
#   '자긴',
#   '지대',
#   '비싼',
#   '아파트',
#   '산다',
#   '자랑'],
#  ['지금', '출근', '하', '는데', '도로', '안보', '침수'],
#  ['서울시',
#   '최초',
#   '터널',
#   '빗물',
#   '시설',
#   '신월',
#   '빗물',
#   '시설',
#   '국내',
#   '최고',
#   '수준',
#   '배수',
#   '능력',
#   '자랑',
#   '하',
#   '며',
#   '폭우',
#   '최대',
#   '빗물',
#   '저장',
#   '신월',
#   '빗물',
#   '시설',
#   '운영',
#   '통해',
#   '장마철',
#   '고질',
#   '침수',
#   '지역',
#   '신월동'],
#  ['현석',
#   '진짜',
#   '오랜',
#   '만이',
#   '수고',
#   '하',
#   '셨',
#   '스미스',
#   '날씨',
#   '오락가락',
#   '이제',
#   '장마',
#   '감기',
#   '조심'],
#  ['대통령',
#   '퇴근',
#   '하',
#   '면서',
#   '보',
#   '니',
#   '다른',
#   '아파트',
#   '침수',
#   '시작',
#   '발언',
#   '논란',
#   '출처',
#   '부산',
#   '일보',
#   '네이버'],
#  ['게임',
#   '가디언',
#   '테일즈',
#   '개발',
#   '스튜디오',
#   '사무실',
#   '이번',
#   '폭우',
#   '침수',
#   '피해',
#   '입',
#   '어',
#   '내일',
#   '예정',
#   '되',
#   '었',
#   '던',
#   '업데이트',
#   '무기',
#   '한',
#   '연기',
#   '되',
#   '었',
#   '다는',
#   '소식'],
#  ['고생',
#   '많',
#   '으시',
#   '고',
#   '대단',
#   '하',
#   '신데',
#   '이건',
#   '감사',
#   '하',
#   '고',
#   '넘길',
#   '문제',
#   '아니',
#   '라',
#   '당장',
#   '대피',
#   '해도',
#   '모자랄',
#   '침수',
#   '진행',
#   '중',
#   '건물',
#   '계속',
#   '남',
#   '아',
#   '청소',
#   '해야',
#   '만',
#   '하',
#   '는',
#   '환경',
#   '비',
#   '정상',
#   '대해',
#   '생각',
#   '해',
#   '봐야',
#   '같',
#   '음',
#   '재난',
#   '상황',
#   '대피',
#   '하',
#   '는',
#   '청소'],
#  ['침수', '시작', '되', '는', '봤', '으면서', '그대로', '퇴근', '했', '다고'],
#  ['내일',
#   '모레',
#   '구건',
#   '발송',
#   '예정',
#   '입니다만',
#   '침수',
#   '지역',
#   '택배',
#   '수령',
#   '어렵',
#   '거나',
#   '불안',
#   '하',
#   '신',
#   '말씀',
#   '주시',
#   '발송',
#   '미루',
#   '겠',
#   '습니다',
#   '다만',
#   '사',
#   '는',
#   '지역',
#   '짱짱',
#   '해',
#   '날씨',
#   '판별',
#   '어려워',
#   '받',
#   '으시',
#   '길',
#   '원하',
#   '는',
#   '시기',
#   '말씀',
#   '주',
#   '셔',
#   '야',
#   '합니다'],
#  ['퇴근길', '침수', '보', '면서', '도', '퇴근'],
#  ['살',
#   '다',
#   '살',
#   '다',
#   '주변',
#   '침수',
#   '출근',
#   '한다는',
#   '대통령',
#   '타',
#   '고',
#   '출근',
#   '해야지',
#   '이런',
#   '재난',
#   '상황',
#   '아니',
#   '무슨',
#   '이런',
#   '얼뜨기',
#   '있',
#   '냐',
#   '멀쩡',
#   '한',
#   '청와대',
#   '놔두',
#   '고'],
#  ['반지하',
#   '침수',
#   '사망',
#   '유족',
#   '방문',
#   '사진',
#   '국민',
#   '지킨다고',
#   '홍포',
#   '포스터',
#   '만든',
#   '거',
#   '소름',
#   '패인'],
#  ['윤석열',
#   '대통령',
#   '장애',
#   '가족',
#   '참변',
#   '반지하',
#   '침수',
#   '현장',
#   '찾',
#   '아',
#   '미리',
#   '대피',
#   '됐',
#   '느냐',
#   '윤석열',
#   '질문',
#   '충격',
#   '박근혜',
#   '구명조끼',
#   '발언',
#   '떠올랐',
#   '음'],
#  ['이제',
#   '우리',
#   '나라',
#   '사계절',
#   '아름다운',
#   '나라',
#   '아니',
#   '다',
#   '동시',
#   '경보',
#   '뜨',
#   '는',
#   '나라',
#   '시바'],
#  ['아크', '비스타', '엘리베이터', '침수', '영상', '가짜', '뉴스'],
#  ['중부',
#   '폭우',
#   '집중호우',
#   '인하',
#   '여',
#   '이',
#   '수역',
#   '침수',
#   '강남역',
#   '침수',
#   '도림',
#   '천',
#   '범람',
#   '지하철',
#   '침수',
#   '도로',
#   '침수',
#   '각종',
#   '피해',
#   '속출',
#   '있',
#   '습니다',
#   '모두',
#   '조심',
#   '하',
#   '시',
#   '고',
#   '무사',
#   '귀',
#   '가',
#   '하',
#   '세요'],
#  ['아주',
#   '친절',
#   '하',
#   '셨',
#   '고',
#   '하',
#   '는데',
#   '덕분',
#   '힘든',
#   '와중',
#   '위',
#   '안',
#   '되',
#   '셨',
#   '다고',
#   '후속',
#   '조치',
#   '로되',
#   '좋',
#   '겠',
#   '다고',
#   '침수',
#   '올해',
#   '세',
#   '번',
#   '힘들',
#   '다고',
#   '호소',
#   '하',
#   '셨',
#   '습니다',
#   '의원',
#   '님',
#   '개인',
#   '없',
#   '으시',
#   '고',
#   '시간',
#   '늦',
#   '어서',
#   '내일'],
#  ['더불',
#   '어',
#   '민주당',
#   '남동구',
#   '의회',
#   '이철상',
#   '의원',
#   '님',
#   '사람',
#   '어머니',
#   '모르',
#   '겠',
#   '다',
#   '하',
#   '시',
#   '네요',
#   '침수',
#   '상가',
#   '지역',
#   '직접',
#   '오',
#   '셔서',
#   '상가',
#   '의견',
#   '물',
#   '어',
#   '보',
#   '시',
#   '고',
#   '시간',
#   '이상',
#   '서서',
#   '피해',
#   '상황',
#   '둘러보',
#   '시',
#   '고',
#   '펌프'],
#  ['금전',
#   '본',
#   '거',
#   '어젯밤',
#   '폭우',
#   '관악',
#   '구',
#   '세',
#   '가족',
#   '침수',
#   '숨진',
#   '훈시',
#   '갔',
#   '는데',
#   '동네',
#   '주민',
#   '항의',
#   '하',
#   '자',
#   '죄송',
#   '하',
#   '다거나',
#   '위',
#   '로',
#   '해',
#   '주',
#   '는',
#   '대신',
#   '있',
#   '던',
#   '사람',
#   '보',
#   '고',
#   '설명',
#   '주세요',
#   '하',
#   '고',
#   '바로',
#   '돌리',
#   '고',
#   '가',
#   '는',
#   '모습'],
#  ['어제',
#   '강남',
#   '서초',
#   '침수',
#   '당했',
#   '는데',
#   '재난',
#   '불공정',
#   '이야기',
#   '나오',
#   '냐며',
#   '같',
#   '지',
#   '도',
#   '않',
#   '던',
#   '소리',
#   '하',
#   '는',
#   '사람',
#   '생각나',
#   '서',
#   '더욱',
#   '화',
#   '가',
#   '난다'],
#  ['항상',
#   '침수',
#   '진행',
#   '되',
#   '는',
#   '상황',
#   '불어',
#   '감당',
#   '하',
#   '지',
#   '긴급',
#   '한',
#   '방류',
#   '시행',
#   '하',
#   '는',
#   '옥상',
#   '처방',
#   '예고',
#   '재난',
#   '상황',
#   '이어지',
#   '는',
#   '안',
#   '타',
#   '까',
#   '시정',
#   '하',
#   '지',
#   '하',
#   '는',
#   '공무원',
#   '작태',
#   '분개',
#   '없',
#   '다는'],
#  ['가족',
#   '이자',
#   '사회',
#   '약자',
#   '별안간',
#   '수재',
#   '돌아가',
#   '신',
#   '찾아가',
#   '우리',
#   '아파트',
#   '침수',
#   '됐',
#   '다',
#   '멘',
#   '트',
#   '하',
#   '는',
#   '리',
#   '더',
#   '도대체',
#   '어떤',
#   '회로',
#   '장착',
#   '걸까',
#   '나름',
#   '공감',
#   '표현',
#   '하',
#   '려는',
#   '노력',
#   '허한',
#   '말',
#   '로',
#   '꾸려',
#   '던',
#   '무엇',
#   '일까'],
#  ['운전',
#   '침수',
#   '도로',
#   '행동',
#   '요령',
#   '웅덩이',
#   '통과',
#   '불가피',
#   '한',
#   '경우',
#   '기어',
#   '시속',
#   '서행',
#   '통과',
#   '범퍼',
#   '높이',
#   '침수',
#   '미리',
#   '기',
#   '어',
#   '놓',
#   '고',
#   '한',
#   '번',
#   '지나가',
#   '야',
#   '도중',
#   '기어',
#   '바꾸',
#   '거나'],
#  ['장애',
#   '가족',
#   '참변',
#   '반지하',
#   '침수',
#   '현장',
#   '찾',
#   '아',
#   '미리',
#   '대피',
#   '됐',
#   '나',
#   '윤석열',
#   '구명조끼',
#   '입',
#   '었',
#   '다고',
#   '하',
#   '는데',
#   '발견',
#   '하',
#   '기',
#   '힘드',
#   '냐',
#   '박근혜',
#   '무슨',
#   '데',
#   '쟈',
#   '뷰',
#   '피해자',
#   '유가족',
#   '이',
#   '었',
#   '으면',
#   '있',
#   '었',
#   '다'],
#  ['속보', '서울', '도봉구', '종로구', '산사태', '주의보', '발령'],
#  ['어제',
#   '마당',
#   '도서관',
#   '국립',
#   '중앙',
#   '도서관',
#   '있',
#   '으니까',
#   '종',
#   '이',
#   '아깝',
#   '다',
#   '정도',
#   '였',
#   '는데',
#   '국립',
#   '중앙',
#   '도서관',
#   '침수'],
#  ['장마',
#   '패턴',
#   '폭우',
#   '폭염',
#   '폭우',
#   '반복',
#   '되',
#   '는',
#   '형태',
#   '최근',
#   '수년',
#   '사이',
#   '과거',
#   '달라졌',
#   '다',
#   '온난',
#   '화',
#   '대기',
#   '수증',
#   '기량',
#   '늘어나',
#   '고',
#   '해수면',
#   '온도',
#   '과거',
#   '상승',
#   '주지',
#   '사실',
#   '이',
#   '라면서',
#   '기후',
#   '변화'],
#  ['존나',
#   '웃긴다',
#   '자택',
#   '주변',
#   '침수',
#   '돼서',
#   '움직',
#   '자택',
#   '실시간',
#   '보',
#   '고',
#   '받',
#   '으신',
#   '대통령실',
#   '언론사',
#   '통화',
#   '했',
#   '데',
#   '웃',
#   '김',
#   '웃',
#   '김',
#   '그러',
#   '니깐',
#   '청와대',
#   '같',
#   '은',
#   '호의호식',
#   '하',
#   '려고',
#   '쓰',
#   '는',
#   '아니',
#   '잖',
#   '냐'],
#  ['침수',
#   '피해',
#   '침수',
#   '피해',
#   '강원도',
#   '강원도',
#   '침수',
#   '피해',
#   '서울',
#   '그런',
#   '줄',
#   '알',
#   '어',
#   '군위'],
#  ['윤석열',
#   '사',
#   '는',
#   '서초동',
#   '아파트',
#   '언덕',
#   '있',
#   '는데',
#   '도',
#   '침수',
#   '정도',
#   '였',
#   '다',
#   '퇴근',
#   '하',
#   '면서',
#   '보',
#   '니',
#   '벌써',
#   '다른',
#   '아래쪽',
#   '아파트',
#   '침수',
#   '시작',
#   '되',
#   '더라',
#   '아파트',
#   '침수',
#   '되',
#   '는',
#   '보고',
#   '퇴근',
#   '했',
#   '다고'],
#  ['실시간',
#   '침수',
#   '상황',
#   '확인',
#   '하',
#   '는',
#   '재난',
#   '포털',
#   '검색',
#   '날씨',
#   '별로',
#   '자세히',
#   '보',
#   '기',
#   '누르',
#   '면',
#   '실시간',
#   '상황',
#   '제보',
#   '있',
#   '고',
#   '시각',
#   '현장',
#   '있',
#   '어서',
#   '편리',
#   '해요',
#   '얼른',
#   '사태',
#   '끝',
#   '나',
#   '길',
#   '깅들'],
#  ['강원도',
#   '피해',
#   '궁금',
#   '해서',
#   '강원',
#   '일보',
#   '들어가',
#   '봤',
#   '다',
#   '영월',
#   '평창',
#   '급류',
#   '말려',
#   '익사',
#   '하',
#   '는',
#   '사고',
#   '있',
#   '었',
#   '고',
#   '주택',
#   '농경지',
#   '침수',
#   '되',
#   '고',
#   '골프장',
#   '유실',
#   '되',
#   '는',
#   '피해'],
#  ['딱',
#   '하',
#   '네',
#   '나오',
#   '는',
#   '이유',
#   '휴가',
#   '이유',
#   '윤석열',
#   '장마',
#   '강남',
#   '침수',
#   '윤석열',
#   '지지',
#   '도'],
#  ['제네시스',
#   '신형',
#   '침수',
#   '됏다',
#   '믿',
#   '어',
#   '지',
#   '지',
#   '않',
#   '음',
#   '천만',
#   '원',
#   '증발',
#   '차주',
#   '엇',
#   '어',
#   '친구',
#   '최대한',
#   '순간',
#   '타',
#   '야',
#   '비록',
#   '보닛'],
#  ['작년',
#   '재작년',
#   '부산',
#   '지하철',
#   '침수',
#   '정도',
#   '왔었',
#   '는데',
#   '언제',
#   '왔었',
#   '냐',
#   '는',
#   '듯',
#   '깨끗',
#   '하',
#   '게',
#   '청소',
#   '지하철역',
#   '화제',
#   '였었',
#   '다',
#   '오',
#   '는',
#   '누군가',
#   '시설',
#   '정비',
#   '해야',
#   '하',
#   '고',
#   '누군가',
#   '청소',
#   '해야',
#   '한'],
#  ['수해',
#   '현장',
#   '가지',
#   '긴급',
#   '조치',
#   '당부',
#   '했',
#   '습니다',
#   '첫째',
#   '빠른',
#   '시일',
#   '위험',
#   '지역',
#   '침수',
#   '빈발',
#   '지역',
#   '반지하',
#   '같',
#   '은',
#   '대한',
#   '현황',
#   '파악',
#   '둘째',
#   '피해',
#   '대해',
#   '서',
#   '는',
#   '절차',
#   '없애',
#   '거나',
#   '최소',
#   '화',
#   '해서',
#   '지원',
#   '나설',
#   '셋째',
#   '자원'],
#  ['훈',
#   '녀',
#   '생정',
#   '침수',
#   '차량',
#   '탈출',
#   '하',
#   '기',
#   '목숨',
#   '보존',
#   '유리창',
#   '깨',
#   '는',
#   '죽',
#   '빵',
#   '스킬'],
#  ['폭우',
#   '계속',
#   '되',
#   '고',
#   '있',
#   '어',
#   '긴급히',
#   '중랑천',
#   '인근',
#   '살피',
#   '있',
#   '습니다',
#   '살',
#   '곶',
#   '운동장',
#   '일대',
#   '많',
#   '은',
#   '침수',
#   '예상',
#   '구간',
#   '전면',
#   '통제',
#   '합니다',
#   '구민',
#   '여러분',
#   '지대',
#   '낮',
#   '은',
#   '통행',
#   '가해',
#   '주',
#   '시',
#   '재난',
#   '경보',
#   '알림'],
#  ['침수', '된', '거'],
#  ['빡',
#   '쳐서',
#   '직접',
#   '찍',
#   '어',
#   '아크',
#   '비스타',
#   '침수',
#   '이동',
#   '불가',
#   '개뿔',
#   '세상',
#   '멀쩡',
#   '합니다',
#   '차량',
#   '아무',
#   '문제',
#   '출입',
#   '중임',
#   '언론',
#   '기사',
#   '똑바로',
#   '써라',
#   '나갈',
#   '없',
#   '어서',
#   '있',
#   '는',
#   '아님',
#   '윤석열',
#   '그냥',
#   '귀찮',
#   '아서',
#   '출근',
#   '하',
#   '는',
#   '거',
#   '임'],
#  ['딱',
#   '하',
#   '네',
#   '나오',
#   '는',
#   '이유',
#   '휴가',
#   '이유',
#   '윤석열',
#   '장마',
#   '강남',
#   '침수',
#   '윤석열',
#   '지지',
#   '도'],
#  ['애초',
#   '멀쩡',
#   '한',
#   '청와대',
#   '버리',
#   '고',
#   '무리',
#   '하',
#   '게',
#   '대통령실',
#   '문제',
#   '호우',
#   '경보',
#   '불구',
#   '퇴근',
#   '문제',
#   '생각',
#   '절대'],
#  ['화요일',
#   '기준',
#   '대',
#   '가',
#   '넘',
#   '는',
#   '차량',
#   '침수',
#   '됐',
#   '고',
#   '손해',
#   '합니다',
#   '오토',
#   '차량',
#   '기어',
#   '낮추',
#   '는',
#   '수동',
#   '기어',
#   '모드',
#   '참조',
#   '하',
#   '세요',
#   '타래',
#   '인용',
#   '둡니다'],
#  ['어르신',
#   '트윗',
#   '활용',
#   '어렵',
#   '습니다',
#   '지하철',
#   '침수',
#   '중단',
#   '구간',
#   '문자',
#   '경보',
#   '알림',
#   '보내',
#   '주',
#   '십시요',
#   '진짜',
#   '어제',
#   '돌아오',
#   '는',
#   '길',
#   '어르신',
#   '무작정',
#   '여기저기',
#   '물어봐',
#   '가',
#   '면서',
#   '버스',
#   '타',
#   '시',
#   '는',
#   '데',
#   '안타까웠',
#   '습니다'],
#  ['진짜',
#   '맞',
#   '는',
#   '거',
#   '침수',
#   '피해',
#   '났',
#   '어',
#   '서울',
#   '잠겼',
#   '어',
#   '대통령',
#   '새끼',
#   '재택근무',
#   '하',
#   '는데',
#   '나머지',
#   '노동자',
#   '밤새',
#   '지하철',
#   '치우',
#   '고',
#   '출근',
#   '심지어',
#   '시발',
#   '지하철',
#   '다시',
#   '운행',
#   '가능',
#   '하',
#   '게',
#   '했',
#   '어'],
#  ['이지영',
#   '중학생',
#   '반지하',
#   '침수',
#   '돼서',
#   '요점',
#   '노트',
#   '젖',
#   '어서',
#   '죽',
#   '으려고',
#   '옥상',
#   '갔',
#   '다는',
#   '생각',
#   '남'],
#  ['버스',
#   '침수',
#   '저상버스',
#   '하',
#   '지',
#   '마세요',
#   '그래도',
#   '보장',
#   '돼',
#   '있',
#   '는',
#   '장애',
#   '인',
#   '동권',
#   '공격',
#   '하',
#   '지',
#   '마세요',
#   '오세훈',
#   '서울',
#   '시장',
#   '재난',
#   '차관',
#   '임명',
#   '배수',
#   '시설',
#   '설치',
#   '배수',
#   '예산',
#   '삭감',
#   '쌍욕'],
#  ['아크',
#   '비스타',
#   '폭우',
#   '피해',
#   '대처',
#   '했',
#   '단다',
#   '그래',
#   '그럼',
#   '통화',
#   '기록',
#   '상황',
#   '기록',
#   '있',
#   '겠',
#   '네',
#   '그치',
#   '대통령',
#   '상황',
#   '대처',
#   '기록',
#   '전부',
#   '남겨야',
#   '하',
#   '는',
#   '맞',
#   '지',
#   '기록',
#   '보',
#   '자',
#   '누구',
#   '무슨',
#   '내용',
#   '통화',
#   '했',
#   '고'],
#  ['폭우',
#   '오늘',
#   '유독',
#   '도로',
#   '죽',
#   '은',
#   '동물',
#   '보이',
#   '네요',
#   '죽',
#   '은',
#   '동물',
#   '발견',
#   '하',
#   '셨',
#   '을',
#   '다산',
#   '콜',
#   '센터',
#   '전화',
#   '해',
#   '주',
#   '세요',
#   '지역',
#   '번호',
#   '입니다',
#   '침수',
#   '피해',
#   '제네시스',
#   '지하철역',
#   '조기',
#   '퇴근',
#   '기록',
#   '폭우',
#   '고양이',
#   '천둥',
#   '번개',
#   '남부',
#   '지방'],
#  ['지형', '높', '아서', '침수', '되', '고', '오', '고', '여름', '덥', '고', '하', '아'],
#  ['기호일보', '만평', '침수', '사태'],
#  ['여기',
#   '는',
#   '그냥',
#   '멸망',
#   '남부',
#   '지방',
#   '폭염',
#   '주의보',
#   '내린',
#   '곳',
#   '도',
#   '있',
#   '다던데',
#   '조그만',
#   '나라',
#   '무슨',
#   '날씨',
#   '모양'],
#  ['아까',
#   '호선',
#   '침수',
#   '알림',
#   '보',
#   '고',
#   '침울',
#   '하',
#   '게',
#   '나오',
#   '는데',
#   '창빈',
#   '줏대',
#   '있',
#   '게',
#   '걸어가',
#   '하',
#   '는',
#   '나',
#   '를',
#   '봐서',
#   '걸어옴'],
#  ['건물',
#   '주가',
#   '침수',
#   '지하',
#   '주차장',
#   '고급',
#   '차량',
#   '잠겨',
#   '거액',
#   '보상금',
#   '지불',
#   '이후',
#   '설치',
#   '했',
#   '다는',
#   '인터넷',
#   '풍문',
#   '거짓',
#   '처음',
#   '건물',
#   '지',
#   '었',
#   '을',
#   '설치',
#   '한다'],
#  ['아까',
#   '부터',
#   '계속',
#   '틀',
#   '어',
#   '눟',
#   '있',
#   '는데',
#   '정부',
#   '실종',
#   '되',
#   '었',
#   '다',
#   '예전',
#   '화면',
#   '하단',
#   '자막',
#   '계속',
#   '특보',
#   '정부',
#   '발표',
#   '집계',
#   '같',
#   '은',
#   '정보',
#   '떴었',
#   '지',
#   '지금',
#   '아무',
#   '나옴',
#   '했',
#   '던',
#   '하',
#   '면서',
#   '반복',
#   '하',
#   '고',
#   '있',
#   '다'],
#  ['장마',
#   '가방',
#   '블',
#   '투',
#   '이어폰',
#   '넣',
#   '을',
#   '지퍼',
#   '이케아',
#   '지퍼',
#   '항상',
#   '넣',
#   '어',
#   '두',
#   '는',
#   '옛날',
#   '엄청난',
#   '아이폰',
#   '지퍼',
#   '넣',
#   '고',
#   '문자',
#   '하',
#   '는',
#   '거',
#   '보',
#   '고',
#   '배움',
#   '가끔',
#   '지퍼',
#   '얇',
#   '은',
#   '손수건',
#   '넣',
#   '더라',
#   '습기'],
#  ['폭염', '보', '구', '진짜', '중간', '없', '네'],
#  ['있', '는', '폭염', '조심', '해'],
#  ['폭염', '다습', '한', '날씨', '어가', '바질', '전멸', '고무나무', '아보카도', '생생', '하', '네'],
#  ['폭염', '괜찮', '으신', '가요'],
#  ['여긴', '폭염', '경보', '조심', '하', '세요'],
#  ['남부',
#   '지방',
#   '가뭄',
#   '폭염',
#   '시달리',
#   '는데',
#   '퇴근길',
#   '피해',
#   '없',
#   '도록',
#   '안전',
#   '안전',
#   '조심',
#   '즐',
#   '퇴',
#   '하',
#   '세요'],
#  ['밤새',
#   '안녕',
#   '하',
#   '셔요',
#   '있',
#   '는',
#   '아랫',
#   '지방',
#   '폭염',
#   '때문',
#   '걱정',
#   '피해',
#   '안전',
#   '한',
#   '하루',
#   '되',
#   '시',
#   '길',
#   '바랍니다',
#   '오늘',
#   '힘',
#   '나',
#   '는',
#   '되',
#   '셔요'],
#  ['같', '은', '나라', '남부', '지방', '방울', '내리', '고', '열흘', '열대야', '폭염', '지속'],
#  ['더',
#   '쇼',
#   '폭염',
#   '여름',
#   '휴가',
#   '필요',
#   '없',
#   '어요',
#   '캡틴',
#   '강',
#   '쥐',
#   '용맹',
#   '함',
#   '과',
#   '비주',
#   '카리스마',
#   '감격',
#   '흐르',
#   '는',
#   '눈물',
#   '왼쪽',
#   '케리',
#   '안',
#   '더',
#   '오른쪽',
#   '더',
#   '쇼',
#   '밤',
#   '축제',
#   '열리',
#   '거든요',
#   '무더운',
#   '여름',
#   '나갈',
#   '필요',
#   '물놀',
#   '이',
#   '하',
#   '게',
#   '해',
#   '주'],
#  ['우린', '폭염', '중간', '없', '냐'],
#  ['우리',
#   '진정',
#   '걱정',
#   '자주',
#   '써',
#   '주',
#   '고',
#   '자주',
#   '읽',
#   '어',
#   '줘',
#   '야',
#   '하',
#   '는',
#   '기사',
#   '이런',
#   '기사',
#   '유럽',
#   '폭염',
#   '연일',
#   '뉴스',
#   '나오',
#   '지만',
#   '생사',
#   '오가',
#   '는',
#   '뉴스',
#   '자주',
#   '써',
#   '주',
#   '는가'],
#  ['오늘',
#   '날씨',
#   '알려',
#   '드리',
#   '겠',
#   '습니다',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '이상',
#   '입니다'],
#  ['여름',
#   '되',
#   '면',
#   '쿠팡',
#   '물류',
#   '센터',
#   '결근',
#   '조퇴',
#   '속출',
#   '합니다',
#   '많',
#   '은',
#   '계약',
#   '개조',
#   '이상',
#   '결근',
#   '조퇴',
#   '정도',
#   '노동자',
#   '사람',
#   '인',
#   '지라',
#   '폭염',
#   '견딜',
#   '없',
#   '으니',
#   '그날',
#   '일당',
#   '비롯',
#   '주휴',
#   '수당',
#   '연차',
#   '날아가',
#   '수입'],
#  ['호우', '주의보', '피해', '폭염', '경보'],
#  ['저희', '폭염', '구간', '습하', '고', '더', '워', '요'],
#  ['수능', '이제', '실감', '납니다', '폭염', '열공'],
#  ['웃', '고', '다정', '하', '게', '웃', '고', '박', '씨', '보이', '는구나', '폭염', '엇다'],
#  ['오늘',
#   '날씨',
#   '알려',
#   '드리',
#   '겠',
#   '습니다',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '폭우',
#   '폭염',
#   '이상',
#   '입니다'],
#  ['우리', '더워서', '넘어가', '슈', '펄', '과연', '폭염', '보가', '맞', '댜'],
#  ['지방', '폭염', '더워'],
#  ['부산', '폭염', '한창', '랍', '니', '심', '죠', '귀', '가', '새오'],
#  ['오늘',
#   '하루',
#   '고생',
#   '하',
#   '셨',
#   '습니다',
#   '중부',
#   '어제',
#   '오늘',
#   '이',
#   '심하',
#   '게',
#   '온다고',
#   '합니다',
#   '그러',
#   '니',
#   '퇴근길',
#   '조심',
#   '하',
#   '시',
#   '고요',
#   '출근',
#   '야근',
#   '하',
#   '시',
#   '는',
#   '조심',
#   '하',
#   '시',
#   '길',
#   '바랍니다',
#   '남부',
#   '열대야',
#   '이',
#   '니',
#   '폭염',
#   '조심',
#   '하',
#   '시',
#   '고',
#   '요',
#   '저녁'],
#  ['지구',
#   '멸망',
#   '할',
#   '이번',
#   '서울',
#   '물난리',
#   '단순',
#   '한',
#   '사건',
#   '아니',
#   '다',
#   '지',
#   '구',
#   '멸망',
#   '전조',
#   '하나',
#   '서울',
#   '기상이변',
#   '있',
#   '는',
#   '게',
#   '아니',
#   '다',
#   '시베리아',
#   '여름',
#   '온도',
#   '섭씨',
#   '넘어가',
#   '고',
#   '일본'],
#  ['시뻘겋',
#   '게',
#   '끓',
#   '었',
#   '다',
#   '나사',
#   '공개',
#   '붉',
#   '은',
#   '지구',
#   '충격',
#   '영상',
#   '도',
#   '를',
#   '웃도',
#   '는',
#   '극심',
#   '한',
#   '폭염',
#   '노멀',
#   '관측',
#   '스페인',
#   '정부',
#   '직장',
#   '인',
#   '넥타이',
#   '착용',
#   '자제',
#   '권고',
#   '영국',
#   '정부',
#   '정원',
#   '호스',
#   '사용'],
#  ['핫',
#   '함',
#   '경보',
#   '폭염',
#   '넘',
#   '어서',
#   '는',
#   '뜨거운',
#   '열기',
#   '승리',
#   '하나',
#   '되',
#   '는',
#   '피치스',
#   '뷰',
#   '잉',
#   '파티',
#   '현장',
#   '피치스',
#   '피치스'],
#  ['강남역',
#   '침수',
#   '되',
#   '고',
#   '정전',
#   '되',
#   '고',
#   '도서관',
#   '젖',
#   '고',
#   '뒤집히',
#   '고',
#   '맨홀',
#   '뚜껑',
#   '뽑히',
#   '고',
#   '바퀴벌레',
#   '득실',
#   '거리',
#   '청와대',
#   '종합',
#   '활',
#   '실',
#   '없',
#   '고',
#   '산사태',
#   '나',
#   '고',
#   '지방',
#   '폭염',
#   '정부',
#   '대책',
#   '없',
#   '다',
#   '진짜',
#   '정부',
#   '상태',
#   '실감'],
#  ['대한민국', '갈라졌', '노', '씨', '여기', '는', '폭염', '매미', '울', '어요'],
#  ['가뭄',
#   '이',
#   '었',
#   '다가',
#   '폭우',
#   '내렸',
#   '다가',
#   '폭염',
#   '이',
#   '었',
#   '다가',
#   '날씨',
#   '그지',
#   '같',
#   '음'],
#  ['아니',
#   '지만',
#   '차',
#   '서',
#   '그렸',
#   '어용',
#   '진짜',
#   '오',
#   '던데',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '폭염',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '안',
#   '전하',
#   '셨',
#   '음',
#   '좋',
#   '겠',
#   '어여',
#   '그림',
#   '그림',
#   '러',
#   '그림',
#   '그림',
#   '벚꽃',
#   '상시',
#   '커미션'],
#  ['여러분',
#   '대구',
#   '날씨',
#   '어떤',
#   '가요',
#   '여기',
#   '하늘',
#   '뚫린',
#   '같',
#   '은데',
#   '지방',
#   '폭염',
#   '주의보',
#   '믿기',
#   '지',
#   '가',
#   '않',
#   '어요'],
#  ['서울', '아마존', '개장', '여기', '는', '폭염', '랜드'],
#  ['폭우', '폭염', '모두', '조심', '하', '시', '길', '바라', '요'],
#  ['아니',
#   '지만',
#   '차',
#   '서',
#   '그렸',
#   '어용',
#   '진짜',
#   '오',
#   '던데',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '폭염',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '안',
#   '전하',
#   '셨',
#   '음',
#   '좋',
#   '겠',
#   '어여',
#   '그림',
#   '그림',
#   '러',
#   '그림',
#   '그림',
#   '벚꽃',
#   '상시',
#   '커미션'],
#  ['경기도',
#   '의회',
#   '드라마',
#   '인',
#   '스타',
#   '그램',
#   '지금',
#   '의회',
#   '크랭크',
#   '한',
#   '여름',
#   '폭염',
#   '시작',
#   '했',
#   '던',
#   '촬영',
#   '갑작스러운',
#   '폭우',
#   '종료',
#   '했',
#   '습니다',
#   '서지수',
#   '러블',
#   '리즈'],
#  ['코',
#   '로',
#   '나',
#   '걸렸',
#   '던',
#   '사람',
#   '줄줄이',
#   '걸리',
#   '고',
#   '있',
#   '어',
#   '폭염',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '코로나',
#   '조심',
#   '하',
#   '시',
#   '구',
#   '손',
#   '소독',
#   '마스크',
#   '하',
#   '세여',
#   '양산',
#   '좋',
#   '더라',
#   '외출',
#   '하',
#   '실',
#   '양산',
#   '추천',
#   '드립니다'],
#  ['진짜', '미치', '겠', '다', '우리', '지역', '오', '면', '비상', '우리', '지역', '폭염', '주의보'],
#  ['남부',
#   '지방',
#   '아예',
#   '내림',
#   '햇빛',
#   '바람',
#   '있',
#   '음',
#   '폭염',
#   '농작물',
#   '말라',
#   '죽음',
#   '곤충',
#   '더워',
#   '죽음'],
#  ['오전',
#   '폭염',
#   '경보',
#   '알림',
#   '왔',
#   '던',
#   '오늘',
#   '같',
#   '은',
#   '미친',
#   '날씨',
#   '기어',
#   '노동자',
#   '아스팔트',
#   '위',
#   '로',
#   '쫓아낸',
#   '파리',
#   '바',
#   '게',
#   '뜨',
#   '평생',
#   '불매'],
#  ['여태',
#   '수업',
#   '준비',
#   '한다고',
#   '앉',
#   '아서',
#   '이제',
#   '서',
#   '야',
#   '부랴부랴',
#   '카톡',
#   '보',
#   '고',
#   '놀래',
#   '서',
#   '이',
#   '돈',
#   '재림',
#   '나발',
#   '이상',
#   '피해',
#   '없',
#   '었',
#   '으면',
#   '좋',
#   '겠',
#   '다',
#   '우리',
#   '터',
#   '친',
#   '피해',
#   '없',
#   '으시',
#   '길',
#   '부산',
#   '며칠',
#   '폭염',
#   '경보',
#   '발효'],
#  ['특보',
#   '발효',
#   '현황',
#   '발효',
#   '시각',
#   '이후',
#   '호우',
#   '경보',
#   '호우',
#   '주의보',
#   '폭염',
#   '경보',
#   '폭염',
#   '주의보'],
#  ['비',
#   '는',
#   '여기',
#   '와야지',
#   '서울',
#   '가',
#   '는',
#   '데',
#   '에',
#   '여긴',
#   '폭염',
#   '주의보',
#   '뜨',
#   '고'],
#  ['특보',
#   '발효',
#   '현황',
#   '발효',
#   '시각',
#   '이후',
#   '호우',
#   '경보',
#   '호우',
#   '주의보',
#   '폭염',
#   '경보',
#   '폭염',
#   '주의보'],
#  ['농작물',
#   '푸석푸석',
#   '하',
#   '니까',
#   '기운',
#   '없',
#   '어',
#   '줘도',
#   '따',
#   '서',
#   '먹',
#   '어도',
#   '쓴',
#   '거',
#   '만',
#   '쓰',
#   '더라구요',
#   '장난',
#   '니야',
#   '이번',
#   '폭염'],
#  ['집중호우',
#   '때문',
#   '사망자',
#   '오늘',
#   '아침',
#   '기준',
#   '나왔',
#   '다는',
#   '데',
#   '수도',
#   '권',
#   '지역',
#   '이',
#   '면',
#   '조심',
#   '하',
#   '세요',
#   '제발',
#   '가족',
#   '서로',
#   '몸조심',
#   '하',
#   '자',
#   '폭염',
#   '나가',
#   '있',
#   '지',
#   '말',
#   '고',
#   '폭염',
#   '집중호우',
#   '무서운',
#   '자연재해',
#   '서로',
#   '몸조심',
#   '합니다'],
#  ['잇',
#   '죠',
#   '폭염',
#   '폭우',
#   '장난',
#   '아니',
#   '네요',
#   '우리',
#   '안',
#   '전하',
#   '게',
#   '살',
#   '아',
#   '있',
#   '어요'],
#  ['하미',
#   '존나',
#   '기여',
#   '우어',
#   '휴',
#   '닝',
#   '카이',
#   '미세먼지',
#   '외치',
#   '는',
#   '와중',
#   '최',
#   '수빈',
#   '귀마개',
#   '촉감'],
#  ['영화',
#   '기생충',
#   '송강호',
#   '폭우',
#   '침수',
#   '다음',
#   '조여정',
#   '어제',
#   '와서',
#   '미세먼지',
#   '없',
#   '구',
#   '하',
#   '고',
#   '송강호',
#   '하',
#   '는',
#   '장면',
#   '있',
#   '거든요',
#   '그거',
#   '충격',
#   '받',
#   '았',
#   '는데',
#   '오늘',
#   '선선',
#   '해서',
#   '좋',
#   '은데'],
#  ['데님',
#   '운동',
#   '금지',
#   '중구',
#   '미세먼지',
#   '좋',
#   '음',
#   '해외',
#   '종',
#   '로',
#   '행복',
#   '한',
#   '그룹',
#   '횡',
#   '성',
#   '소개팅',
#   '거울',
#   '블루스'],
#  ['포카', '왔음', '차', '도', '미세먼지', '낀', '게', '아쉽', '지만', '얼굴', '쵝오'],
#  ['무슨', '이제', '미세먼지', '저', '만', '먹', '읗게', '노래', '불러', '주', '세요'],
#  ['포카',
#   '진짜',
#   '미세먼지',
#   '필터',
#   '없애',
#   '줘',
#   '공지',
#   '포카',
#   '색감',
#   '기대',
#   '했',
#   '더니',
#   '실물',
#   '조명',
#   '진해',
#   '보이',
#   '는',
#   '거',
#   '구',
#   '얼굴',
#   '했',
#   '다'],
#  ['추억',
#   '건가',
#   '세상',
#   '장난꾸러기',
#   '황금',
#   '돼지',
#   '다이어트',
#   '동초',
#   '광고',
#   '제작',
#   '미세',
#   '먼지',
#   '좋',
#   '음',
#   '엄마',
#   '생각',
#   '간',
#   '만',
#   '업',
#   '뎃',
#   '볼수록',
#   '빠져드',
#   '는',
#   '미쳤',
#   '다'],
#  ['도초도', '강릉', '여행', '아이', '반찬', '미세먼지', '차단', '카페', '탐험대', '케이시'],
#  ['국가',
#   '재난',
#   '상황',
#   '관저',
#   '숨',
#   '어',
#   '있',
#   '던',
#   '대통령',
#   '폭우',
#   '내림',
#   '에',
#   '도',
#   '정시',
#   '퇴근',
#   '했',
#   '다',
#   '즈음',
#   '헐레벌떡',
#   '돌아왔',
#   '던',
#   '서울',
#   '시장',
#   '자신',
#   '대응',
#   '미숙',
#   '아니',
#   '었',
#   '다면',
#   '살릴',
#   '수',
#   '도',
#   '있',
#   '었',
#   '을',
#   '반지하',
#   '가족',
#   '사망',
#   '사고',
#   '현장',
#   '저런',
#   '사람',
#   '사네'],
#  ['대선',
#   '언론',
#   '국민',
#   '대체',
#   '무슨',
#   '조금',
#   '달',
#   '아야',
#   '만',
#   '이',
#   '만',
#   '이',
#   '하',
#   '며',
#   '일',
#   '일',
#   '최대',
#   '폭우',
#   '강조',
#   '하',
#   '는',
#   '데',
#   '돌아봐도',
#   '이번',
#   '능가',
#   '하',
#   '는',
#   '최대',
#   '폭우',
#   '매우',
#   '많',
#   '다고'],
#  ['산사태',
#   '위기',
#   '경보',
#   '경계',
#   '상향',
#   '이례',
#   '폭우',
#   '발생',
#   '서울',
#   '인천',
#   '경기',
#   '지역',
#   '산사태',
#   '위기',
#   '보가',
#   '주',
#   '의',
#   '경계',
#   '상향',
#   '되',
#   '었',
#   '습니다',
#   '산사태',
#   '고립',
#   '되',
#   '었',
#   '을',
#   '경우',
#   '구조',
#   '요청',
#   '산림청',
#   '산림',
#   '항공',
#   '구조대'],
#  ['물난리',
#   '났',
#   '는데',
#   '고립',
#   '되',
#   '서',
#   '나오',
#   '질',
#   '와중',
#   '대책',
#   '폭우',
#   '헬기',
#   '부르',
#   '려다가',
#   '실패',
#   '한',
#   '대통령',
#   '솔직히',
#   '어젯밤',
#   '의지',
#   '있',
#   '었',
#   '어도',
#   '출근',
#   '가능',
#   '했었',
#   '음',
#   '이런',
#   '날씨',
#   '일전',
#   '예고',
#   '됐었',
#   '는데',
#   '칼',
#   '퇴',
#   '해',
#   '가지',
#   '고',
#   '귀찮',
#   '아서',
#   '나온',
#   '거'],
#  ['어제',
#   '폭우',
#   '재난',
#   '피해',
#   '입',
#   '으신',
#   '가구',
#   '근처',
#   '건강',
#   '정지원',
#   '센터',
#   '긴급',
#   '위기',
#   '가족',
#   '지원',
#   '상담',
#   '받',
#   '아',
#   '보',
#   '세요',
#   '센터',
#   '별로',
#   '보유',
#   '민간',
#   '단체',
#   '자원',
#   '받',
#   '거나',
#   '가',
#   '구',
#   '사례',
#   '관리',
#   '재난',
#   '지역',
#   '선포',
#   '정부',
#   '지원',
#   '아이돌'],
#  ['폭우', '로켓', '배송', '근황', '쿠팡', '진짜', '빼', '고', '사', '는', '건가'],
#  ['지역구',
#   '포함',
#   '수도',
#   '권',
#   '온통',
#   '물난리',
#   '났',
#   '는데',
#   '씬',
#   '나',
#   '잼',
#   '있',
#   '다',
#   '트윗',
#   '올렸',
#   '다가',
#   '삭제',
#   '올린',
#   '트윗',
#   '오늘',
#   '폭우',
#   '길',
#   '위',
#   '레일',
#   '거의',
#   '굶',
#   '었',
#   '아잔',
#   '거리',
#   '폭우',
#   '소재',
#   '말장난',
#   '치',
#   '는',
#   '트윗'],
#  ['낭', '만', '넘치', '는', '강남역', '차주', '폭우', '낭만', '워터', '파크'],
#  ['강남역',
#   '아저씨',
#   '배수관',
#   '쌓여',
#   '있',
#   '는',
#   '쓰레기',
#   '건져',
#   '내',
#   '니',
#   '물',
#   '이',
#   '빠졌',
#   '다는',
#   '데',
#   '대단',
#   '하',
#   '신',
#   '것',
#   '과',
#   '별개',
#   '폭우',
#   '예보',
#   '진작',
#   '했',
#   '는데',
#   '전혀',
#   '대비',
#   '됐',
#   '다는',
#   '게',
#   '화나',
#   '고'],
#  ['아빠',
#   '공무원',
#   '어제',
#   '도착',
#   '비상',
#   '걸려서',
#   '다시',
#   '출근',
#   '그리고',
#   '시간',
#   '내내',
#   '소식',
#   '없',
#   '음',
#   '매년',
#   '했',
#   '어',
#   '폭우',
#   '폭설',
#   '기타',
#   '등등',
#   '무슨',
#   '있',
#   '을'],
#  ['폭우',
#   '고립',
#   '되',
#   '어',
#   '봐야',
#   '아무',
#   '하',
#   '러',
#   '오',
#   '지',
#   '대통령',
#   '죽이',
#   '겠',
#   '다고',
#   '트윗',
#   '하',
#   '면',
#   '시간',
#   '경찰',
#   '잡',
#   '으러'],
#  ['폭우',
#   '등등',
#   '이야기',
#   '나오',
#   '는데',
#   '이전',
#   '사뭇',
#   '다르',
#   '다는',
#   '이해',
#   '해',
#   '온난',
#   '화',
#   '이전',
#   '아웃',
#   '라이어',
#   '상황',
#   '일상',
#   '만들',
#   '분명',
#   '하',
#   '고',
#   '이전',
#   '본',
#   '적',
#   '없',
#   '는',
#   '상황',
#   '가져오'],
#  ['어제',
#   '오늘',
#   '수도',
#   '권',
#   '오',
#   '던데',
#   '트친',
#   '괜찮',
#   '으신',
#   '가요',
#   '부산',
#   '더워',
#   '디',
#   '질',
#   '것',
#   '같',
#   '은데',
#   '폭우',
#   '온다니',
#   '건강',
#   '하',
#   '고',
#   '열공',
#   '합시다'],
#  ['플로리', '폭우', '조심', '하', '구', '감기', '조심', '하', '기', '더', '쇼', '만나'],
#  ['서울',
#   '어마어마',
#   '한',
#   '폭우',
#   '예보',
#   '한가',
#   '롭',
#   '게',
#   '런던',
#   '아이',
#   '능가',
#   '하',
#   '는',
#   '대관람차',
#   '세우',
#   '겠',
#   '다는',
#   '발표',
#   '서울',
#   '시장',
#   '있',
#   '다구요'],
#  ['박원순',
#   '시장',
#   '여름',
#   '내내',
#   '장마',
#   '호우',
#   '태풍',
#   '대비',
#   '했었',
#   '고',
#   '피해',
#   '거의',
#   '없',
#   '었',
#   '죠',
#   '오세훈',
#   '시장',
#   '하',
#   '면',
#   '서울',
#   '바로',
#   '잠깁니다',
#   '서울',
#   '잠기',
#   '있',
#   '는데',
#   '오세훈',
#   '하',
#   '고',
#   '있',
#   '나요',
#   '행안',
#   '부',
#   '장관',
#   '있',
#   '나요'],
#  ['서방', '비록', '여기', '는', '폭염', '주의보'],
#  ['오늘', '닫', '아야', '겠', '어차피', '온라인', '있', '구', '폭우', '확실히', '사람', '없', '다'],
#  ['강남역',
#   '인근',
#   '어떤',
#   '하수',
#   '뚜껑',
#   '열',
#   '고',
#   '거기',
#   '쌓여',
#   '있',
#   '던',
#   '쓰레기',
#   '내자',
#   '허벅지',
#   '차올랐',
#   '던',
#   '물',
#   '이',
#   '빠졌',
#   '다고',
#   '하',
#   '는데',
#   '영웅',
#   '활약',
#   '조명',
#   '하',
#   '기',
#   '에',
#   '앞서',
#   '일',
#   '주일',
#   '수도',
#   '권',
#   '폭우',
#   '예보',
#   '됐',
#   '음',
#   '에',
#   '도',
#   '기본'],
#  ['안녕',
#   '하',
#   '십니까',
#   '폭우',
#   '침수',
#   '피해',
#   '인하',
#   '여',
#   '본래',
#   '강남',
#   '모나코',
#   '스페이스',
#   '개최',
#   '예정',
#   '이',
#   '었',
#   '던',
#   '행사',
#   '스페이스',
#   '쉐',
#   '어',
#   '삼성',
#   '센터',
#   '변경',
#   '결정',
#   '되',
#   '었',
#   '습니다',
#   '행사'],
#  ['폭우',
#   '어떻게',
#   '시장',
#   '퇴근',
#   '하',
#   '냐',
#   '서울',
#   '폭우',
#   '왔',
#   '습니다',
#   '호우',
#   '경보',
#   '발령',
#   '이',
#   '었',
#   '습니다',
#   '호우',
#   '경보',
#   '그냥',
#   '짱짱',
#   '선언',
#   '아니',
#   '잖아요'],
#  ['재난',
#   '결코',
#   '공평',
#   '하',
#   '지',
#   '않',
#   '습니다',
#   '공평',
#   '하',
#   '지',
#   '않',
#   '은',
#   '재난',
#   '우리',
#   '최소한',
#   '안전',
#   '되',
#   '어',
#   '주',
#   '는',
#   '국가',
#   '입니다',
#   '그러나',
#   '국가',
#   '기능',
#   '상실',
#   '포기',
#   '했',
#   '을',
#   '우리',
#   '서로',
#   '있',
#   '을',
#   '없',
#   '습니다',
#   '폭우'],
#  ['심각', '한', '데', '쓰', '나', '미', '아닌가', '정도'],
#  ['호우',
#   '일어났',
#   '을',
#   '자연',
#   '재난',
#   '행동',
#   '요령',
#   '구급',
#   '약품',
#   '손전등',
#   '식수',
#   '비상',
#   '식량',
#   '라디오',
#   '핸드폰',
#   '충전기',
#   '휴대',
#   '버너',
#   '담요',
#   '비상',
#   '용품',
#   '점검',
#   '한번',
#   '하',
#   '기',
#   '에요',
#   '이미지',
#   '호우',
#   '침수',
#   '관련'],
#  ['얼마나',
#   '일',
#   '이',
#   '정작',
#   '내려',
#   '야',
#   '하',
#   '는',
#   '농촌',
#   '지역',
#   '오',
#   '고',
#   '정도',
#   '가뭄',
#   '정작',
#   '내리',
#   '면',
#   '취약',
#   '도시',
#   '홍수',
#   '일어난다는',
#   '게',
#   '괴담',
#   '누가',
#   '알',
#   '티',
#   '해서',
#   '많',
#   '은',
#   '사람'],
#  ['근처',
#   '싱크홀',
#   '발생',
#   '지하',
#   '방',
#   '갑자기',
#   '물',
#   '이',
#   '차오르',
#   '기',
#   '시작',
#   '했',
#   '고',
#   '옆집',
#   '살',
#   '던',
#   '주민',
#   '필사',
#   '창문',
#   '뜯',
#   '어서',
#   '구출',
#   '하',
#   '려',
#   '했',
#   '지만',
#   '물',
#   '이',
#   '차',
#   '서',
#   '수',
#   '가',
#   '없',
#   '었',
#   '다고'],
#  ['동공', '지진', '났', '어'],
#  ['노원구',
#   '상계',
#   '인근',
#   '주민',
#   '여러분',
#   '산사태',
#   '경보',
#   '입니다',
#   '있',
#   '지',
#   '마세요',
#   '산사태',
#   '경보',
#   '토양',
#   '함수',
#   '내려',
#   '집니다',
#   '있',
#   '는',
#   '최대한',
#   '도의',
#   '내렸',
#   '습니다',
#   '나무',
#   '기울어져',
#   '있',
#   '거나',
#   '비탈',
#   '갑자기',
#   '물',
#   '이'],
#  ['진짜',
#   '오늘',
#   '오',
#   '는',
#   '무료',
#   '취소',
#   '시켜',
#   '줘야',
#   '하',
#   '는',
#   '거',
#   '아니',
#   '냐',
#   '제작사',
#   '정부',
#   '호우',
#   '주',
#   '의',
#   '경보',
#   '때리',
#   '고',
#   '지하철',
#   '역',
#   '은',
#   '침수',
#   '되',
#   '고',
#   '난리'],
#  ['자택',
#   '실시간',
#   '보',
#   '고',
#   '받',
#   '으며',
#   '호우',
#   '피해',
#   '점검',
#   '상황',
#   '지켜보',
#   '면서',
#   '어떡',
#   '해',
#   '어떡',
#   '해',
#   '하',
#   '고',
#   '있',
#   '는',
#   '크',
#   '게',
#   '차이'],
#  ['진짜', '뻔했', '어', '눈앞', '산사태', '나', '서', '앞앞', '깔렸', '음', '맞', '냐고'],
#  ['호우',
#   '주의보',
#   '떴',
#   '는데',
#   '대기',
#   '안함',
#   '배민',
#   '아니',
#   '면서',
#   '도착',
#   '예정',
#   '세종',
#   '이유',
#   '종합',
#   '황실',
#   '있',
#   '던',
#   '청와대',
#   '쓰',
#   '니까'],
#  ['차', '가', '여기저기', '그냥', '서', '있', '고', '산사태', '돌', '이'],
#  ['지하철',
#   '침수',
#   '역사',
#   '천정',
#   '무너지',
#   '고',
#   '도로',
#   '잠기',
#   '산사태',
#   '비상',
#   '폭우',
#   '우면산',
#   '산사태',
#   '강남역',
#   '침수',
#   '사태',
#   '광화문',
#   '물난리',
#   '난리',
#   '났었',
#   '다',
#   '지대',
#   '주민',
#   '조심',
#   '하',
#   '시',
#   '고'],
#  ['가천', '대', '기숙사', '산사태', '났', '나'],
#  ['재난',
#   '상황',
#   '트위터',
#   '소식',
#   '제일',
#   '빨라요',
#   '지난',
#   '년',
#   '전',
#   '지진',
#   '트위터',
#   '소식',
#   '제일',
#   '빨랐',
#   '어요',
#   '전화',
#   '통화',
#   '카톡',
#   '먹통',
#   '되',
#   '었었',
#   '고',
#   '재난',
#   '발생',
#   '하',
#   '면',
#   '트친',
#   '끼리',
#   '정보',
#   '공유',
#   '하',
#   '는',
#   '필요',
#   '합니다',
#   '들',
#   '어',
#   '어디',
#   '대피'],
#  ['됩니까',
#   '다른',
#   '지역',
#   '사망자',
#   '나오',
#   '고',
#   '폭우',
#   '수도',
#   '권',
#   '전체',
#   '고통',
#   '스럽',
#   '습니다',
#   '미추홀',
#   '어제',
#   '내렸',
#   '고',
#   '오후',
#   '건',
#   '의',
#   '피해',
#   '접수',
#   '됐',
#   '고',
#   '산사태',
#   '주의보',
#   '내려졌',
#   '습니다',
#   '밤',
#   '사'],
#  ['속보', '서울', '노원구', '상계', '중계동', '산사태', '경보', '발령'],
#  ['아랫',
#   '지방',
#   '현재',
#   '상황',
#   '서울',
#   '물난리',
#   '몰랐',
#   '음',
#   '우리',
#   '나라',
#   '오',
#   '는',
#   '몰랐',
#   '음',
#   '가뭄',
#   '개오지',
#   '저',
#   '수지',
#   '거',
#   '즘',
#   '바닥',
#   '보임',
#   '매미',
#   '소리',
#   '하루',
#   '종일',
#   '들으니까',
#   '미치',
#   '겠',
#   '음'],
#  ['속보', '대본', '서울', '경기', '호우', '사망', '실종', '부상', '뉴스'],
#  ['소리',
#   '영상',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제',
#   '다음',
#   '뉴스'],
#  ['간밤',
#   '무서운',
#   '폭우',
#   '천둥',
#   '번개',
#   '워낙',
#   '피해',
#   '커서',
#   '안녕',
#   '묻',
#   '기',
#   '무서울',
#   '정도',
#   '입니다',
#   '사망',
#   '오늘',
#   '폭우',
#   '이어지',
#   '는데',
#   '부디',
#   '무서운',
#   '산사태',
#   '사고',
#   '없',
#   '기',
#   '를',
#   '악몽',
#   '떠오릅니다',
#   '부디',
#   '무사',
#   '하',
#   '시',
#   '기',
#   '를',
#   '부디',
#   '피해'],
#  ['조만간',
#   '가',
#   '겠',
#   '군',
#   '영상',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제'],
#  ['청와대',
#   '있',
#   '으면',
#   '국민',
#   '목숨',
#   '살릴',
#   '수',
#   '있',
#   '었',
#   '는데',
#   '우리',
#   '나라',
#   '공무원',
#   '죽',
#   '었',
#   '어',
#   '강원도',
#   '산불',
#   '나',
#   '서',
#   '물난리',
#   '나',
#   '서',
#   '사람',
#   '죽',
#   '었',
#   '어',
#   '경주',
#   '지진',
#   '나',
#   '서',
#   '사람',
#   '죽',
#   '었',
#   '냐고',
#   '청와대',
#   '나',
#   '랏',
#   '님',
#   '있',
#   '으면',
#   '재해',
#   '사람',
#   '죽',
#   '는다면',
#   '많',
#   '은'],
#  ['참고',
#   '가',
#   '는',
#   '건',
#   '파란색',
#   '지진',
#   '겪',
#   '은',
#   '트친',
#   '알려',
#   '라이트',
#   '봉지',
#   '씌우',
#   '면',
#   '밝',
#   '아',
#   '집니다'],
#  ['구르', '는', '지진', '날', '수', '있', '으니', '조심', '하', '시', '오'],
#  ['속보',
#   '서울',
#   '노원구',
#   '상계',
#   '중계동',
#   '산사태',
#   '경보',
#   '발령',
#   '출처',
#   '매일신문',
#   '네이버',
#   '뉴스'],
#  ['당시',
#   '문재',
#   '인',
#   '정부',
#   '호우',
#   '대처',
#   '긴급',
#   '상황',
#   '점검',
#   '회의',
#   '모습',
#   '어제',
#   '총리',
#   '호우',
#   '대처',
#   '긴급',
#   '상황',
#   '점검',
#   '회의',
#   '모습'],
#  ['서울',
#   '중구',
#   '산사태',
#   '경보',
#   '발령',
#   '됐',
#   '다는',
#   '데',
#   '재난',
#   '문자',
#   '제대로',
#   '발송',
#   '되',
#   '고',
#   '있',
#   '는',
#   '건가'],
#  ['지금',
#   '목격담',
#   '호우',
#   '버디',
#   '산책',
#   '딘',
#   '깅',
#   '사진',
#   '찍',
#   '어',
#   '호시',
#   '준',
#   '앤',
#   '앤',
#   '전',
#   '맛있',
#   '는',
#   '거',
#   '먹',
#   '으러',
#   '간',
#   '듯',
#   '잇',
#   '군',
#   '추',
#   '면서',
#   '걸',
#   '었',
#   '다',
#   '제보',
#   '투명',
#   '카약',
#   '자전거',
#   '경주',
#   '릴레이',
#   '홍',
#   '앤',
#   '밍',
#   '새벽',
#   '백화점',
#   '물',
#   '어'],
#  ['퇴근',
#   '하',
#   '고',
#   '싶',
#   '었',
#   '나',
#   '대통령',
#   '평생',
#   '하나',
#   '최선',
#   '다',
#   '해',
#   '가뭄',
#   '잘못',
#   '홍수',
#   '잘못',
#   '이',
#   '라며',
#   '작',
#   '은',
#   '일',
#   '도',
#   '꼼꼼히',
#   '챙기',
#   '고',
#   '해결',
#   '하',
#   '겠',
#   '다는',
#   '그런',
#   '마음',
#   '있',
#   '어야죠',
#   '국정',
#   '철학',
#   '문제',
#   '퍼낼',
#   '것',
#   '도',
#   '아니',
#   '고',
#   '담당자'],
#  ['횡', '성', '산사태', '돌아가', '셨', '대', '속상하', '다', '고인', '명복', '빕', '니다'],
#  ['지금',
#   '시점',
#   '서울시',
#   '인사',
#   '공백',
#   '하수',
#   '처리',
#   '예산',
#   '문제',
#   '하',
#   '는',
#   '게',
#   '가장',
#   '기본',
#   '어떻게',
#   '세훈',
#   '이',
#   '형',
#   '수',
#   '가',
#   '있',
#   '나',
#   '게다가',
#   '어제',
#   '오전',
#   '호우',
#   '예보',
#   '있',
#   '었',
#   '으니',
#   '세훈',
#   '이형',
#   '쉴드',
#   '칠',
#   '거',
#   '면',
#   '상습',
#   '피해',
#   '지역'],
#  ['산사태', '남', '한', '산성', '인근', '세대', '고립', '전화', '먹통'],
#  ['가뭄',
#   '여름',
#   '수해',
#   '난다',
#   '모든',
#   '모든',
#   '자연재해',
#   '제외',
#   '된다',
#   '인류',
#   '문명',
#   '상당히',
#   '발전',
#   '했',
#   '지만',
#   '폭우',
#   '하나',
#   '감당',
#   '강수량',
#   '맥스',
#   '설정',
#   '해서',
#   '재난',
#   '대비',
#   '한다던',
#   '전',
#   '의',
#   '계획'],
#  ['영상',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제'],
#  ['서울', '노원', '도봉', '종로구', '산사태', '경보', '주의보', '발령'],
#  ['강원', '횡', '성', '산사태', '주택', '매몰', '평창', '급류', '숨져', '뉴스'],
#  ['영상',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제',
#   '다음',
#   '뉴스',
#   '박형수',
#   '원내',
#   '대변인',
#   '지시',
#   '했',
#   '느냐는',
#   '문제',
#   '없',
#   '어'],
#  ['나라',
#   '가뭄',
#   '홍수',
#   '계속',
#   '되',
#   '어',
#   '곡식',
#   '익',
#   '지',
#   '않',
#   '으면',
#   '허물',
#   '돌려',
#   '바꾸',
#   '거나',
#   '죽여야',
#   '한다고',
#   '했',
#   '다',
#   '결과',
#   '마',
#   '여',
#   '죽',
#   '고',
#   '아들',
#   '여섯',
#   '짜리',
#   '의려',
#   '세워',
#   '세웠',
#   '다',
#   '삼국지',
#   '부여',
#   '시대',
#   '상관'],
#  ['오세훈',
#   '서울',
#   '시장',
#   '우면산',
#   '산사태',
#   '사망',
#   '이재명',
#   '성남',
#   '시장',
#   '교환',
#   '풍구',
#   '참사',
#   '사망',
#   '정말',
#   '어휴'],
#  ['오세훈', '가뭄', '지역', '분할', '설치', '하', '자'],
#  ['서울',
#   '인천',
#   '홍수',
#   '나',
#   '서',
#   '곳곳이',
#   '잠기',
#   '폐쇄',
#   '하',
#   '지하철역',
#   '수십',
#   '길',
#   '이',
#   '잠겨서',
#   '꼼짝',
#   '달싹',
#   '거',
#   '나',
#   '둥둥',
#   '떠내려가',
#   '고',
#   '있',
#   '는데',
#   '재난',
#   '직접',
#   '책임자',
#   '서울',
#   '시장',
#   '행안',
#   '부',
#   '장관',
#   '인천',
#   '시장',
#   '대통령',
#   '빼',
#   '기'],
#  ['싱크홀', '생겨서', '트럭', '빠짐', '아스팔트', '일어남', '여긴', '논현', '입니다'],
#  ['과거',
#   '이',
#   '돈',
#   '시절',
#   '강남역',
#   '호우',
#   '인해',
#   '진흥',
#   '아파트',
#   '인도',
#   '행인',
#   '감전사',
#   '하',
#   '는',
#   '사고',
#   '보도',
#   '되',
#   '자',
#   '진흥',
#   '아파트',
#   '주민',
#   '집값',
#   '떨어진다고',
#   '하',
#   '며',
#   '민원',
#   '넣',
#   '는',
#   '바람',
#   '기사',
#   '삭제',
#   '되',
#   '었',
#   '던',
#   '기억',
#   '있',
#   '슴',
#   '덕분',
#   '상황',
#   '여전히',
#   '반복'],
#  ['가뭄',
#   '지구',
#   '어딘가',
#   '폭탄',
#   '퍼붓',
#   '는다는',
#   '지구',
#   '물',
#   '의',
#   '총량',
#   '일정',
#   '하',
#   '고',
#   '재앙',
#   '서로',
#   '연결',
#   '되',
#   '어',
#   '있',
#   '다'],
#  ['동공',
#   '지진',
#   '일',
#   '이',
#   '거짓말',
#   '같',
#   '은',
#   '같',
#   '은데',
#   '진실',
#   '되',
#   '어',
#   '보였',
#   '어',
#   '비록',
#   '했',
#   '지만',
#   '표정'],
#  ['수도', '권', '강원도', '호우', '특보', '내려진', '가운데', '시간', '내리', '는', '있', '습니다'],
#  ['초밥',
#   '깔',
#   '아',
#   '놨',
#   '어',
#   '밀려',
#   '드',
#   '는',
#   '감동',
#   '쓰',
#   '나미',
#   '후',
#   '란',
#   '받',
#   '아서',
#   '고맙',
#   '다고',
#   '움',
#   '쬬움쬬',
#   '해',
#   '주',
#   '는데',
#   '누구',
#   '허리',
#   '감싸',
#   '더니',
#   '저런',
#   '멘',
#   '트',
#   '날리',
#   '고',
#   '있',
#   '는',
#   '거',
#   '야',
#   '보',
#   '기',
#   '했',
#   '고',
#   '저런',
#   '말',
#   '하',
#   '는지',
#   '도',
#   '알',
#   '겠',
#   '는'],
#  ['민주',
#   '정부',
#   '지진',
#   '태풍',
#   '미리',
#   '재난',
#   '경고',
#   '분주',
#   '하',
#   '게',
#   '움직이',
#   '면',
#   '별일',
#   '아닌',
#   '피곤',
#   '하',
#   '게',
#   '호들갑',
#   '세금',
#   '낭비',
#   '한다',
#   '한다',
#   '이런',
#   '반응',
#   '많',
#   '았',
#   '음'],
#  ['성심',
#   '당',
#   '홈페이지',
#   '깄다',
#   '이번',
#   '호우',
#   '때문',
#   '았',
#   '았',
#   '는데',
#   '저번',
#   '호우',
#   '때문',
#   '이',
#   '었',
#   '에'],
#  ['서울시',
#   '치수',
#   '예산',
#   '억',
#   '원',
#   '줄',
#   '어',
#   '증가',
#   '추세',
#   '이후',
#   '감소',
#   '종전',
#   '서울시',
#   '호우',
#   '대비',
#   '해서',
#   '공사',
#   '미리',
#   '진행',
#   '도로',
#   '배수',
#   '시설',
#   '사전',
#   '점검',
#   '정리',
#   '했',
#   '어요',
#   '후관'],
#  ['순', '훈', '호우', '영', '뾰', '아기', '토끼', '머리', '했', '더라'],
#  ['인용', '동공', '지진'],
#  ['영상',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제',
#   '윤석열',
#   '대통령',
#   '문제',
#   '아니',
#   '었',
#   '알',
#   '았',
#   '습니다',
#   '재난',
#   '물으니',
#   '갑자기',
#   '소리',
#   '하',
#   '는',
#   '국민'],
#  ['기록',
#   '폭우',
#   '기후',
#   '변화',
#   '아니',
#   '라',
#   '그냥',
#   '그런',
#   '게',
#   '가끔',
#   '발생',
#   '아니',
#   '씨',
#   '바',
#   '그게',
#   '한국',
#   '있',
#   '었',
#   '던',
#   '되',
#   '지',
#   '유럽',
#   '기록',
#   '폭염',
#   '켄터키',
#   '기록',
#   '폭우',
#   '미국',
#   '서부',
#   '산불',
#   '기록',
#   '가뭄',
#   '세계'],
#  ['호우', '대처', '회의', '모습', '호우', '대처', '회의', '모습'],
#  ['푸딩', '케이크', '동공', '지진', '선생', '님', '거기', '어딘가'],
#  ['싸이',
#   '가뭄',
#   '흠뻑',
#   '쑈',
#   '한다',
#   '손기락',
#   '질',
#   '받',
#   '았',
#   '잖아',
#   '좌파',
#   '비록',
#   '현직',
#   '아닌',
#   '전직',
#   '대통령',
#   '이',
#   '었',
#   '다면',
#   '물난리',
#   '났',
#   '는데',
#   '자기',
#   '제주',
#   '신나',
#   '게',
#   '물놀',
#   '이',
#   '중',
#   '이',
#   '사진',
#   '올리',
#   '는',
#   '욕먹',
#   '을',
#   '만',
#   '하',
#   '지',
#   '않',
#   '냐'],
#  ['서울시',
#   '산사태',
#   '축대',
#   '담장',
#   '파손',
#   '지역',
#   '침수',
#   '도로',
#   '주택',
#   '상가',
#   '최대한',
#   '빠른',
#   '시간',
#   '복구',
#   '있',
#   '도록',
#   '최선',
#   '있',
#   '습니다',
#   '시민',
#   '여러분',
#   '재난',
#   '문자',
#   '기상',
#   '상황',
#   '확인',
#   '주',
#   '시'],
#  ['어제',
#   '강원도',
#   '산간',
#   '지역',
#   '많',
#   '은',
#   '내려',
#   '침수',
#   '산사태',
#   '피해',
#   '발생',
#   '있',
#   '습니다',
#   '물가',
#   '산사태',
#   '위험',
#   '지역',
#   '감전',
#   '위험',
#   '있',
#   '는',
#   '고압',
#   '전선',
#   '근처',
#   '해',
#   '주',
#   '시',
#   '고',
#   '산사태',
#   '보가',
#   '내려진',
#   '춘천',
#   '홍천',
#   '횡',
#   '성',
#   '철원'],
#  ['지자체',
#   '정부',
#   '되',
#   '면',
#   '수구',
#   '걸림',
#   '여부',
#   '확인',
#   '산사태',
#   '극한',
#   '더위',
#   '대비',
#   '작업',
#   '해야',
#   '하',
#   '지',
#   '않',
#   '냐구',
#   '그게',
#   '상식',
#   '아냐',
#   '이제',
#   '수구',
#   '막힘',
#   '타령',
#   '있',
#   '는',
#   '게',
#   '되',
#   '냐구',
#   '하',
#   '기',
#   '싫',
#   '으면',
#   '그냥',
#   '꺼져',
#   '대가리'],
#  ['지금',
#   '우리',
#   '라인',
#   '산사태',
#   '나',
#   '서',
#   '소방관',
#   '집집',
#   '초인종',
#   '누르',
#   '고',
#   '피하',
#   '급하',
#   '게',
#   '지갑',
#   '들',
#   '고',
#   '나왔',
#   '는데',
#   '도로',
#   '엉망',
#   '빠져',
#   '나올',
#   '무슨',
#   '일',
#   '이',
#   '어디',
#   '가',
#   '야',
#   '해'],
#  ['산사태', '발생', '주택', '쳤', '고', '남성', '매몰', '숨졌', '습니다'],
#  ['한국',
#   '과외',
#   '한국',
#   '장마',
#   '보',
#   '고',
#   '정말',
#   '고맙',
#   '다고',
#   '해서',
#   '가뭄',
#   '고통',
#   '받',
#   '았었',
#   '나',
#   '재해',
#   '상황',
#   '아니',
#   '지',
#   '않',
#   '나',
#   '했',
#   '는데',
#   '완전',
#   '반대',
#   '어이',
#   '없',
#   '을',
#   '정도',
#   '불만'],
#  ['이', '쯤', '되', '면', '오세훈', '가뭄', '지역', '시장', '해야', '되', '는', '아닌지'],
#  ['아니',
#   '가뭄',
#   '이한창',
#   '흠뻑',
#   '같',
#   '은',
#   '걸',
#   '하',
#   '니까',
#   '예수',
#   '님',
#   '빡',
#   '친',
#   '거',
#   '아'],
#  ['지금',
#   '댓글',
#   '달리',
#   '는',
#   '보고',
#   '동공',
#   '지진',
#   '나',
#   '서',
#   '없',
#   '는',
#   '신어',
#   '하나',
#   '고민',
#   '중',
#   '이'],
#  ['서울',
#   '폭설',
#   '내리',
#   '고',
#   '난리',
#   '구경',
#   '없',
#   '던',
#   '지방',
#   '살',
#   '던',
#   '모습',
#   '마치',
#   '다른',
#   '나라',
#   '같',
#   '았',
#   '다',
#   '지금',
#   '수도',
#   '권',
#   '물난리',
#   '남부',
#   '가뭄',
#   '시달리',
#   '는',
#   '지역',
#   '아득히',
#   '멀',
#   '게',
#   '느껴',
#   '지',
#   '겠',
#   '구나',
#   '한다'],
#  ['내려서',
#   '스스로',
#   '생각',
#   '하',
#   '기',
#   '에',
#   '자신',
#   '비슷',
#   '하',
#   '게',
#   '생긴',
#   '사람',
#   '험악',
#   '근육',
#   '덮',
#   '은',
#   '문신',
#   '상',
#   '탈',
#   '가리키',
#   '면서',
#   '귀엽',
#   '지',
#   '속닥',
#   '동공',
#   '지진',
#   '하',
#   '는',
#   '보',
#   '고',
#   '싶',
#   '다',
#   '생각',
#   '맞',
#   '았',
#   '나'],
#  ['현재',
#   '수도',
#   '권',
#   '강원',
#   '산지',
#   '호우',
#   '특보',
#   '발효',
#   '가운데',
#   '서울',
#   '인천',
#   '북부',
#   '강원',
#   '북부',
#   '중심',
#   '시간',
#   '매우',
#   '강한',
#   '내리',
#   '는',
#   '있',
#   '습니다',
#   '최신',
#   '기상',
#   '정보',
#   '특보',
#   '상황',
#   '실시간',
#   '레이더',
#   '영상',
#   '참고',
#   '해',
#   '주',
#   '시'],
#  ['윗', '쪽', '피해', '남쪽', '극심', '한', '가뭄', '함부로', '옮기', '는', '게', '아니', '다'],
#  ['계양',
#   '구청',
#   '계양구',
#   '산사태',
#   '발생',
#   '위험',
#   '높',
#   '음',
#   '산림',
#   '발생',
#   '우려',
#   '지역',
#   '주민',
#   '방문객',
#   '입산',
#   '금지',
#   '떨어진',
#   '안전',
#   '한',
#   '피해',
#   '시기',
#   '바랍니다',
#   '계양',
#   '구청',
#   '안전',
#   '안내',
#   '문자',
#   '재난',
#   '문자'],
#  ['호우', '순', '훈', '호랑이', '산신령', '이제', '인간', '행세', '한다', '네요'],
#  ['중부', '집중호우', '서울', '자치구', '산사태', '경보', '주의보', '발령'],
#  ['스',
#   '쿠',
#   '이타',
#   '메인',
#   '지른',
#   '먹',
#   '는',
#   '사람',
#   '고유',
#   '후시',
#   '이타',
#   '소비',
#   '하',
#   '는',
#   '데',
#   '그릴',
#   '그릴지',
#   '는',
#   '몰라',
#   '용',
#   '그림',
#   '가뭄',
#   '하',
#   '고',
#   '파우',
#   '치',
#   '만',
#   '듭니',
#   '숨',
#   '쉬',
#   '듯이',
#   '여체',
#   '화',
#   '하',
#   '니',
#   '지뢰',
#   '계정',
#   '뮤',
#   '트',
#   '추천',
#   '드립',
#   '니',
#   '당'],
#  ['국민',
#   '박형수',
#   '원내',
#   '대변인',
#   '윤석열',
#   '대통령',
#   '호우',
#   '대처',
#   '아쉬운',
#   '묻',
#   '자',
#   '서해',
#   '공무원',
#   '피살',
#   '무대',
#   '처',
#   '가',
#   '문제',
#   '머릿속',
#   '북풍',
#   '공작',
#   '글자',
#   '아무',
#   '들',
#   '어',
#   '있',
#   '는',
#   '게',
#   '없',
#   '다',
#   '보',
#   '니'],
#  ['기록',
#   '호우',
#   '인한',
#   '강남',
#   '침수',
#   '오세훈',
#   '대권',
#   '떠내려가',
#   '버림',
#   '수해',
#   '기억',
#   '하',
#   '는',
#   '서초',
#   '구민',
#   '강남',
#   '구민',
#   '많',
#   '아요'],
#  ['서울',
#   '폭설',
#   '내리',
#   '고',
#   '난리',
#   '구경',
#   '없',
#   '던',
#   '남쪽',
#   '끄트머리',
#   '살',
#   '던',
#   '모습',
#   '마치',
#   '다른',
#   '나라',
#   '재난',
#   '같',
#   '았',
#   '다',
#   '남부',
#   '가뭄',
#   '시달리',
#   '는',
#   '지역',
#   '지금',
#   '수도',
#   '권',
#   '물난리',
#   '아득히',
#   '멀',
#   '게',
#   '느껴',
#   '지',
#   '겠',
#   '구나',
#   '한다'],
#  ['육아',
#   '경력',
#   '이',
#   '긴',
#   '했',
#   '지만',
#   '무선',
#   '낳',
#   '은',
#   '아이',
#   '부친',
#   '남',
#   '망기',
#   '가졌',
#   '을',
#   '낳',
#   '아만',
#   '주',
#   '면',
#   '세상',
#   '전부',
# ...
#   '누적',
#   '천만',
#   '원',
#   '상당',
#   '상품권',
#   '걸린',
#   '대박',
#   '이벤트',
#   '금일',
#   '시작',
#   '진행',
#   '되',
#   '오니',
#   '많',
#   '은',
#   '참여',
#   '바랍니다'],
#  ['충청',
#   '권',
#   '경북',
#   '북부',
#   '호우',
#   '특보',
#   '발효',
#   '가운데',
#   '충청',
#   '권',
#   '시간',
#   '이상',
#   '경기',
#   '남부',
#   '시간',
#   '내외',
#   '경북',
#   '강원도',
#   '시간',
#   '미만',
#   '내리',
#   '고',
#   '해상',
#   '발달',
#   '비구름',
#   '유입',
#   '되',
#   '면서',
#   '돌풍',
#   '천둥',
#   '번개'],
#  ['아쉽',
#   '게',
#   '도',
#   '가지',
#   '는',
#   '한답니다',
#   '내년',
#   '부모',
#   '님',
#   '전액',
#   '지원',
#   '해',
#   '주',
#   '신다고',
#   '해서',
#   '내년',
#   '노리',
#   '는',
#   '입니다',
#   '키즈',
#   '보',
#   '러',
#   '가',
#   '시',
#   '길'],
#  ['컵', '홀더', '일러스트', '공개', '합니다', '협력', '주신', '헤', '문', '진심', '감사', '드립니다'],
#  ['나락',
#   '도락',
#   '이번',
#   '펜',
#   '타',
#   '나락',
#   '깃발',
#   '만든',
#   '페스티벌',
#   '라이프',
#   '입니다',
#   '일요일',
#   '자우림',
#   '무대',
#   '마지막',
#   '윤',
#   '아',
#   '저희',
#   '깃발',
#   '보',
#   '며',
#   '구호',
#   '외쳐',
#   '주',
#   '셨',
#   '어요',
#   '락',
#   '페',
#   '인생',
#   '최고',
#   '영광',
#   '이',
#   '었',
#   '습니다'],
#  ['지반',
#   '약해져서',
#   '싱크홀',
#   '걱정',
#   '해야',
#   '겠',
#   '네',
#   '잠실',
#   '버틸',
#   '수',
#   '있',
#   '겠',
#   '냐',
#   '윤석렬',
#   '퇴진',
#   '김건희',
#   '특검'],
#  ['이건',
#   '단순히',
#   '사안',
#   '아님',
#   '재난',
#   '쉽',
#   '게',
#   '구조',
#   '용이',
#   '하',
#   '려고',
#   '띄',
#   '는',
#   '형광',
#   '명',
#   '도',
#   '높',
#   '은',
#   '하',
#   '는',
#   '건데',
#   '칙칙',
#   '한',
#   '그냥',
#   '시멘트',
#   '보호색',
#   '묻히',
#   '라는',
#   '특수',
#   '의류',
#   '소재',
#   '뒷돈',
#   '받',
#   '음'],
#  ['복지', '배치', '된', '게', '다행'],
#  ['지민',
#   '안부',
#   '지민',
#   '패턴',
#   '있',
#   '는',
#   '듯',
#   '날씨',
#   '과격',
#   '할',
#   '잊',
#   '지',
#   '않',
#   '고',
#   '오',
#   '기',
#   '나갈',
#   '들어올',
#   '소식',
#   '알리',
#   '기',
#   '자신',
#   '좋',
#   '은',
#   '일',
#   '이',
#   '있',
#   '을',
#   '나',
#   '를',
#   '칭찬',
#   '하',
#   '는',
#   '감사',
#   '사',
#   '하',
#   '기',
#   '신기',
#   '함',
#   '우리',
#   '칭찬',
#   '하',
#   '러'],
#  ['우리',
#   '강아지',
#   '애기',
#   '자꾸',
#   '내밀',
#   '어서',
#   '충치',
#   '구강',
#   '구조',
#   '문제',
#   '있',
#   '으면',
#   '밀',
#   '고',
#   '있',
#   '는대서',
#   '덜덜',
#   '떨',
#   '면서',
#   '병원',
#   '갔',
#   '는데',
#   '그냥',
#   '길',
#   '대',
#   '길',
#   '어서',
#   '가끔',
#   '아니',
#   '고',
#   '자주',
#   '넣',
#   '는',
#   '거래',
#   '애기',
#   '꾸준히'],
#  ['풍수',
#   '보험',
#   '있',
#   '다는',
#   '태풍',
#   '홍수',
#   '호우',
#   '강풍',
#   '대설',
#   '지진',
#   '해일',
#   '풍랑',
#   '인해',
#   '피해',
#   '발생',
#   '하',
#   '면',
#   '보상',
#   '해',
#   '주',
#   '는',
#   '정책',
#   '보험',
#   '정부',
#   '지자체',
#   '이상',
#   '보험료',
#   '지원',
#   '해',
#   '준다고'],
#  ['레드',
#   '벨벳',
#   '대우',
#   '개선',
#   '해시',
#   '태그',
#   '공모',
#   '구글',
#   '링크',
#   '첨부',
#   '합니다',
#   '많',
#   '은',
#   '비분',
#   '참여',
#   '부탁',
#   '드리',
#   '며',
#   '이번',
#   '해시',
#   '태그',
#   '목적',
#   '소속',
#   '사',
#   '나',
#   '은',
#   '대우',
#   '바라',
#   '는',
#   '것',
#   '임',
#   '알',
#   '립니',
#   '다'],
#  ['서울',
#   '페스',
#   '개막',
#   '공연',
#   '참여',
#   '자',
#   '명단',
#   '본인',
#   '확인',
#   '안내',
#   '마감',
#   '시간',
#   '장소',
#   '호선',
#   '종합',
#   '운동장',
#   '역',
#   '출구',
#   '공터',
#   '서울',
#   '페스',
#   '개막',
#   '공연',
#   '참여',
#   '하',
#   '시',
#   '는'],
#  ['강민',
#   '샌드위치',
#   '도시락',
#   '보내',
#   '주',
#   '셨',
#   '습니다',
#   '덕분',
#   '맛있',
#   '게',
#   '먹',
#   '고',
#   '나',
#   '네요',
#   '박스',
#   '무게',
#   '만큼',
#   '무거웠',
#   '던',
#   '마음',
#   '감사',
#   '합니다',
#   '항상',
#   '감사',
#   '합니다',
#   '강민아',
#   '먹',
#   '을',
#   '게',
#   '김강민'],
#  ['오늘', '발매', '주년', '기념', '실총', '예정', '입니다', '많', '은', '참여', '부탁', '드립니다'],
#  ['괜찮', '으시', '다니', '정말', '다행', '그만', '야할', '텐데', '조심', '하', '셔야'],
#  ['역사', '만드', '는', '게', '아니', '라', '복원', '하', '는', '것'],
#  ['자기',
#   '덕분',
#   '눈물',
#   '난다',
#   '자기',
#   '아니',
#   '였',
#   '음',
#   '여기',
#   '올',
#   '수',
#   '있',
#   '었',
#   '을가',
#   '자기',
#   '야',
#   '우리',
#   '머나먼',
#   '멘',
#   '에서',
#   '만나',
#   '사랑'],
#  ['오늘',
#   '죽였',
#   '다',
#   '이제',
#   '점점',
#   '재미',
#   '있',
#   '어',
#   '진다',
#   '처음',
#   '매우',
#   '당황',
#   '스러웠',
#   '지만',
#   '이제',
#   '자연',
#   '스럽',
#   '다',
#   '이번',
#   '귀여운',
#   '사람',
#   '하나',
#   '죽였',
#   '다',
#   '사람',
#   '나와',
#   '취미',
#   '같',
#   '았',
#   '다',
#   '아니',
#   '취미',
#   '존경',
#   '하',
#   '는'],
#  ['손', '글씨', '지원', '되', '는'],
#  ['예상',
#   '되',
#   '던',
#   '비구름',
#   '형성',
#   '되',
#   '지',
#   '않',
#   '거나',
#   '위치',
#   '이탈',
#   '해서',
#   '대량',
#   '담수',
#   '유입',
#   '멈추',
#   '면',
#   '다행',
#   '시나리오',
#   '모두',
#   '일어나',
#   '지',
#   '않',
#   '게',
#   '입',
#   '니다',
#   '하',
#   '지만',
#   '까딱',
#   '잘못',
#   '해서',
#   '비구름',
#   '계속',
#   '있',
#   '었',
#   '으면',
#   '내일',
#   '정말',
#   '무슨'],
#  ['모두',
#   '익명',
#   '질문',
#   '모집',
#   '최근',
#   '답변',
#   '질문',
#   '덕',
#   '질',
#   '처음',
#   '그러',
#   '는',
#   '썸머',
#   '이번',
#   '제주',
#   '완전',
#   '다행',
#   '제주시',
#   '슬로건',
#   '제작',
#   '하',
#   '시',
#   '나용',
#   '질문',
#   '상자'],
#  ['보은군',
#   '외',
#   '적',
#   '자봉',
#   '사회',
#   '취약',
#   '계층',
#   '가정',
#   '반찬',
#   '나눔',
#   '봉사',
#   '브레이크',
#   '뉴스'],
#  ['호기심',
#   '쿠션',
#   '그란',
#   '매력',
#   '고양이',
#   '쿠션',
#   '깜냥',
#   '경우',
#   '두운',
#   '배치',
#   '두면',
#   '발견',
#   '하',
#   '지',
#   '같',
#   '아요',
#   '수요',
#   '조사',
#   '참여'],
#  ['용인시',
#   '이상일',
#   '용인',
#   '특례시',
#   '수해',
#   '현장',
#   '인명',
#   '구조',
#   '주민',
#   '모범',
#   '시민',
#   '표창',
#   '주기',
#   '보도',
#   '뉴스'],
#  ['어',
#   '맛',
#   '마감',
#   '합니다',
#   '많',
#   '은',
#   '관심',
#   '감사',
#   '드립니다',
#   '정식',
#   '개장',
#   '뵙',
#   '겠',
#   '습니다'],
#  ['맥시', '마', '이', '까말까', '고민', '했', '는데', '계기', '주', '는군', '감사', '감사'],
#  ['사상',
#   '최대',
#   '폭우',
#   '산사태',
#   '홍수',
#   '사건',
#   '사망자',
#   '열',
#   '도',
#   '결코',
#   '적',
#   '지',
#   '않',
#   '은',
#   '같',
#   '은데',
#   '지역',
#   '별',
#   '강수량',
#   '붕괴',
#   '위험',
#   '도',
#   '를',
#   '돌아가',
#   '며',
#   '전달',
#   '하',
#   '는',
#   '일본',
#   '방송',
#   '다급',
#   '한',
#   '재해',
#   '정보',
#   '뉴스',
#   '설렁',
#   '설렁',
#   '보영',
#   '침수',
#   '중고차',
#   '피하'],
#  ['입',
#   '고',
#   '안내',
#   '이벤트',
#   '일요일',
#   '오후',
#   '작가',
#   '제품',
#   '종이',
#   '입',
#   '고',
#   '됩니다',
#   '많',
#   '은',
#   '성원',
#   '감사',
#   '드리',
#   '며',
#   '해당',
#   '게시',
#   '주신',
#   '사진'],
#  ['다행', '이런', '게', '아니', '라서'],
#  ['차별',
#   '공론',
#   '에스엠',
#   '레드',
#   '벨벳',
#   '콘서트',
#   '돌려',
#   '소리',
#   '자기',
#   '지원',
#   '해',
#   '주',
#   '고',
#   '흔한',
#   '자',
#   '컨',
#   '만들',
#   '어',
#   '주',
#   '고',
#   '돌',
#   '은',
#   '해',
#   '주',
#   '는',
#   '프로모션',
#   '계속',
#   '띄워',
#   '줬',
#   '으면',
#   '성과',
#   '내지',
#   '자기'],
#  ['엉덩이', '젤', '안', '아픈', '부위', '다행', '압', '바'],
#  ['사실',
#   '테스트',
#   '취소',
#   '였',
#   '다면',
#   '굳이',
#   '결제',
#   '만든',
#   '자체',
#   '이상',
#   '했',
#   '다',
#   '의혹',
#   '퍼진',
#   '비상',
#   '선언',
#   '박스오피스',
#   '했',
#   '는데',
#   '위',
#   '로',
#   '밀려난',
#   '한산',
#   '매출',
#   '오히려',
#   '적',
#   '었',
#   '다',
#   '당시',
#   '특별',
#   '매출'],
#  ['평등',
#   '교육',
#   '시간',
#   '공평',
#   '한',
#   '가사',
#   '임금',
#   '차이',
#   '이런',
#   '얘기',
#   '했',
#   '는데',
#   '구조',
#   '성',
#   '차별',
#   '이런',
#   '건',
#   '배우',
#   '겠',
#   '지'],
#  ['아니',
#   '주말',
#   '백화점',
#   '극장',
#   '빵집',
#   '경호',
#   '의전',
#   '우려',
#   '잘',
#   '만',
#   '다니',
#   '던',
#   '대통령',
#   '호우',
#   '사태',
#   '주민',
#   '불편',
#   '우려',
#   '해서',
#   '헬기',
#   '띄우',
#   '고',
#   '하',
#   '는',
#   '사람',
#   '불편',
#   '할까봐',
#   '나오',
#   '지',
#   '않',
#   '았',
#   '다니',
#   '대통령',
#   '경호',
#   '받',
#   '고'],
#  ['안녕',
#   '하',
#   '세요',
#   '돌입',
#   '주년',
#   '이벤트',
#   '시작',
#   '됩니다',
#   '오랜',
#   '시간',
#   '지켜',
#   '주',
#   '시',
#   '고',
#   '사랑',
#   '해',
#   '주',
#   '신',
#   '모든',
#   '감사',
#   '마음',
#   '합니다',
#   '창조',
#   '멋진',
#   '의상',
#   '인형',
#   '여러분',
#   '보답',
#   '하',
#   '겠',
#   '습니다',
#   '감사',
#   '합니다',
#   '리',
#   '트윗'],
#  ['합니다'],
#  ['믹스', '펜', '석', '생각', '다행'],
#  ['다행'],
#  ['별거', '아니', '였', '지만', '도움', '되', '셨', '다니', '다행'],
#  ['트위터',
#   '이자',
#   '트',
#   '좍',
#   '들',
#   '하',
#   '면',
#   '이상',
#   '한',
#   '게',
#   '아니',
#   '구나',
#   '싶',
#   '고',
#   '이런',
#   '생각',
#   '하',
#   '는',
#   '게',
#   '아니',
#   '여서',
#   '다행',
#   '싶',
#   '은데',
#   '시간',
#   '그리고',
#   '점점',
#   '실',
#   '친',
#   '만날',
#   '필요',
#   '성',
#   '느껴',
#   '지',
#   '고',
#   '적당히',
#   '해야지'],
#  ['다친', '사람', '없', '어', '다행', '이', '었', '어요'],
#  ['지인', '사랑', '스러운', '시도', '보중', '홍보', '한번', '해', '주', '시', '감사'],
#  ['이벤트',
#   '도운',
#   '문득',
#   '레코드',
#   '커버',
#   '다가오',
#   '는',
#   '우리',
#   '냉이',
#   '생일',
#   '기념',
#   '하',
#   '여',
#   '문득',
#   '해',
#   '주',
#   '신',
#   '보내',
#   '드립니다',
#   '인쇄',
#   '장식',
#   '노래',
#   '나오',
#   '지'],
#  ['가흐',
#   '아이',
#   '아해',
#   '같',
#   '은',
#   '아니',
#   '라서',
#   '다행',
#   '당겨진',
#   '상태',
#   '심통',
#   '부린다',
#   '조심',
#   '다녀',
#   '와라',
#   '잡',
#   '고',
#   '있',
#   '는',
#   '억지로',
#   '떼',
#   '어',
#   '내',
#   '고',
#   '했',
#   '다'],
#  ['처음',
#   '겪',
#   '는',
#   '가뭄',
#   '솔직히',
#   '트친',
#   '들',
#   '이',
#   '트윗',
#   '달라',
#   '하',
#   '시',
#   '는',
#   '거',
#   '벅찼',
#   '어요'],
#  ['진짜',
#   '이제',
#   '한숨',
#   '돌립니다',
#   '오늘',
#   '참여',
#   '했어여',
#   '출장',
#   '갔',
#   '다가',
#   '이제',
#   '들어옴',
#   '다시',
#   '야근',
#   '고고'],
#  ['차량',
#   '침수',
#   '위험',
#   '행동',
#   '하',
#   '세요',
#   '타이어',
#   '높이',
#   '이상',
#   '잠기',
#   '기',
#   '차량',
#   '옮기',
#   '기',
#   '고립',
#   '급류',
#   '밀려오',
#   '는',
#   '반대쪽',
#   '탈출',
#   '열리',
#   '면',
#   '단단',
#   '한',
#   '물체'],
#  ['멈춰',
#   '있',
#   '는',
#   '보고',
#   '웃',
#   '은',
#   '같',
#   '다',
#   '별거',
#   '아니',
#   '라는',
#   '가벼운',
#   '말투',
#   '걱정',
#   '하',
#   '는',
#   '그럴',
#   '정도',
#   '아냐',
#   '하루',
#   '후회',
#   '하',
#   '지만',
#   '정도'],
#  ['기부',
#   '전통',
#   '시장',
#   '조속',
#   '수해',
#   '복구',
#   '정책',
#   '역량',
#   '총동원',
#   '집중호우',
#   '피해',
#   '입',
#   '은',
#   '수도',
#   '권',
#   '지역',
#   '전통',
#   '시장',
#   '조속',
#   '영업',
#   '재개',
#   '위해',
#   '금융',
#   '시설',
#   '복구'],
#  ['모닝', '비기', '그쳐서', '다행', '해피', '하루', '되', '세요'],
#  ['어느',
#   '개방',
#   '거지',
#   '홍대광',
#   '심부름',
#   '화산',
#   '달려왔',
#   '음',
#   '지금',
#   '강남',
#   '도움',
#   '받',
#   '았',
#   '던',
#   '마을',
#   '양민',
#   '사패',
#   '련',
#   '공격',
#   '받',
#   '았',
#   '다고',
#   '정파',
#   '무시',
#   '했으니',
#   '급히',
#   '우맹',
#   '지원',
#   '요청',
#   '바란다고'],
#  ['셀리', '느', '님', '침착', '한', '나레이션', '덕분', '웃겨', '춰요'],
#  ['다행', '잔기침', '졸린', '거', '빼', '고', '있', '어요', '싶', '다'],
#  ['우리',
#   '인피니트',
#   '톡',
#   '방',
#   '얘기',
#   '보',
#   '면',
#   '하',
#   '고',
#   '싶',
#   '은',
#   '게',
#   '많',
#   '더라구요',
#   '하',
#   '고',
#   '싶',
#   '어',
#   '하',
#   '는',
#   '많',
#   '고',
#   '이런',
#   '멤버',
#   '마음',
#   '감사',
#   '드립니다',
#   '진짜',
#   '인피니트',
#   '건강',
#   '하',
#   '게',
#   '보',
#   '자'],
#  ['페이',
#   '회당',
#   '스',
#   '폰',
#   '문',
#   '의',
#   '주세요',
#   '서울',
#   '회사',
#   '다니',
#   '고',
#   '있',
#   '어서',
#   '평일',
#   '불가',
#   '합니다',
#   '중반',
#   '본가',
#   '전주',
#   '입니다',
#   '원',
#   '하',
#   '시',
#   '면',
#   '차량',
#   '지원',
#   '가능',
#   '하',
#   '고',
#   '금토',
#   '일',
#   '가능',
#   '합니다',
#   '편하'],
#  ['가물', '어', '있', '는', '우퍼', '부으면', '백', '퍼', '산사태', '대본', '멍청이', '썼', '냐'],
#  ['감사',
#   '드려요',
#   '베',
#   '어',
#   '뮤지컬',
#   '베',
#   '어',
#   '교환',
#   '회차',
#   '교환',
#   '윤석호',
#   '윤',
#   '승우',
#   '한결',
#   '박상준',
#   '박슬기',
#   '김경민',
#   '중',
#   '블',
#   '오른쪽',
#   '중',
#   '블',
#   '왼쪽'],
#  ['아산시',
#   '신정호',
#   '야외',
#   '음악당',
#   '열리',
#   '는',
#   '페스티벌',
#   '국카스텐',
#   '초청',
#   '공연',
#   '펼칩니다',
#   '무료',
#   '입장',
#   '진행',
#   '예정',
#   '여러분',
#   '많',
#   '은',
#   '관심',
#   '참여',
#   '부탁',
#   '드립니다',
#   '국카스텐'],
#  ['팔로우',
#   '해',
#   '주',
#   '시',
#   '모든',
#   '감사',
#   '드립니다',
#   '보답',
#   '의미',
#   '작품',
#   '준비',
#   '했',
#   '습니다',
#   '혹시',
#   '가',
#   '지',
#   '싶',
#   '으신',
#   '계실까'],
#  ['아이',
#   '나',
#   '나',
#   '일곱',
#   '다행',
#   '이',
#   '었',
#   '으면',
#   '일곱',
#   '아니',
#   '야',
#   '질문',
#   '길',
#   '게',
#   '설명',
#   '하',
#   '다가',
#   '고',
#   '가',
#   '빡',
#   '쳐서',
#   '묻',
#   '었',
#   '어',
#   '라고',
#   '하',
#   '는',
#   '사태',
#   '벌어지',
#   '지',
#   '않',
#   '음'],
#  ['시발', '소리', '이용', '다행', '뿌', '뿌', '국', '붘', '였', '다고'],
#  ['예상',
#   '되',
#   '던',
#   '비구름',
#   '형성',
#   '되',
#   '지',
#   '않',
#   '거나',
#   '위치',
#   '이탈',
#   '해서',
#   '대량',
#   '담수',
#   '유입',
#   '멈추',
#   '면',
#   '다행',
#   '시나리오',
#   '모두',
#   '일어나',
#   '지',
#   '않',
#   '게',
#   '입',
#   '니다',
#   '하',
#   '지만',
#   '까딱',
#   '잘못',
#   '해서',
#   '비구름',
#   '계속',
#   '있',
#   '었',
#   '으면',
#   '내일',
#   '정말',
#   '무슨',
#   '일',
#   '이'],
#  ['사랑',
#   '우정',
#   '이별',
#   '추억',
#   '감사',
#   '행복',
#   '한',
#   '마음',
#   '희망',
#   '모든',
#   '느낌',
#   '다양',
#   '한',
#   '장르',
#   '통해',
#   '생생히',
#   '느껴',
#   '지',
#   '는',
#   '명반',
#   '트랙',
#   '티',
#   '리',
#   '톰바'],
#  ['사실',
#   '영상',
#   '자체',
#   '뭔가',
#   '기억',
#   '안',
#   '나',
#   '갑자기',
#   '탈출',
#   '노예',
#   '잡',
#   '으러',
#   '댕기',
#   '힙합',
#   '노래',
#   '처럼',
#   '처절',
#   '하',
#   '고',
#   '어쩌구',
#   '그런',
#   '싶',
#   '엇다'],
#  ['우리',
#   '그',
#   '이',
#   '당장',
#   '쫓겨날',
#   '모르',
#   '고',
#   '있',
#   '으니',
#   '다행',
#   '해야',
#   '하나',
#   '대리',
#   '구매',
#   '종로',
#   '가연',
#   '어',
#   '플',
#   '놀',
#   '아',
#   '났',
#   '다는',
#   '생각',
#   '그냥',
#   '당장'],
#  ['인',
#   '스타',
#   '스토리',
#   '올',
#   '린지',
#   '기억',
#   '못',
#   '햇',
#   '는데',
#   '올라와',
#   '있',
#   '길래',
#   '생각',
#   '비타',
#   '피',
#   '는',
#   '거',
#   '찍',
#   '은',
#   '기억',
#   '있',
#   '어서',
#   '실수',
#   '올렸',
#   '나',
#   '생각',
#   '쫄',
#   '았',
#   '는데',
#   '다른',
#   '거',
#   '였',
#   '다',
#   '다행'],
#  ['최고', '탈출', '마술사', '후디니', '지옥', '돌아옵니다'],
#  ['최예나',
#   '엠',
#   '카운트',
#   '다운',
#   '공개',
#   '방송',
#   '참여',
#   '명단',
#   '안내',
#   '생방송',
#   '최예나',
#   '예나',
#   '스마트폰'],
#  ['래',
#   '빈',
#   '행복',
#   '해서',
#   '다행',
#   '자기',
#   '행복',
#   '한',
#   '게',
#   '미안',
#   '해서',
#   '말',
#   '못하',
#   '는',
#   '사랑'],
#  ['그래', '찬다는', '뜻', '이', '겟', '다행', '소중', '해'],
#  ['진짜',
#   '정권',
#   '바뀔',
#   '지랄',
#   '대표',
#   '캐릭터',
#   '슬로건',
#   '로고',
#   '온갖',
#   '홍보물',
#   '조물',
#   '전부',
#   '교체',
#   '하',
#   '는',
#   '데',
#   '드',
#   '는',
#   '비용',
#   '인력',
#   '지겨워',
#   '죽',
#   '겠',
#   '어'],
#  ['노조',
#   '홍씨',
#   '가족',
#   '죽음',
#   '이르',
#   '게',
#   '구조',
#   '원인',
#   '있',
#   '다고',
#   '주장',
#   '했',
#   '다',
#   '반지하',
#   '열악',
#   '한',
#   '주거',
#   '형태',
#   '발달',
#   '장애',
#   '노인',
#   '사회',
#   '약자',
#   '대한',
#   '지원',
#   '미비',
#   '집중호우',
#   '당시',
#   '재난',
#   '대응',
#   '시스템',
#   '제대로',
#   '작동',
#   '하',
#   '지'],
#  ['박문',
#   '대',
#   '의',
#   '배려',
#   '방식',
#   '어설퍼서',
#   '웃',
#   '김',
#   '유진',
#   '먼저',
#   '해서',
#   '결정',
#   '했',
#   '다는',
#   '선택',
#   '책임',
#   '따르',
#   '는',
#   '아니',
#   '까',
#   '선택',
#   '늦추',
#   '거나',
#   '안전',
#   '만든',
#   '방식',
#   '살아온',
#   '박문',
#   '이런',
#   '불가피',
#   '한',
#   '상황'],
#  ['영재',
#   '있',
#   '다니',
#   '진짜',
#   '보',
#   '고',
#   '싶',
#   '었',
#   '는데',
#   '뽑',
#   '자마자',
#   '우리',
#   '아가',
#   '등장',
#   '슈',
#   '스',
#   '덥',
#   '덕분',
#   '콘서트',
#   '보',
#   '기',
#   '전',
#   '에',
#   '다양',
#   '한',
#   '체험',
#   '해',
#   '보',
#   '고',
#   '좋',
#   '았',
#   '던',
#   '같',
#   '아요',
#   '다음',
#   '수량',
#   '해',
#   '주',
#   '세요'],
#  ['참여', '안내', '서울', '페스', '개막', '공연'],
#  ['부탁',
#   '드립니다',
#   '고양이',
#   '분양',
#   '고양이',
#   '입양',
#   '안녕',
#   '하',
#   '세요',
#   '고양이',
#   '분양',
#   '보내',
#   '기',
#   '위해',
#   '씁니다',
#   '맞',
#   '으며',
#   '죽',
#   '어',
#   '가',
#   '던',
#   '고양이',
#   '구조',
#   '했',
#   '고',
#   '없',
#   '던',
#   '애기',
#   '현재',
#   '붙',
#   '고',
#   '건강',
#   '하',
#   '게',
#   '컸으며',
#   '병원'],
#  ['트친',
#   '소',
#   '아',
#   '는',
#   '사람',
#   '아',
#   '시',
#   '겠',
#   '지만',
#   '여자',
#   '친구',
#   '있',
#   '구요',
#   '사람',
#   '마세요',
#   '서울',
#   '사람',
#   '다정',
#   '착함',
#   '잔소리',
#   '진입',
#   '장벽',
#   '낮',
#   '아여',
#   '환영',
#   '플',
#   '러',
#   '팅',
#   '섹',
#   '러'],
#  ['호우'],
#  ['아카이브', '남', '아', '있', '다니', '다행'],
#  ['입양',
#   '홍보',
#   '하',
#   '겠',
#   '습니다',
#   '월령',
#   '중성',
#   '예방',
#   '접종',
#   '완료',
#   '경남',
#   '지역',
#   '데려다',
#   '드립니다',
#   '파양',
#   '경험',
#   '단순',
#   '변심',
#   '어미',
#   '새끼',
#   '낳',
#   '은',
#   '로드',
#   '킬',
#   '당해',
#   '케이스',
#   '중성',
#   '방사',
#   '했으나',
#   '방사',
#   '동안',
#   '모금',
#   '먹',
#   '지',
#   '않',
#   '아',
#   '구조',
#   '많',
#   '고',
#   '소심',
#   '합',
#   '니'],
#  ['미친',
#   '왹',
#   '냥',
#   '키',
#   '링',
#   '자랑',
#   '하',
#   '아',
#   '아아',
#   '귀여워',
#   '요',
#   '우러',
#   '힙',
#   '쿨',
#   '왹',
#   '냥',
#   '도안',
#   '공유',
#   '해',
#   '주',
#   '신',
#   '도영',
#   '무한',
#   '감사',
#   '드리',
#   '고',
#   '계신',
#   '방향',
#   '올립니다',
#   '키',
#   '링',
#   '받',
#   '으면',
#   '먼저'],
#  ['요즘',
#   '다시',
#   '접',
#   '률',
#   '높',
#   '아',
#   '지',
#   '신',
#   '익명',
#   '이',
#   '세',
#   '귀여우',
#   '시',
#   '고',
#   '말랑',
#   '하',
#   '신',
#   '뵙',
#   '지',
#   '했',
#   '는데',
#   '돌아오',
#   '셔서',
#   '다행',
#   '익명',
#   '드림',
#   '간',
#   '만',
#   '보',
#   '니',
#   '더욱',
#   '반가웠',
#   '어요',
#   '올리',
#   '신',
#   '커미션',
#   '정말',
#   '예뻤',
#   '고요',
#   '귀여운',
#   '친구'],
#  ['타',
#   '팬',
#   '참여',
#   '가능',
#   '추첨',
#   '스테이',
#   '색안경',
#   '아이',
#   '앨범',
#   '포카',
#   '드립니다',
#   '이벤트',
#   '당첨',
#   '되',
#   '지',
#   '않',
#   '았',
#   '다고',
#   '언',
#   '괄',
#   '하',
#   '실',
#   '경우',
#   '블락',
#   '됩니다'],
#  ['서울',
#   '경기',
#   '인천',
#   '울진',
#   '산불',
#   '현장',
#   '구조',
#   '초딩',
#   '모아',
#   '가',
#   '입양',
#   '찾',
#   '고',
#   '있',
#   '어요',
#   '고양이',
#   '입양',
#   '사지',
#   '입양',
#   '하',
#   '세요'],
#  ['뮤직', '뱅크', '사전', '녹화', '본', '방송', '참여', '안내', '골든', '일', '드', '아우라'],
#  ['다행'],
#  ['감사',
#   '드립니다',
#   '거래',
#   '실례',
#   '하',
#   '겠',
#   '습니다',
#   '엘리',
#   '히어로',
#   '카오스',
#   '오스',
#   '엘리',
#   '히어로',
#   '마그마',
#   '오스',
#   '일판',
#   '일괄',
#   '팝',
#   '니',
#   '다',
#   '등기',
#   '비용',
#   '추가',
#   '됩니다'],
#  ['세븐',
#   '우지',
#   '인형',
#   '피카',
#   '수요',
#   '조사',
#   '추첨',
#   '제작',
#   '확정',
#   '피카',
#   '뾰',
#   '보내',
#   '드립니다',
#   '자세',
#   '한',
#   '내용'],
#  ['이재명',
#   '아니',
#   '고',
#   '여유',
#   '자금',
#   '이',
#   '라면서',
#   '경기도',
#   '재난',
#   '관리',
#   '기금',
#   '정부',
#   '재난',
#   '원금',
#   '비대',
#   '상자',
#   '였',
#   '던',
#   '퍼센트',
#   '상위',
#   '시원',
#   '하',
#   '게',
#   '덕분',
#   '이번',
#   '수해',
#   '이후',
#   '인물',
#   '말라리아',
#   '모기',
#   '대량',
#   '번식',
#   '인한',
#   '말라리아',
#   '창궐'],
#  ['토크',
#   '믹스',
#   '글로벌',
#   '거래소',
#   '상장',
#   '커뮤니티',
#   '월렛',
#   '통한',
#   '바',
#   '이',
#   '블루칩',
#   '에어드',
#   '랍'],
#  ['포카',
#   '바인더',
#   '수요',
#   '조사',
#   '많',
#   '은',
#   '감사',
#   '하',
#   '게',
#   '도',
#   '포카',
#   '바인더',
#   '대해',
#   '문',
#   '의',
#   '주',
#   '셔서',
#   '조사',
#   '진행',
#   '하',
#   '려고',
#   '합니다',
#   '최소',
#   '수량',
#   '채워',
#   '지',
#   '지',
#   '않',
#   '을',
#   '경우',
#   '무산',
#   '알려',
#   '드리',
#   '며',
#   '구매',
#   '하',
#   '실',
#   '참여',
#   '부탁',
#   '드립니다'],
#  ['아이구', '아팠', '구나', '꿉', '마', '지금', '괜찮', '다니', '다행'],
#  ['초코',
#   '부자',
#   '돼서',
#   '이벤트',
#   '열',
#   '어',
#   '봐요',
#   '트친',
#   '참여',
#   '가능',
#   '하',
#   '니깐',
#   '받',
#   '아',
#   '가요'],
#  ['진실',
#   '밝혀',
#   '주',
#   '셔서',
#   '본인',
#   '뒤집',
#   '어',
#   '쓰',
#   '고',
#   '죽',
#   '는',
#   '없',
#   '게',
#   '주',
#   '셔서',
#   '진심',
#   '감사',
#   '드립니다'],
#  ['골드',
#   '니스',
#   '여러분',
#   '지금',
#   '바로',
#   '네이버',
#   '파티',
#   '놀',
#   '러',
#   '오',
#   '세요',
#   '아래',
#   '링크',
#   '들어와',
#   '주',
#   '세요',
#   '어',
#   '플',
#   '설치',
#   '참여',
#   '가능',
#   '합니다'],
#  ['성규', '동시', '살', '고', '있', '어서', '다행'],
#  ['사찬', '천사', '덕분', '꽃', '숮', '직관']]

# %%
type(result)
# Out:
# list

# %%
mecab1['word']=pd.Series(result)

# %%
mecab1
# Out:
#                                                 tokens  tone  \
# 0    서울 되련 뭣같 이돈 뭣같 지옥런 새끼 뭣같 산불 보러 간다 했으면서 멀쩡한 컨트롤...    -3
# 1                                     지겹게 이어지던 산불 가득하다    -1
# 2    이번 뉴스 해도 파키스탄 지난 주간 폭우 사망 미국 켄터키주 폭우 사망 이란 폭우 ...    -2
# 3                   이상 화재 사람 죽어 도지사 떡볶이 먹방 찍고계셨던 말씀 셨습    -2
# 4    재난 닥치니 진짜 문재인 대통령 이낙연 총리 시절 그리워 죽겠음 그때 산불 났을 어...    -2
# ..                                                 ...   ...
# 824                초코 부자 돼서 이벤트 열어 봐요 트친 참여 가능하니깐 받아가요     1
# 825           진실 밝혀 주셔서 본인 뒤집어 쓰고 죽는 없게 주셔서 진심 감사 드립니다     1
# 826  골드 니스 여러분 지금 바로 네이버 파티 놀러 오세요 아래 링크 들어와 주세요 어플...     0
# 827                                     성규 동시 살고있어서 다행     0
# 828                                     사찬 천사 덕분 꽃숮 직관     1
#
#                                                   word
# 0    [서울, 되, 련, 뭣, 같, 이, 돈, 뭣, 같, 지옥, 런, 새끼, 뭣, 같, ...
# 1                        [지겹, 게, 이어지, 던, 산불, 가득, 하, 다]
# 2    [이번, 뉴스, 해도, 파키스탄, 지난, 주간, 폭우, 사망, 미국, 켄터키주, 폭...
# 3    [이상, 화재, 사람, 죽, 어, 도지사, 떡볶이, 먹방, 찍, 고, 계셨, 던, ...
# 4    [재난, 닥치, 니, 진짜, 문재, 인, 대통령, 이낙연, 총리, 시절, 그리워, ...
# ..                                                 ...
# 824  [초코, 부자, 돼서, 이벤트, 열, 어, 봐요, 트친, 참여, 가능, 하, 니깐,...
# 825  [진실, 밝혀, 주, 셔서, 본인, 뒤집, 어, 쓰, 고, 죽, 는, 없, 게, 주...
# 826  [골드, 니스, 여러분, 지금, 바로, 네이버, 파티, 놀, 러, 오, 세요, 아래...
# 827                          [성규, 동시, 살, 고, 있, 어서, 다행]
# 828                             [사찬, 천사, 덕분, 꽃, 숮, 직관]
#
# [829 rows x 3 columns]

# %%
import konlpy

# %% [markdown]
# Word2Vec 학습

# %%
from gensim.models import Word2Vec
w2v_model = Word2Vec(mecab1['word'], size=100, window=5, min_count=5, workers=4, sg=0)
# Out:
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
w2v_model.train(mecab1['word'],epochs=10,total_examples=len(mecab1['word']))
# Out:
# WARNING:gensim.models.base_any2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# (91162, 188150)

# %%
w2v_model.wv.get_vector('폭염')
# Out:
# array([-0.0471651 , -0.48604834, -0.05126873,  0.17372158,  0.17117384,
#         0.07252903, -0.19358446,  0.03208101,  0.3518953 , -0.13845585,
#        -0.11806884,  0.30697307,  0.19527267,  0.23898914,  0.15249035,
#        -0.11940234, -0.06275327, -0.00157507, -0.19533557, -0.06219251,
#         0.1318571 , -0.28471053,  0.40438268,  0.09621154,  0.21935545,
#         0.19172016, -0.04801303,  0.06292937,  0.05988831, -0.06635524,
#        -0.2688427 ,  0.2699307 ,  0.01784352,  0.05365425,  0.33597127,
#        -0.49360666,  0.24822691, -0.06267721, -0.35758102, -0.35257638,
#         0.15622115,  0.03433609,  0.23848012, -0.04041442,  0.13771227,
#        -0.04950699, -0.00985904, -0.24400821,  0.02808829,  0.36036164,
#        -0.19246225, -0.19653617, -0.36096132,  0.12670906,  0.08062725,
#        -0.4516243 , -0.7960447 , -0.3182171 , -0.15253486,  0.04098013,
#         0.30076182, -0.17280638, -0.1440175 ,  0.26840797,  0.05067078,
#        -0.43345058,  0.0528288 ,  0.12045186, -0.08133621,  0.2660434 ,
#         0.11142896,  0.12980917,  0.21027589, -0.03888104,  0.2087596 ,
#        -0.06960701, -0.04562394, -0.19973437,  0.15619013, -0.18495399,
#        -0.0024606 , -0.03466729,  0.42160287,  0.03863774, -0.05350669,
#         0.21551536,  0.08159123, -0.22367072, -0.06240152, -0.1881873 ,
#        -0.10898252, -0.08182202, -0.4075811 ,  0.25254956, -0.42723694,
#         0.33479038,  0.07717538,  0.08328512,  0.19670501, -0.03186369],
#       dtype=float32)

# %%
vocab=w2v_model.wv.vocab

# %%
w2v_model.wv.most_similar('폭염')
# Out:
# [('주의보', 0.9995733499526978),
#  ('경보', 0.999366283416748),
#  ('호우', 0.9993630647659302),
#  ('폭우', 0.9991953372955322),
#  ('발령', 0.9991815686225891),
#  ('발효', 0.9991775751113892),
#  ('산사태', 0.9991214275360107),
#  ('서울', 0.99900221824646),
#  ('피해', 0.9989963173866272),
#  ('남부', 0.9989914298057556)]

# %%
w2v_model.wv.similarity('폭염','경보')
# Out:
# 0.99936634

# %%
model_result1 = model.wv.most_similar('폭염')
print(model_result1)
# Out:
# [('은', 0.9999063611030579), ('는데', 0.999894380569458), ('호우', 0.9998927116394043), ('로', 0.9998891353607178), ('와', 0.9998880624771118), ('가', 0.9998875856399536), ('도', 0.9998844265937805), ('에', 0.9998838305473328), ('한', 0.9998820424079895), ('피해', 0.9998811483383179)]

# %%
model_result2 = model.wv.most_similar('폭우')
print(model_result2)
# Out:
# [('은', 0.9999381899833679), ('고', 0.9999322891235352), ('s', 0.9999298453330994), ('에서', 0.9999275207519531), ('을', 0.9999272227287292), ('에', 0.9999229907989502), ('인', 0.9999228715896606), ('다', 0.9999213814735413), ('를', 0.9999211430549622), ('호우', 0.9999197125434875)]

# %%
model_result3 = model.wv.most_similar('장마')
print(model_result3)
# Out:
# [('까지', 0.9993916749954224), ('기', 0.999382495880127), (',', 0.9993792176246643), ('지금', 0.9993767738342285), ('은', 0.9993762969970703), ('아', 0.9993679523468018), ('사랑', 0.9993560910224915), ('집', 0.999354362487793), ('엔', 0.9993424415588379), ('게', 0.9993411898612976)]

# %%
model_result4 = model.wv.most_similar('열대야')
print(model_result4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ada4aa2b9690> in <module>
# ----> 1 model_result4 = model.wv.most_similar('열대야')
#       2 print(model_result4)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     529                 mean.append(weight * word)
#     530             else:
# --> 531                 mean.append(weight * self.word_vec(word, use_norm=True))
#     532                 if word in self.vocab:
#     533                     all_words.add(self.vocab[word].index)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     450             return result
#     451         else:
# --> 452             raise KeyError("word '%s' not in vocabulary" % word)
#     453
#     454     def get_vector(self, word):
#
# KeyError: "word '열대야' not in vocabulary"

# %%
model_result5 = model.wv.most_similar('미세먼지')
print(model_result5)
# Out:
# [('드립니다', 0.9995397925376892), ('는데', 0.999518632888794), ('나', 0.9995152950286865), ('은', 0.9995111227035522), ('받', 0.9994935989379883), ('안', 0.9994924664497375), ('s', 0.9994905591011047), ('로', 0.9994888305664062), ('도', 0.9994879961013794), (',', 0.9994876980781555)]

# %%
model_result6 = model.wv.most_similar('감사')
print(model_result6)
# Out:
# [('호우', 0.9999151825904846), ('에', 0.9999150633811951), ('한', 0.9999145269393921), ('으로', 0.9999107122421265), ('도', 0.9999102354049683), ('이벤트', 0.9999077916145325), ('로', 0.9999077916145325), (',', 0.9999058842658997), ('어', 0.9999037981033325), ('이', 0.999903678894043)]

# %%
model_result7 = model.wv.most_similar('구호')
print(model_result7)
# Out:
# [('쿠팡', 0.9978756308555603), ('이벤트', 0.9978430271148682), ('으로', 0.9978277683258057), ('반지하', 0.9978252649307251), ('진짜', 0.9977995753288269), ('내', 0.997779130935669), ('거', 0.9977753162384033), ('한', 0.997774064540863), ('될', 0.9977724552154541), ('수요', 0.9977611303329468)]

# %%
model_result8 = model.wv.most_similar('봉사')
print(model_result8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6270c315423a> in <module>
# ----> 1 model_result8 = model.wv.most_similar('봉사')
#       2 print(model_result8)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     529                 mean.append(weight * word)
#     530             else:
# --> 531                 mean.append(weight * self.word_vec(word, use_norm=True))
#     532                 if word in self.vocab:
#     533                     all_words.add(self.vocab[word].index)
#
# /usr/local/lib/python3.7/dist-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     450             return result
#     451         else:
# --> 452             raise KeyError("word '%s' not in vocabulary" % word)
#     453
#     454     def get_vector(self, word):
#
# KeyError: "word '봉사' not in vocabulary"

# %%
# model_result9 = model.wv.most_similar('헌금')
# print(model_result9)

# # KeyError: "word '헌금' not in vocabulary"

# %%
model_result10 = model.wv.most_similar('구조')
print(model_result10)
# Out:
# [('생명', 0.4288700222969055), ('로운', 0.4180153012275696), ('위태', 0.40249109268188477), ('요령', 0.3944876492023468), ('없', 0.38351112604141235), ('피딱지', 0.3804859519004822), ('있', 0.37930065393447876), ('고용', 0.3525405526161194), ('먹', 0.3333415985107422), ('생겨서', 0.33124783635139465)]

# %%
model_result11 = model.wv.most_similar('복원')
print(model_result11)
# Out:
# [('훈련', 0.6285222172737122), ('민정', 0.6250796914100647), ('군사', 0.5827081203460693), ('맛집', 0.5428624749183655), ('가죽', 0.5257540941238403), ('블락', 0.5088286399841309), ('허전', 0.5081915259361267), ('추진', 0.47981876134872437), ('합격', 0.4693043828010559), ('한미', 0.46403756737709045)]

# %%
model_result12 = model.wv.most_similar('성금')
print(model_result12)
# Out:
# [('기부', 0.7022218704223633), ('기탁', 0.6266367435455322), ('박진영', 0.6093829870223999), ('선', 0.592495322227478), ('김진우', 0.5792907476425171), ('천만', 0.5615476369857788), ('위해', 0.5531625747680664), ('위너', 0.5314822793006897), ('식사', 0.5224571824073792), ('세븐', 0.5151652097702026)]

# %%
model_result13 = model.wv.most_similar('덕분')
print(model_result13)
# Out:
# [('안쪽', 0.38795119524002075), ('썸머', 0.3870335519313812), ('클라', 0.3733670115470886), ('알뜰', 0.3553280234336853), ('루', 0.3426221013069153), ('찾아와', 0.34174391627311707), ('외', 0.3376672863960266), ('클', 0.3357512652873993), ('군산', 0.32952746748924255), ('음악중심', 0.32312291860580444)]

# %%
model_result14 = model.wv.most_similar('다행')
print(model_result14)
# Out:
# [('믿', 0.3955284357070923), ('주머니', 0.3879498839378357), ('천사', 0.375988245010376), ('앙', 0.369259238243103), ('빨랐', 0.34011903405189514), ('교미', 0.33924493193626404), ('멍해', 0.33880090713500977), ('거주민', 0.3248734474182129), ('울고불', 0.3231324553489685), ('돈', 0.32276690006256104)]

# %%
model_result15 = model.wv.most_similar('탈출')
print(model_result15)
# Out:
# [('으름', 0.7322622537612915), ('추간판', 0.6722912788391113), ('착과', 0.6329920291900635), ('수막', 0.622794508934021), ('협', 0.5977888703346252), ('법', 0.5712242126464844), ('생정', 0.5588423609733582), ('마술사', 0.5503325462341309), ('녀', 0.501824140548706), ('후디니', 0.4967937171459198)]

# %%
model_result16 = model.wv.most_similar('자원')
print(model_result16)
# Out:
# [('시중', 0.7008351683616638), ('소비', 0.6255648136138916), ('외교', 0.6248132586479187), ('계획', 0.53000807762146), ('셋째', 0.5290130376815796), ('연계', 0.5063797235488892), ('판매', 0.49347758293151855), ('민간단체', 0.4859551787376404), ('나설', 0.46883419156074524), ('기량', 0.4601386487483978)]

# %%
model_result17 = model.wv.most_similar('지원')
print(model_result17)
# Out:
# [('극복', 0.49275413155555725), ('한테', 0.47459426522254944), ('사업', 0.4620247185230255), ('유지', 0.45016705989837646), ('합심', 0.44736427068710327), ('나설', 0.42402148246765137), ('상관', 0.4100351333618164), ('최소', 0.4048599600791931), ('신청', 0.39997223019599915), ('제휴', 0.39989298582077026)]

# %%
model_result18 = model.wv.most_similar('참여')
print(model_result18)
# Out:
# [('폼', 0.5027613639831543), ('불고기', 0.46575191617012024), ('버거', 0.46427613496780396), ('가게', 0.4613768756389618), ('캡', 0.459553986787796), ('맥도날드', 0.4478757977485657), ('포장비', 0.43380478024482727), ('사전', 0.4301600158214569), ('녹화', 0.42815327644348145), ('스', 0.4184895157814026)]
